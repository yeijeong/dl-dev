# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client
import ctypes
 
################################################
# PLUS 공통 OBJECT
g_objCodeMgr = win32com.client.Dispatch('CpUtil.CpCodeMgr')
g_objCpStatus = win32com.client.Dispatch('CpUtil.CpCybos')
g_objCpTrade = win32com.client.Dispatch('CpTrade.CpTdUtil')
 
 
################################################
# PLUS 실행 기본 체크 함수
def InitPlusCheck():
    # 프로세스가 관리자 권한으로 실행 여부
    if ctypes.windll.shell32.IsUserAnAdmin():
        print('정상: 관리자권한으로 실행된 프로세스입니다.')
    else:
        print('오류: 일반권한으로 실행됨. 관리자 권한으로 실행해 주세요')
        return False
 
    # 연결 여부 체크
    if (g_objCpStatus.IsConnect == 0):
        print("PLUS가 정상적으로 연결되지 않음. ")
        return False
 
    # # 주문 관련 초기화
    # if (g_objCpTrade.TradeInit(0) != 0):
    #     print("주문 초기화 실패")
    #     return False
 
    return True
 
 
################################################
# CpEvent: 실시간 이벤트 수신 클래스
class CpEvent:
    def set_params(self, client, name, caller):
        self.client = client  # CP 실시간 통신 object
        self.name = name  # 서비스가 다른 이벤트를 구분하기 위한 이름
        self.caller = caller  # callback 을 위해 보관
 
    def OnReceived(self):
        # 실시간 처리 - 현재가 주문 체결
        if self.name == 'stockcur':
            code = self.client.GetHeaderValue(0)  # 초
            name = self.client.GetHeaderValue(1)  # 초
            timess = self.client.GetHeaderValue(18)  # 초
            exFlag = self.client.GetHeaderValue(19)  # 예상체결 플래그
            cprice = self.client.GetHeaderValue(13)  # 현재가
            diff = self.client.GetHeaderValue(2)  # 대비
            cVol = self.client.GetHeaderValue(17)  # 순간체결수량
            vol = self.client.GetHeaderValue(9)  # 거래량
 
            if exFlag != ord('2'):
                return
 
            item = {}
            item['code'] = code
            item['time'] = timess
            item['diff'] = diff
            item['cur'] = cprice
            item['vol'] = vol
 
            # 현재가 업데이트
            self.caller.updateCurData(item)
 
 
            return
 
 
################################################
# plus 실시간 수신 base 클래스
class CpPublish:
    def __init__(self, name, serviceID):
        self.name = name
        self.obj = win32com.client.Dispatch(serviceID)
        self.bIsSB = False
 
    def Subscribe(self, var, caller):
        if self.bIsSB:
            self.Unsubscribe()
 
        if (len(var) > 0):
            self.obj.SetInputValue(0, var)
 
        handler = win32com.client.WithEvents(self.obj, CpEvent)
        handler.set_params(self.obj, self.name, caller)
        self.obj.Subscribe()
        self.bIsSB = True
 
    def Unsubscribe(self):
        if self.bIsSB:
            self.obj.Unsubscribe()
        self.bIsSB = False
 
 
################################################
# CpPBStockCur: 실시간 현재가 요청 클래스
class CpPBStockCur(CpPublish):
    def __init__(self):
        super().__init__('stockcur', 'DsCbo1.StockCur')
 
 
class CMinchartData:
    def __init__(self):
        self.minDatas = {}
        self.objCur = {}
 
    def stop(self):
        for k,v in self.objCur.items() :
            v.Unsubscribe()
 
 
    def addCode(self, code):
        if (code in self.minDatas) :
            return
 
        self.minDatas[code] = []
        self.objCur[code] = CpPBStockCur()
        self.objCur[code].Subscribe(code, self)
 
 
 
    def updateCurData(self, item):
        code = item['code']
        time  = item['time']
        cur = item['cur']
        self.makeMinchart(code, time, cur)
 
 
    def makeMinchart(self, code, time, cur) :
        hh, mm = divmod(time, 10000)
        mm, tt = divmod(mm, 100)
        mm += 1
        if (mm == 60) :
            hh += 1
            mm = 0
 
        hhmm = hh * 100 + mm
        if hhmm > 1530 :
            hhmm = 1530
        bFind = False
        minlen =len(self.minDatas[code])
        if (minlen > 0) :
            # 0 : 시간 1 : 시가 2: 고가 3: 저가 4: 종가
            if (self.minDatas[code][-1][0] == hhmm) :
                item = self.minDatas[code][-1]
                bFind = True
                item[4] = cur
                if (item[2] < cur):
                    item[2] = cur
                if (item[3] > cur):
                    item[3] = cur
 
        if bFind ==  False :
            self.minDatas[code].append([hhmm, cur, cur, cur, cur])
 
#        print(code, self.minDatas[code])
        return
 
    def print(self, code):
        print('====================================================-')
        print('분데이터 print', code, g_objCodeMgr.CodeToName(code))
        print('시간,시가,고가,저가,종가')
        for item in self.minDatas[code] :
            hh, mm = divmod(item[0], 100)
            print("%02d:%02d,%d,%d,%d,%d" %(hh, mm, item[1], item[2], item[3], item[4]))
 
 
 
# print(code, self.minDatas[code])
 
 
 
################################################
# 테스트를 위한 메인 화면
class MyWindow(QMainWindow):
    def __init__(self):
        super().__init__()
 
        # plus 상태 체크
        if InitPlusCheck() == False:
            exit()
 
        self.minData = CMinchartData()
 
        # 코스피 200 종목 가져와 추가
        self.codelist = g_objCodeMgr.GetGroupCodeList(180)
        for code in self.codelist :
            print(code, g_objCodeMgr.CodeToName(code))
            self.minData.addCode(code)
 
 
        self.setWindowTitle("주식 분 차트 생성")
        self.setGeometry(300, 300, 300, 180)
 
        nH  = 20
 
        btnPrint = QPushButton('print', self)
        btnPrint.move(20, nH)
        btnPrint.clicked.connect(self.btnPrint_clicked)
        nH += 50
 
 
        btnExit = QPushButton('종료', self)
        btnExit.move(20, nH)
        btnExit.clicked.connect(self.btnExit_clicked)
        nH += 50
 
 
    def btnPrint_clicked(self):
        for i in range(len(self.codelist)):
            self.minData.print(self.codelist[i])
            if i > 10: break
        return
 
 
    def btnExit_clicked(self):
        self.minData.stop()
        exit()
        return
 
 
 
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exec_()
# Out:
# 정상: 관리자권한으로 실행된 프로세스입니다.
# A282330 BGF리테일
# A138930 BNK금융지주
# A001040 CJ
# A000120 CJ대한통운
# A097950 CJ제일제당
# A005830 DB손해보험
# A000990 DB하이텍
# A139130 DGB금융지주
# A000210 DL
# A375500 DL이앤씨
# A383220 F&F
# A114090 GKL
# A078930 GS
# A006360 GS건설
# A007070 GS리테일
# A294870 HDC현대산업개발
# A009540 HD한국조선해양
# A267250 HD현대
# A042670 HD현대인프라코어
# A329180 HD현대중공업
# A204320 HL만도
# A011200 HMM
# A175330 JB금융지주
# A105560 KB금융
# A002380 KCC
# A016380 KG스틸
# A030200 KT
# A033780 KT&G
# A003550 LG
# A034220 LG디스플레이
# A051900 LG생활건강
# A373220 LG에너지솔루션
# A032640 LG유플러스
# A011070 LG이노텍
# A066570 LG전자
# A051910 LG화학
# A079550 LIG넥스원
# A006260 LS
# A010120 LS ELECTRIC
# A001120 LX인터내셔널
# A035420 NAVER
# A005940 NH투자증권
# A010060 OCI홀딩스
# A178920 PI첨단소재
# A005490 POSCO홀딩스
# A010950 S-Oil
# A034730 SK
# A011790 SKC
# A001740 SK네트웍스
# A302440 SK바이오사이언스
# A326030 SK바이오팜
# A402340 SK스퀘어
# A361610 SK아이이테크놀로지
# A096770 SK이노베이션
# A285130 SK케미칼
# A017670 SK텔레콤
# A000660 SK하이닉스
# A069260 TKG휴켐스
# A035250 강원랜드
# A010130 고려아연
# A001570 금양
# A011780 금호석유
# A073240 금호타이어
# A000270 기아
# A024110 기업은행
# A251270 넷마블
# A006280 녹십자
# A005250 녹십자홀딩스
# A004370 농심
# A001680 대상
# A047040 대우건설
# A003090 대웅
# A069620 대웅제약
# A006650 대한유화
# A001440 대한전선
# A003490 대한항공
# A192080 더블유게임즈
# A026960 동서
# A014820 동원시스템즈
# A000150 두산
# A241560 두산밥캣
# A034020 두산에너빌리티
# A336260 두산퓨얼셀
# A032350 롯데관광개발
# A023530 롯데쇼핑
# A020150 롯데에너지머티리얼즈
# A280360 롯데웰푸드
# A004000 롯데정밀화학
# A004990 롯데지주
# A005300 롯데칠성
# A011170 롯데케미칼
# A138040 메리츠금융지주
# A009900 명신산업
# A006800 미래에셋증권
# A003850 보령
# A006400 삼성SDI
# A028260 삼성물산
# A207940 삼성바이오로직스
# A032830 삼성생명
# A018260 삼성에스디에스
# A028050 삼성엔지니어링
# A009150 삼성전기
# A005930 삼성전자
# A010140 삼성중공업
# A016360 삼성증권
# A029780 삼성카드
# A000810 삼성화재
# A003230 삼양식품
# A004490 세방전지
# A068270 셀트리온
# A004170 신세계
# A031430 신세계인터내셔날
# A019170 신풍제약
# A055550 신한지주
# A003410 쌍용C&E
# A112610 씨에스윈드
# A002790 아모레G
# A090430 아모레퍼시픽
# A020560 아시아나항공
# A010780 아이에스동서
# A137310 에스디바이오센서
# A005850 에스엘
# A012750 에스원
# A036570 엔씨소프트
# A111770 영원무역
# A000670 영풍
# A007310 오뚜기
# A271560 오리온
# A001800 오리온홀딩스
# A316140 우리금융지주
# A000100 유한양행
# A008730 율촌화학
# A139480 이마트
# A271940 일진하이솔루스
# A030000 제일기획
# A185750 종근당
# A013890 지누스
# A035720 카카오
# A323410 카카오뱅크
# A377300 카카오페이
# A381970 케이카
# A192820 코스맥스
# A005420 코스모화학
# A120110 코오롱인더
# A021240 코웨이
# A284740 쿠쿠홈시스
# A259960 크래프톤
# A039490 키움증권
# A003240 태광산업
# A028670 팬오션
# A047050 포스코인터내셔널
# A003670 포스코퓨처엠
# A103140 풍산
# A086790 하나금융지주
# A039130 하나투어
# A352820 하이브
# A000080 하이트진로
# A036460 한국가스공사
# A071050 한국금융지주
# A000240 한국앤컴퍼니
# A015760 한국전력
# A161890 한국콜마
# A161390 한국타이어앤테크놀로지
# A047810 한국항공우주
# A008930 한미사이언스
# A128940 한미약품
# A009240 한샘
# A020000 한섬
# A105630 한세실업
# A014680 한솔케미칼
# A018880 한온시스템
# A009420 한올바이오파마
# A300720 한일시멘트
# A051600 한전KPS
# A052690 한전기술
# A180640 한진칼
# A000880 한화
# A088350 한화생명
# A009830 한화솔루션
# A272210 한화시스템
# A012450 한화에어로스페이스
# A042660 한화오션
# A000720 현대건설
# A086280 현대글로비스
# A064350 현대로템
# A012330 현대모비스
# A010620 현대미포조선
# A069960 현대백화점
# A017800 현대엘리베이
# A011210 현대위아
# A004020 현대제철
# A005380 현대차
# A001450 현대해상
# A057050 현대홈쇼핑
# A008770 호텔신라
# A004800 효성
# A298050 효성첨단소재
# A298020 효성티앤씨
# A093370 후성
# A081660 휠라홀딩스
# ====================================================-
# 분데이터 print A282330 BGF리테일
# 시간,시가,고가,저가,종가
# 14:43,170300,170300,170300,170300
# ====================================================-
# 분데이터 print A138930 BNK금융지주
# 시간,시가,고가,저가,종가
# ====================================================-
# 분데이터 print A001040 CJ
# 시간,시가,고가,저가,종가
# 14:43,65400,65400,65300,65300
# ====================================================-
# 분데이터 print A000120 CJ대한통운
# 시간,시가,고가,저가,종가
# 14:43,76000,76000,76000,76000
# ====================================================-
# 분데이터 print A097950 CJ제일제당
# 시간,시가,고가,저가,종가
# 14:43,277500,277500,277500,277500
# ====================================================-
# 분데이터 print A005830 DB손해보험
# 시간,시가,고가,저가,종가
# 14:43,72900,72900,72800,72800
# ====================================================-
# 분데이터 print A000990 DB하이텍
# 시간,시가,고가,저가,종가
# 14:43,62400,62400,62400,62400
# ====================================================-
# 분데이터 print A139130 DGB금융지주
# 시간,시가,고가,저가,종가
# 14:43,7490,7490,7480,7480
# ====================================================-
# 분데이터 print A000210 DL
# 시간,시가,고가,저가,종가
# 14:43,39000,39100,38950,39100
# ====================================================-
# 분데이터 print A375500 DL이앤씨
# 시간,시가,고가,저가,종가
# 14:43,34050,34050,34050,34050
# ====================================================-
# 분데이터 print A383220 F&F
# 시간,시가,고가,저가,종가
# 14:43,121200,121200,121100,121100
# ====================================================-
# 분데이터 print A114090 GKL
# 시간,시가,고가,저가,종가
# 14:43,15210,15210,15200,15200
