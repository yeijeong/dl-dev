# %% [markdown]
# ##### 참고 url : https://github.com/FinanceData/OpenDartReader
# pip install opendartreader

# %%
import OpenDartReader

### 0. 객체 생성 ###
# 객체 생성 (API KEY 지정) 
api_key = '3d218f72d3a558aa85ff91f2a0f2d720e3158223'

dart = OpenDartReader(api_key)

# %% [markdown]
# ### 1. 공시정보 ###

# %%
# 특정기업(삼성전자) 상장이후 모든 공시 목록 (5,600 건+)
dart.list('삼성전자') # 기업이름 혹은,
dart.list('005930') # 종목코드를 사용할 수 있습니다.

# 특정기업(삼성전자) 특정 날짜 이후 공시목록 (날짜에 다양한 포맷이 가능합니다 2022, '2022-01-01', '20220101' )
dart.list('삼성전자', start='2022-01-01') # 2022-01-01 ~ 오늘
dart.list('005930', start='2022-01-01') # 2022-01-01 ~ 오늘

# 특정기업(삼성전자) 특정 일자 범위(start~end)의 공시목록 (날짜에 다양한 포맷이 가능합니다)
dart.list('005930', start='2022-04-28', end='2022-04-28')

# 특정기업(삼성전자) 1999년~이후 모든 정기보고서 (정정된 공시포함)
dart.list('005930', start='1999-01-01', kind='A', final=False)

# 특정기업(삼성전자) 1999년~이후 모든 정기보고서 (최종보고서)
dart.list('005930', start='1999-01-01', kind='A') 

# 2022-07-01 하루동안 모든 기업의 공시목록
dart.list(start='20200701', end='20200701')

# 2022-01-01 ~ 2022-01-10 모든 회사의 모든 공시목록 (3,139 건)
dart.list(start='2022-01-01', end='2022-01-10')

# 2022-01-01 ~ 2022-01-10 모든 회사의 모든 공시목록 (정정된 공시포함) (3,587 건)
dart.list(start='2022-01-01', end='2022-01-10', final=False)

# 2022-01-01~2022-03-30 모든 회사의 정기보고서 (corp를 특정 하지 않으면 최대 3개월) (2,352 건)
dart.list(start='2022-01-01', end='2022-03-30', kind='A')
# Out:
#      corp_code  corp_name stock_code corp_cls              report_nm  \
# 0     01309209  더블다운인터액티브                   E  [첨부추가]사업보고서 (2021.12)
# 1     01011562      우성아이비     194610        E  [첨부추가]사업보고서 (2021.12)
# 2     00463449      더존홀딩스                   E  [첨부추가]사업보고서 (2021.12)
# 3     00362885     에스텍시스템                   E  [첨부추가]사업보고서 (2021.12)
# 4     00259934        예림당     036000        K        사업보고서 (2021.12)
# ...        ...        ...        ...      ...                    ...
# 2283  00209443    우리금융캐피탈     033660        E  [기재정정]사업보고서 (2020.12)
# 2284  00201432      비츠로시스     054220        K  [기재정정]반기보고서 (2021.09)
# 2285  00171636      한솔홀딩스     004150        Y  [기재정정]분기보고서 (2021.09)
# 2286  00109781       대림제지     017650        K  [기재정정]사업보고서 (2019.12)
# 2287  00109781       대림제지     017650        K  [기재정정]사업보고서 (2016.12)
#
#             rcept_no     flr_nm  rcept_dt rm
# 0     20220330000909  더블다운인터액티브  20220330  연
# 1     20220328000568      우성아이비  20220328  연
# 2     20220328000811      더존홀딩스  20220328  연
# 3     20220330000029     에스텍시스템  20220330  연
# 4     20220330001786        예림당  20220330  연
# ...              ...        ...       ... ..
# 2283  20220111000355    우리금융캐피탈  20220111  연
# 2284  20220106000470      비츠로시스  20220106
# 2285  20220106000434      한솔홀딩스  20220106
# 2286  20220103000285       대림제지  20220103
# 2287  20220103000219       대림제지  20220103
#
# [2288 rows x 9 columns]

# %% [markdown]
# ##### 1. 예시

# %%
dart.list('005930', start='2022-01-01')
# Out:
#     corp_code corp_name stock_code corp_cls                  report_nm  \
# 0    00126380      삼성전자     005930        Y  [기재정정]임원ㆍ주요주주특정증권등소유상황보고서
# 1    00126380      삼성전자     005930        Y             최대주주등소유주식변동신고서
# 2    00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 3    00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 4    00126380      삼성전자     005930        Y                기업지배구조보고서공시
# ..        ...       ...        ...      ...                        ...
# 308  00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 309  00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 310  00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 311  00126380      삼성전자     005930        Y          기업설명회(IR)개최(안내공시)
# 312  00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
#
#            rcept_no          flr_nm  rcept_dt rm
# 0    20230608000326              이혁  20230608
# 1    20230605800255            삼성전자  20230605  유
# 2    20230601000073  SONG SANG CHUL  20230601
# 3    20230601000004  SONG SANG CHUL  20230601
# 4    20230531800731            삼성전자  20230531  유
# ..              ...             ...       ... ..
# 308  20220111000233             김용주  20220111
# 309  20220110000025             정진민  20220110
# 310  20220107000644             고정욱  20220107
# 311  20220107800039            삼성전자  20220107  유
# 312  20220103000348             박찬훈  20220103
#
# [313 rows x 9 columns]

# %%
dart.list(start='2022-01-01', end='2022-01-10')
# Out:
#      corp_code              corp_name stock_code corp_cls  \
# 0     01578067      뉴스타해피제삼차유동화전문유한회사                   E
# 1     00498162               한국주택금융공사                   E
# 2     00419484           현대인베스트먼트자산운용                   E
# 3     01606351  도이치파이낸셜오토제오차유동화전문유한회사                   E
# 4     01606351  도이치파이낸셜오토제오차유동화전문유한회사                   E
# ...        ...                    ...        ...      ...
# 3061  00324548               한국투자신탁운용                   E
# 3062  00324548               한국투자신탁운용                   E
# 3063  00860794          디비씨앤에스자동차손해사정                   E
# 3064  00860794          디비씨앤에스자동차손해사정                   E
# 3065  00860794          디비씨앤에스자동차손해사정                   E
#
#                                           report_nm        rcept_no  \
# 0                                       자산양도등의등록신청서  20220110000065
# 1                             채권양도등의등록신청서[한국주택금융공사]  20220106000367
# 2     일괄신고서(집합투자증권-신탁형)(현대인베스트먼트코리아ESG증권투자신탁1호(채권))  20220105000105
# 3                            자산유동화계획의등록신청서(유동화전문회사)  20220105000521
# 4                     자산유동화계획의등록신청서[신탁회사(은행신탁계정포함)]  20220105000445
# ...                                             ...             ...
# 3061     효력발생안내( 2021.12.30. 제출 일괄신고서(집합투자증권-신탁형) )  20211231100015
# 3062     효력발생안내( 2021.12.30. 제출 일괄신고서(집합투자증권-신탁형) )  20211231100014
# 3063                                 특수관계인으로부터부동산임차  20211231000498
# 3064                                 특수관계인으로부터부동산임차  20211231000497
# 3065                                    특수관계인과의내부거래  20211231000496
#
#                      flr_nm  rcept_dt rm
# 0                        다날  20220110
# 1                  한국주택금융공사  20220106
# 2              현대인베스트먼트자산운용  20220105
# 3     도이치파이낸셜오토제오차유동화전문유한회사  20220105
# 4                      수협은행  20220105
# ...                     ...       ... ..
# 3061                  금융감독원  20220103
# 3062                  금융감독원  20220103
# 3063          디비씨앤에스자동차손해사정  20220103  공
# 3064          디비씨앤에스자동차손해사정  20220103  공
# 3065          디비씨앤에스자동차손해사정  20220103  공
#
# [3066 rows x 9 columns]

# %% [markdown]
# #### ==== 1-2. 공시정보 - 기업개황 ====

# %%
# 기업의 개황정보
dart.company('005930')

# 회사명에 "삼성전자"가 포함된 회사들에 대한 개황정보
dart.company_by_name('삼성전자')

# ==== 1-2. 공시정보 - 기업개황 ====
# 기업의 개황정보
dart.company('005930')

# 회사명에 "삼성전자"가 포함된 회사들에 대한 개황정보
dart.company_by_name('삼성전자')
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00258999',
#   'corp_name': '삼성전자 서비스주식회사',
#   'corp_name_eng': 'SAMSUNNG ELECTRONICS SERVICE CO., LTD',
#   'stock_name': '삼성전자서비스',
#   'stock_code': '',
#   'ceo_nm': '송봉섭',
#   'corp_cls': 'E',
#   'jurir_no': '1301110049139',
#   'bizr_no': '1248158485',
#   'adres': '경기도 수원시 영통구 삼성로 290 (원천동)',
#   'hm_url': 'www.samsungsvc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-2177',
#   'fax_no': '031-270-2106',
#   'induty_code': '95',
#   'est_dt': '19981027',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01345812',
#   'corp_name': '삼성전자서비스씨에스 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SERVICE CUSTOMER SATISFACTION., LTD.',
#   'stock_name': '삼성전자서비스씨에스',
#   'stock_code': '',
#   'ceo_nm': '이명옥',
#   'corp_cls': 'E',
#   'jurir_no': '1358110352541',
#   'bizr_no': '7898701103',
#   'adres': '경기도 수원시 영통구 중부대로 324 (매탄동, KT동수원지사)',
#   'hm_url': '',
#   'ir_url': '',
#   'phn_no': '031-210-8914',
#   'fax_no': '031-8006-1009',
#   'induty_code': '75991',
#   'est_dt': '20181105',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00252074',
#   'corp_name': '삼성전자판매 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SALES Co., Ltd.',
#   'stock_name': '삼성전자판매',
#   'stock_code': '',
#   'ceo_nm': '이평우',
#   'corp_cls': 'E',
#   'jurir_no': '1801110210300',
#   'bizr_no': '6178117517',
#   'adres': '경기도 성남시 분당구 황새울로 340',
#   'hm_url': 'www.samsungsales.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3460-6656',
#   'fax_no': '02-3460-6802',
#   'induty_code': '47320',
#   'est_dt': '19960711',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00126380',
#   'corp_name': '삼성전자(주)',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#   'stock_name': '삼성전자',
#   'stock_code': '005930',
#   'ceo_nm': '한종희, 경계현',
#   'corp_cls': 'Y',
#   'jurir_no': '1301110006246',
#   'bizr_no': '1248100998',
#   'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#   'hm_url': 'www.samsung.com/sec',
#   'ir_url': '',
#   'phn_no': '02-2255-0114',
#   'fax_no': '031-200-7538',
#   'induty_code': '264',
#   'est_dt': '19690113',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00366997',
#   'corp_name': '삼성전자로지텍(주)',
#   'corp_name_eng': 'SELC.CO.,LTD',
#   'stock_name': '삼성전자로지텍',
#   'stock_code': '',
#   'ceo_nm': '최윤범',
#   'corp_cls': 'E',
#   'jurir_no': '1301110046797',
#   'bizr_no': '1248155381',
#   'adres': '경기도 수원시 영통구 삼성로 129',
#   'hm_url': 'www.selc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-3488',
#   'fax_no': '031-270-3673',
#   'induty_code': '52999',
#   'est_dt': '19980401',
#   'acc_mt': '12'}]

# %% [markdown]
# ##### 1-2. 예시

# %%
dart.company_by_name('삼성전자')
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00258999',
#   'corp_name': '삼성전자 서비스주식회사',
#   'corp_name_eng': 'SAMSUNNG ELECTRONICS SERVICE CO., LTD',
#   'stock_name': '삼성전자서비스',
#   'stock_code': '',
#   'ceo_nm': '송봉섭',
#   'corp_cls': 'E',
#   'jurir_no': '1301110049139',
#   'bizr_no': '1248158485',
#   'adres': '경기도 수원시 영통구 삼성로 290 (원천동)',
#   'hm_url': 'www.samsungsvc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-2177',
#   'fax_no': '031-270-2106',
#   'induty_code': '95',
#   'est_dt': '19981027',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01345812',
#   'corp_name': '삼성전자서비스씨에스 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SERVICE CUSTOMER SATISFACTION., LTD.',
#   'stock_name': '삼성전자서비스씨에스',
#   'stock_code': '',
#   'ceo_nm': '이명옥',
#   'corp_cls': 'E',
#   'jurir_no': '1358110352541',
#   'bizr_no': '7898701103',
#   'adres': '경기도 수원시 영통구 중부대로 324 (매탄동, KT동수원지사)',
#   'hm_url': '',
#   'ir_url': '',
#   'phn_no': '031-210-8914',
#   'fax_no': '031-8006-1009',
#   'induty_code': '75991',
#   'est_dt': '20181105',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00252074',
#   'corp_name': '삼성전자판매 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SALES Co., Ltd.',
#   'stock_name': '삼성전자판매',
#   'stock_code': '',
#   'ceo_nm': '이평우',
#   'corp_cls': 'E',
#   'jurir_no': '1801110210300',
#   'bizr_no': '6178117517',
#   'adres': '경기도 성남시 분당구 황새울로 340',
#   'hm_url': 'www.samsungsales.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3460-6656',
#   'fax_no': '02-3460-6802',
#   'induty_code': '47320',
#   'est_dt': '19960711',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00126380',
#   'corp_name': '삼성전자(주)',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#   'stock_name': '삼성전자',
#   'stock_code': '005930',
#   'ceo_nm': '한종희, 경계현',
#   'corp_cls': 'Y',
#   'jurir_no': '1301110006246',
#   'bizr_no': '1248100998',
#   'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#   'hm_url': 'www.samsung.com/sec',
#   'ir_url': '',
#   'phn_no': '02-2255-0114',
#   'fax_no': '031-200-7538',
#   'induty_code': '264',
#   'est_dt': '19690113',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00366997',
#   'corp_name': '삼성전자로지텍(주)',
#   'corp_name_eng': 'SELC.CO.,LTD',
#   'stock_name': '삼성전자로지텍',
#   'stock_code': '',
#   'ceo_nm': '최윤범',
#   'corp_cls': 'E',
#   'jurir_no': '1301110046797',
#   'bizr_no': '1248155381',
#   'adres': '경기도 수원시 영통구 삼성로 129',
#   'hm_url': 'www.selc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-3488',
#   'fax_no': '031-270-3673',
#   'induty_code': '52999',
#   'est_dt': '19980401',
#   'acc_mt': '12'}]

# %% [markdown]
# #### ==== 1-3. 공시정보 - 공시서류원본파일 ====

# %%
# 삼성전자 사업보고서 (2022년 반기사업보고서) 원문 텍스트
xml_text = dart.document('20220816001711')

# ==== 1-3. 공시정보 - 공시서류원본파일 전체 리스트 (사업보고서, 감사보고서) ====
# 삼성전자 사업보고서 (2022년 반기사업보고서) 원문 텍스트, 감사보고서
xml_text_list = dart.document_all('20220816001711')
xml_text = xml_text_list[0]

# %% [markdown]
# #### ==== 1-4. 공시정보 - 고유번호 ====

# %%
# 종목코드로 고유번호 얻기
dart.find_corp_code('005930')

# 기업명으로 고유번호 얻기
dart.find_corp_code('삼성전자')
# Out:
# '00126380'

# %% [markdown]
# ### 2. 사업보고서 ###

# %%
# 조회가능한 사업보고서의 항목: 
['조건부자본증권미상환', '미등기임원보수', '회사채미상환', '단기사채미상환', '기업어음미상환', '채무증권발행', '사모자금사용', '공모자금사용', '임원전체보수승인', '임원전체보수유형', '주식총수', '회계감사', '감사용역', '회계감사용역계약', '사외이사', '신종자본증권미상환', '증자', '배당', '자기주식', '최대주주', '최대주주변동', '소액주주', '임원', '직원', '임원개인보수', '임원전체보수', '개인별보수', '타법인출자']

dart.report('005930', '미등기임원보수', 2021)  # 미등기임원 보수현황
dart.report('005930', '증자', 2021) # 증자(감자) 현황
dart.report('005930', '배당', 2018)  # 배당에 관한 사항
# Out:
#           rcept_no corp_cls corp_code corp_name              se      thstrm  \
# 0   20190401004781        Y  00126380      삼성전자       주당액면가액(원)         100
# 1   20190401004781        Y  00126380      삼성전자  (연결)당기순이익(백만원)  43,890,877
# 2   20190401004781        Y  00126380      삼성전자  (별도)당기순이익(백만원)  32,815,127
# 3   20190401004781        Y  00126380      삼성전자    (연결)주당순이익(원)       6,461
# 4   20190401004781        Y  00126380      삼성전자    현금배당금총액(백만원)   9,619,243
# 5   20190401004781        Y  00126380      삼성전자    주식배당금총액(백만원)           -
# 6   20190401004781        Y  00126380      삼성전자   (연결)현금배당성향(%)       21.90
# 7   20190401004781        Y  00126380      삼성전자      현금배당수익률(%)        3.70
# 8   20190401004781        Y  00126380      삼성전자      현금배당수익률(%)        4.50
# 9   20190401004781        Y  00126380      삼성전자      주식배당수익률(%)           -
# 10  20190401004781        Y  00126380      삼성전자      주식배당수익률(%)           -
# 11  20190401004781        Y  00126380      삼성전자     주당 현금배당금(원)       1,416
# 12  20190401004781        Y  00126380      삼성전자     주당 현금배당금(원)       1,417
# 13  20190401004781        Y  00126380      삼성전자      주당 주식배당(주)           -
# 14  20190401004781        Y  00126380      삼성전자      주당 주식배당(주)           -
#
#         frmtrm        lwfr stock_knd
# 0        5,000       5,000       NaN
# 1   41,344,569  22,415,655       NaN
# 2   28,800,837  11,579,749       NaN
# 3      299,868     157,967       NaN
# 4    5,826,302   3,991,892       NaN
# 5            -           -       NaN
# 6        14.10       17.80       NaN
# 7         1.70        1.60       보통주
# 8         2.10        2.00       우선주
# 9            -           -       보통주
# 10           -           -       우선주
# 11      42,500      28,500       보통주
# 12      42,550      28,550       우선주
# 13           -           -       보통주
# 14           -           -       우선주

# %% [markdown]
# ### 3. 상장기업 재무정보 ###

# %%
# 상장법인(금융업 제외)의 주요계정과목(재무상태표, 손익계산서)

# 삼성전자 2021 재무제표 
dart.finstate('삼성전자', 2021) 

# 삼성전자 2021Q1 재무제표
dart.finstate('삼성전자', 2021, reprt_code='11013')

# 여러 상장법인(금융업 제외)의 주요계정과목(재무상태표, 손익계산서)
dart.finstate('00126380,00164779,00164742', 2021)
dart.finstate('005930, 000660, 005380', 2021)
dart.finstate('삼성전자, SK하이닉스, 현대자동차', 2021)

# 재무제표 XBRL 원본 파일 저장 (삼성전자 2021 사업보고서)
dart.finstate_xml('20220308000798', save_as='삼성전자_2021_사업보고서_XBRL.zip')

# 전체 재무제표 (삼성전자 2021 전체 재무제표)
dart.finstate_all('005930', 2021)

# XBRL 표준계정과목체계(계정과목)
dart.xbrl_taxonomy('BS1')
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
#     sj_div   bsns_de                                         account_id  \
# 0      BS1  20180701          ifrs_StatementOfFinancialPositionAbstract
# 1      BS1  20180701                                ifrs_AssetsAbstract
# 2      BS1  20180701                                 ifrs_CurrentAssets
# 3      BS1  20180701                        ifrs_CashAndCashEquivalents
# 4      BS1  20180701                                          ifrs_Cash
# ..     ...       ...                                                ...
# 514    BS1  20180701                             dart_VoluntaryReserves
# 515    BS1  20180701  dart_RetainedEarningsBeforeAppropriationsAccum...
# 516    BS1  20180701                       ifrs_NoncontrollingInterests
# 517    BS1  20180701                                        ifrs_Equity
# 518    BS1  20180701                          ifrs_EquityAndLiabilities
#
#                                             account_nm         label_kor  \
# 0                 StatementOfFinancialPositionAbstract  재무상태표 [abstract]
# 1                                       AssetsAbstract     자산 [abstract]
# 2                                        CurrentAssets              유동자산
# 3                               CashAndCashEquivalents          현금및현금성자산
# 4                                                 Cash                현금
# ..                                                 ...               ...
# 514                                  VoluntaryReserves             임의적립금
# 515  RetainedEarningsBeforeAppropriationsAccumulate...  미처분이익잉여금(미처리결손금)
# 516                            NoncontrollingInterests             비지배지분
# 517                                             Equity              자본총계
# 518                               EquityAndLiabilities           자본과부채총계
#
#                                              label_eng  \
# 0           Statement of financial position [abstract]
# 1                                    Assets [abstract]
# 2                                       Current assets
# 3                            Cash and cash equivalents
# 4                                                 Cash
# ..                                                 ...
# 514                                 Voluntary Reserves
# 515  Retained earnings before appropriations(accumu...
# 516                          Non-controlling interests
# 517                                       Total equity
# 518                       Total equity and liabilities
#
#                                               ifrs_ref data_tp
# 0                                                          NaN
# 1                                                          NaN
# 2                                    K-IFRS 1001 문단 60       X
# 3              K-IFRS 1001 문단 54 (9),K-IFRS 1007 문단 45       X
# 4              K-IFRS 1001 문단 54 (9),K-IFRS 1007 문단 45       X
# ..                                                 ...     ...
# 514  K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K...       X
# 515  K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K...       X
# 516                             K-IFRS 1001 문단 54 (17)       X
# 517                                                        NaN
# 518                                                        NaN
#
# [519 rows x 8 columns]

# %% [markdown]
# ### 4. 지분공시 ###

# %%
# 대량보유 상황보고 (종목코드, 종목명, 고유번호 모두 지정 가능)
dart.major_shareholders('삼성전자')

# 임원ㆍ주요주주 소유보고 (종목코드, 종목명, 고유번호 모두 지정 가능)
dart.major_shareholders_exec('005930')
# Out:
#            rcept_no    rcept_dt corp_code corp_name          repror  \
# 0    20210624000396  2021-06-24  00126380      삼성전자             최주호
# 1    20210629000122  2021-06-29  00126380      삼성전자             박창진
# 2    20210629000190  2021-06-29  00126380      삼성전자             안규리
# 3    20210723000157  2021-07-23  00126380      삼성전자             김강수
# 4    20210730000206  2021-07-30  00126380      삼성전자             안규리
# ..              ...         ...       ...       ...             ...
# 206  20230406002362  2023-04-06  00126380      삼성전자             김이태
# 207  20230412002146  2023-04-12  00126380      삼성전자             김이태
# 208  20230601000004  2023-06-01  00126380      삼성전자  SONG SANG CHUL
# 209  20230601000073  2023-06-01  00126380      삼성전자  SONG SANG CHUL
# 210  20230608000326  2023-06-08  00126380      삼성전자              이혁
#
#     isu_exctv_rgist_at isu_exctv_ofcps isu_main_shrholdr sp_stock_lmp_cnt  \
# 0                비등기임원             부사장                 -                0
# 1                비등기임원              상무                 -              500
# 2                 등기임원            사외이사                 -            3,200
# 3                비등기임원              상무                 -            1,500
# 4                 등기임원            사외이사                 -            3,300
# ..                 ...             ...               ...              ...
# 206              비등기임원             부사장                 -            1,800
# 207              비등기임원             부사장                 -                0
# 208              비등기임원              상무                 -            1,000
# 209              비등기임원              상무                 -              500
# 210              비등기임원              상무                 -               70
#
#     sp_stock_lmp_irds_cnt sp_stock_lmp_rate sp_stock_lmp_irds_rate
# 0                  -4,600              0.00                   0.00
# 1                     500              0.00                   0.00
# 2                     100              0.00                   0.00
# 3                     500              0.00                   0.00
# 4                     100              0.00                   0.00
# ..                    ...               ...                    ...
# 206                 1,800              0.00                   0.00
# 207                -1,800                 0                  -0.00
# 208                 1,000              0.00                   0.00
# 209                  -500              0.00                   0.00
# 210                    70              0.00                   0.00
#
# [211 rows x 12 columns]

# %% [markdown]
# ### 5. 주요사항보고서  ###

# %%
# dart.event(corp, event, start=None, end=None)
# 조회가능한 주요사항 항목: 
# ['부도발생', '영업정지', '회생절차', '해산사유', '유상증자', '무상증자', '유무상증자', '감자', '관리절차개시', '소송', '해외상장결정', '해외상장폐지결정', '해외상장', '해외상장폐지', '전환사채발행', '신주인수권부사채발행', '교환사채발행', '관리절차중단', '조건부자본증권발행', '자산양수도', '타법인증권양도', '유형자산양도', '유형자산양수', '타법인증권양수', '영업양도', '영업양수', '자기주식취득신탁계약해지', '자기주식취득신탁계약체결', '자기주식처분', '자기주식취득', '주식교환', '회사분할합병', '회사분할', '회사합병', '사채권양수', '사채권양도결정']

dart.event('052220', '영업정지', '2019') # iMBC(052220)
dart.event('라이트론', '회생절차', '2019') # 라이트론(069540)
dart.event('휴림네트웍스', '유상증자') # 휴림네트웍스(192410)
dart.event('미원상사', '무상증자') # 미원상사(084990)
dart.event('017810', '전환사채발행') # 풀무원(017810)
dart.event('키다리스튜디오', '신주인수권부사채발행') #  키다리스튜디오(020120) 
dart.event('이스트소프트', '교환사채발행') # 이스트소프트(047560)
# Out:
#          rcept_no corp_cls corp_code corp_name           bddd od_a_at_t  \
# 0  20191212000301        K  00273420    이스트소프트  2019년 12월 10일         3
# 1  20230210000461        K  00273420    이스트소프트  2023년 02월 10일         1
#
#   od_a_at_b adt_a_atn fdpp_fclt fdpp_bsninh  ...  \
# 0         -        참석         -           -  ...
# 1         -        참석         -           -  ...
#
#                                              ex_sm_r ovis_ltdtl ex_rt  ex_prc  \
# 0               사모발행으로 증권신고서 제출면제 (발행 후 1년간 권면분할 금지)          -   100   5,080
# 1  본 사채는 발행회사의 동의없이 제3자에게 전매될 수 있으나, 발행일로부터 1년 이내...          -   100  14,500
#
#                                          ex_prc_dmth                 extg  \
# 0  교환대상 주식1주로 교환되는 가격(이하 "교환가격”이라 함)은 본 사채 발행을 위한...       줌인터넷 주식회사 보통주식
# 1  본 사채 발행을 위한 이사회 결의일 전일로부터 소급한 교환대상 주식의 1개월 거래량...  주식회사 이스트소프트 기명식 보통주
#
#   extg_stkcnt extg_tisstk_vs     exrqpd_bgd     exrqpd_edd
# 0   1,181,102           4.60  2019년 12월 13일  2022년 12월 05일
# 1     344,827           3.03  2023년 02월 15일  2028년 01월 14일
#
# [2 rows x 42 columns]

# %% [markdown]
# ### 6. 증권신고서   ###

# %%
# dart.regstate(corp, key_word, start=None, end=None)
# 조회가능한 증권신고서 항목: ['주식의포괄적교환이전', '합병', '증권예탁증권', '채무증권', '지분증권', '분할']

dart.regstate('하림지주', '주식의포괄적교환이전')
dart.regstate('사조대림', '합병')
dart.regstate('에스앤케이', '증권예탁증권')
dart.regstate('BNK금융지주', '채무증권')
dart.regstate('금호전기', '지분증권')
dart.regstate('케이씨씨', '분할')
# Out:
#          rcept_no corp_cls corp_code corp_name        rpt_rcpn  stn  \
# 0  20191015000270        Y  00105271      케이씨씨  20191008000558   분할
# 0  20191015000270        Y  00105271      케이씨씨             NaN  NaN
# 0  20191015000270        Y  00105271      케이씨씨             NaN  NaN
# 1  20191015000270        Y  00105271      케이씨씨             NaN  NaN
# 2  20191015000270        Y  00105271      케이씨씨             NaN  NaN
# 3  20191015000270        Y  00105271      케이씨씨             NaN  NaN
#
#             bddd ctrd gmtsck_shddstd      ap_gmtsck  ...    slprc  \
# 0  2019년 07월 11일    -  2019년 10월 01일  2019년 11월 13일  ...      NaN
# 0            NaN  NaN            NaN            NaN  ...  108,038
# 0            NaN  NaN            NaN            NaN  ...      NaN
# 1            NaN  NaN            NaN            NaN  ...      NaN
# 2            NaN  NaN            NaN            NaN  ...      NaN
# 3            NaN  NaN            NaN            NaN  ...      NaN
#
#               slta    kndn        cnt    cmpnm      sen               tast  \
# 0              NaN     NaN        NaN      NaN      NaN                NaN
# 0  902,143,056,892  기명식보통주  8,350,210      NaN      NaN                NaN
# 0              NaN     NaN        NaN  (주)케이씨씨  분할되는 회사  8,805,709,000,000
# 1              NaN     NaN        NaN  (주)케이씨씨  분할되는 회사  8,805,709,000,000
# 2              NaN     NaN        NaN        -  분할되는 회사                  -
# 3              NaN     NaN        NaN        -  분할되는 회사                  -
#
#               cpt isstk_knd   isstk_cnt
# 0             NaN       NaN         NaN
# 0             NaN       NaN         NaN
# 0  56,435,000,000       보통주  10,556,513
# 1  56,435,000,000       우선주           -
# 2               -       보통주           -
# 3               -       우선주           -
#
# [6 rows x 29 columns]

# %% [markdown]
# ### 7. 확장 기능   ###

# %%
# 지정한 날짜의 공시목록 전체 (공시 시간 정보 포함)
dart.list_date_ex('2022-10-03')

# 하위 문서(sub_docs), 첨부 문서(attach_doc_list)
rcp_no = '20220308000798' 
dart.sub_docs(rcp_no) # 하위 문서 제목과 URL
dart.sub_docs(rcp_no, match='감사의견')  # 제목이 잘 매치되는 순서로 소트
dart.attach_doc_list(rcp_no) # 첨부 문서(i.e. 감사보고서) 제목과 URL
dart.attach_doc_list(rcp_no, match='감사의의견서') # 제목이 잘 매치되는 순서로 소트

# 첨부 파일 제목과 URL
dart.attach_files(rcp_no)

# URL을 지정한 파일로 다운로드
url = 'http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20220308000798&dcm_no=8446647&lang=ko'
fn = '[삼성전자]사업보고서_재무제표(2022.03.08)_ko.xls'
dart.download(url, fn)

# 첨부파일 모두 다운로드
for k in dart.attach_files('20221111000817'):
    # url, fn = atts[k], k
    print(url, fn)
    dart.download(url, fn)
# Out:
# attach_doc_list() will deprecated. use attach_files() instead
# attach_doc_list() will deprecated. use attach_files() instead
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20220308000798&dcm_no=8446647&lang=ko [삼성전자]사업보고서_재무제표(2022.03.08)_ko.xls
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20220308000798&dcm_no=8446647&lang=ko [삼성전자]사업보고서_재무제표(2022.03.08)_ko.xls
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20220308000798&dcm_no=8446647&lang=ko [삼성전자]사업보고서_재무제표(2022.03.08)_ko.xls
