# %%
# -*- coding: utf-8 -*-
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import pandas as pd
import re
from tqdm import tqdm
import ssl
import sys
import warnings
warnings.filterwarnings('ignore')
import os

# %%
# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)
def makeUrl(search, page, maxpage_t, sort, s_date, e_date, s_from, e_to):
    urls = []
    if page == maxpage_t:       # 최대페이지 1일 경우
        url = "https://search.naver.com/search.naver?where=news&query=" + search + "&sort="+sort+"&ds=" + s_date + "&de=" + e_date + "&nso=so%3Ar%2Cp%3Afrom" + s_from + "to" + e_to + "%2Ca%3A&start=" + str(page)
        urls.append(url)
    else:
        while page <= maxpage_t :
            url = "https://search.naver.com/search.naver?where=news&query=" + search + "&sort="+sort+"&ds=" + s_date + "&de=" + e_date + "&nso=so%3Ar%2Cp%3Afrom" + s_from + "to" + e_to + "%2Ca%3A&start=" + str(page)
            urls.append(url)
            page += 10
    return urls    

# html에서 원하는 속성 추출하는 함수 만들기 (기사, 추출하려는 속성값)
def news_attrs_crawler(articles,attrs):
    attrs_content=[]
    for i in articles:
        attrs_content.append(i.attrs[attrs])
    return attrs_content

# ConnectionError방지
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}

#html생성해서 기사크롤링하는 함수 만들기(url): 링크를 반환
def articles_crawler(url):
    #html 불러오기
    original_html = requests.get(url, headers=headers, verify=False)
    html = BeautifulSoup(original_html.text, "html.parser")

    url_naver = html.select("div.group_news > ul.list_news > li div.news_area > div.news_info > div.info_group > a.info")
    url = news_attrs_crawler(url_naver,'href')
    return url

# %%
def crawling_all(search, page, maxpage_t, sort, s_date, e_date, s_from, e_to) :
    # naver url 생성
    urls = makeUrl(search, page, maxpage_t, sort, s_date, e_date, s_from, e_to)

    #뉴스 크롤러 실행
    news_titles = []
    news_url =[]
    news_contents =[]
    news_dates = []

    while page <= maxpage_t :
        url_origin = "https://search.naver.com/search.naver?where=news&query=" + search + "&sort="+sort+"&ds=" + s_date + "&de=" + e_date + "&nso=so%3Ar%2Cp%3Afrom" + s_from + "to" + e_to + "%2Ca%3A&start=" + str(page)
        url = articles_crawler(url_origin)
        news_url .append(url)
        page += 10

    #제목, 링크, 내용 1차원 리스트로 꺼내는 함수 생성
    def makeList(newlist, content):
        for i in content:
            for j in i:
                newlist.append(j)
        return newlist

    #제목, 링크, 내용 담을 리스트 생성
    news_url_1 = []

    #1차원 리스트로 만들기(내용 제외)
    makeList(news_url_1,news_url)

    #NAVER 뉴스만 남기기
    final_urls = []
    for i in tqdm(range(len(news_url_1))):
        if "news.naver.com" in news_url_1[i]:
            final_urls.append(news_url_1[i])
        else:
            pass
    
    for i in tqdm(final_urls):
        #각 기사 html get하기
        headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
        news = requests.get(i, headers=headers, verify=False)
        news_html = BeautifulSoup(news.text,"html.parser")

        # 뉴스 제목 가져오기
        title = news_html.select_one("#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
        if title == None:
            title = news_html.select_one("#content > div.end_ct > div > h2")
        
        # 뉴스 본문 가져오기
        content = news_html.select("div#dic_area")
        if content == []:
            content = news_html.select("#articeBody")
            
        # 기사 텍스트만 가져오기
        # list합치기
        content = ''.join(str(content))

        # html태그제거 및 텍스트 다듬기
        pattern1 = '<[^>]*>'
        title = re.sub(pattern=pattern1, repl='', string=str(title))
        content = re.sub(pattern=pattern1, repl='', string=content)
        pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
        content = content.replace(pattern2, '')

        news_titles.append(title)
        news_contents.append(content)

        # html_date = news_html.select_one("div#ct > div.media_end_head > div.media_end_head_info > div span")
        # news_date = html_date.attrs['data-date-time']
        # news_dates.append(news_date)

        try:
            html_date = news_html.select_one("div#ct > div.media_end_head > div.media_end_head_info > div span")
            news_date = html_date.attrs['data-date-time']
        except AttributeError:
            news_date = news_html.select_one("#content > div.end_ct > div > div.article_info > span > em")
            news_date = re.sub(pattern=pattern1,repl='',string=str(news_date))
        # 날짜 가져오기
        news_dates.append(news_date)

    a = pd.DataFrame({'date':news_dates,'title':news_titles,'link':final_urls,'content':news_contents})
    return a

# %%
kospi = pd.read_csv('./KOSPI200.csv', encoding='euc-kr')
kospi200 = kospi['종목명']
kospi200
# Out:
# 0          삼성전자
# 1      LG에너지솔루션
# 2        SK하이닉스
# 3      삼성바이오로직스
# 4         삼성SDI
#          ...
# 195         지누스
# 196       쿠쿠홈시스
# 197    신세계인터내셔날
# 198       현대홈쇼핑
# 199          한섬
# Name: 종목명, Length: 200, dtype: object

# %%
day = []
# i = 7
# while i<13:
#     day.append('2021.{}.01'.format(str(i).zfill(2)))
#     i += 1

# print(day)

# %%
# i = 1
# while i<13:
#     day.append('2022.{}.01'.format(str(i).zfill(2)))
#     i += 1

# print(day)

# %%
i = 1
while i<7:
    day.append('2023.{}.01'.format(str(i).zfill(2)))
    i += 1

print(day)
# Out:
# ['2023.01.01', '2023.02.01', '2023.03.01', '2023.04.01', '2023.05.01', '2023.06.01']

# %%
# for keyword in kospi200 : 
#     #데이터 프레임 만들기
#     news_df = news_df = pd.DataFrame(
#         data=None
#         , index=None
#         , columns=['date','title','link''content']
#     )

#     # 최대 페이지 수
#     maxpage = 401
#     #검색어 입력
#     search = keyword
#     # 검색 방식
#     sort = '0'
#     # 시작날짜
#     s_date = '2021.06.28'
#     # 끝나는 날짜
#     e_date = '2021.06.30'

#     # 날짜 바꾸기
#     s_from = s_date.replace(".","")
#     e_to = e_date.replace(".","")

#     page = 1  
#     maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지

#     a = crawling_all(search,page,maxpage_t, sort, s_date, e_date, s_from, e_to)
#     news_df = pd.concat([news_df, a], ignore_index=True, keys=['date','title','link''content'])
#     news_df = news_df.drop_duplicates(keep='first',ignore_index=True)

#     now = datetime.now()
#     news_df.to_csv('C:/big16/trading/DATA/{}_{}_date{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H%M%S'),s_from, e_to),encoding='utf-8-sig',index=False)

# %%
#####뉴스크롤링 시작#####
for keyword in tqdm(kospi200) :
    for i in day :
        #데이터 프레임 만들기
        news_df = news_df = pd.DataFrame(
            data=None
            , index=None
            , columns=['date','title','link''content']
        )

        # 최대 페이지 수
        maxpage = 401
        #검색어 입력
        search = keyword
        # 검색 방식
        sort = str(0)
        # 시작날짜
        s_date = i
        # 끝나는 날짜
        e_1 = i[-2:]
        e_2 = int(e_1)+30
        e_3 = i[:-2]+str(e_2)
        e_date = e_3

        # 날짜 바꾸기
        s_from = s_date.replace(".","")
        e_to = e_date.replace(".","")

        page = 1  
        maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지

        a = crawling_all(search,page,maxpage_t, sort, s_date, e_date, s_from, e_to)
        news_df = pd.concat([news_df, a], ignore_index=True, keys=['date','title','link''content'])
        news_df = news_df.drop_duplicates(keep='first',ignore_index=True)

        now = datetime.now()
        news_df.to_csv('C:/big16/trading/DATA/{}_{}_date{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H%M%S'),s_from, e_to),encoding='utf-8-sig',index=False)
# Out:
# 100%|██████████| 5833/5833 [00:00<00:00, 2477506.35it/s]
# 100%|██████████| 1823/1823 [08:16<00:00,  3.67it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 3244/3244 [00:00<00:00, 3250435.30it/s]
#  19%|█▊        | 179/964 [00:52<03:51,  3.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 32
#      29 page = 1
#      30 maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지
# ---> 32 a = crawling_all(search,page,maxpage_t, sort, s_date, e_date, s_from, e_to)
#      33 news_df = pd.concat([news_df, a], ignore_index=True, keys=['date','title','link''content'])
#      34 news_df = news_df.drop_duplicates(keep='first',ignore_index=True)
#
# Cell In[29], line 38, in crawling_all(search, page, maxpage_t, sort, s_date, e_date, s_from, e_to)
#      35     else:
#      36         pass
# ---> 38 for i in tqdm(final_urls):
#      39     #각 기사 html get하기
#      40     headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
#      41     news = requests.get(i, headers=headers, verify=False)
#
# File c:\Users\USER\anaconda3\lib\site-packages\tqdm\std.py:1205, in tqdm.__iter__(self)
#    1203 dt = cur_t - last_print_t
#    1204 if dt >= mininterval and cur_t >= min_start_t:
# -> 1205     self.update(n - last_print_n)
#    1206     last_print_n = self.last_print_n
#    1207     last_print_t = self.last_print_t
#
# File c:\Users\USER\anaconda3\lib\site-packages\tqdm\std.py:1256, in tqdm.update(self, n)
#    1254     self._ema_dn(dn)
#    1255     self._ema_dt(dt)
# -> 1256 self.refresh(lock_args=self.lock_args)
#    1257 if self.dynamic_miniters:
#    1258     # If no `miniters` was specified, adjust automatically to the
#    1259     # maximum iteration rate seen so far between two prints.
#    1260     # e.g.: After running `tqdm.update(5)`, subsequent
#    1261     # calls to `tqdm.update()` will only cause an update after
#    1262     # at least 5 more iterations.
#    1263     if self.maxinterval and dt >= self.maxinterval:
#
# File c:\Users\USER\anaconda3\lib\site-packages\tqdm\std.py:1361, in tqdm.refresh(self, nolock, lock_args)
#    1359     else:
#    1360         self._lock.acquire()
# -> 1361 self.display()
#    1362 if not nolock:
#    1363     self._lock.release()
#
# File c:\Users\USER\anaconda3\lib\site-packages\tqdm\std.py:1509, in tqdm.display(self, msg, pos)
#    1507 if pos:
#    1508     self.moveto(pos)
# -> 1509 self.sp(self.__str__() if msg is None else msg)
#    1510 if pos:
#    1511     self.moveto(-pos)
#
# File c:\Users\USER\anaconda3\lib\site-packages\tqdm\std.py:350, in tqdm.status_printer.<locals>.print_status(s)
#     348 def print_status(s):
#     349     len_s = disp_len(s)
# --> 350     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     351     last_len[0] = len_s
#
# File c:\Users\USER\anaconda3\lib\site-packages\tqdm\std.py:344, in tqdm.status_printer.<locals>.fp_write(s)
#     342 def fp_write(s):
#     343     fp.write(_unicode(s))
# --> 344     fp_flush()
#
# File c:\Users\USER\anaconda3\lib\site-packages\tqdm\utils.py:145, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     143 def inner(*args, **kwargs):
#     144     try:
# --> 145         return func(*args, **kwargs)
#     146     except OSError as e:
#     147         if e.errno != 5:
#
# File c:\Users\USER\anaconda3\lib\site-packages\ipykernel\iostream.py:488, in OutStream.flush(self)
#     486     self.pub_thread.schedule(evt.set)
#     487     # and give a timeout to avoid
# --> 488     if not evt.wait(self.flush_timeout):
#     489         # write directly to __stderr__ instead of warning because
#     490         # if this is happening sys.stderr may be the problem.
#     491         print("IOStream.flush timed out", file=sys.__stderr__)
#     492 else:
#
# File c:\Users\USER\anaconda3\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File c:\Users\USER\anaconda3\lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
for keyword in kospi200 : 
    #데이터 프레임 만들기
    news_df = news_df = pd.DataFrame(
        data=None
        , index=None
        , columns=['date','title','link''content']
    )

    # 최대 페이지 수
    maxpage = 401
    #검색어 입력
    search = keyword
    # 검색 방식
    sort = '0'
    # 시작날짜
    s_date = '2023.07.01'
    # 끝나는 날짜
    e_date = '2023.07.06'

    # 날짜 바꾸기
    s_from = s_date.replace(".","")
    e_to = e_date.replace(".","")

    page = 1  
    maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지

    a = crawling_all(search,page,maxpage_t, sort, s_date, e_date, s_from, e_to)
    news_df = pd.concat([news_df, a], ignore_index=True, keys=['date','title','link''content'])
    news_df = news_df.drop_duplicates(keep='first',ignore_index=True)

    now = datetime.now()
    news_df.to_csv('C:/big16/trading/DATA/{}_{}_date{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H%M%S'),s_from, e_to),encoding='utf-8-sig',index=False)
