# %%
#크롤링시 필요한 라이브러리 불러오기
from bs4 import BeautifulSoup
import requests
import re
import datetime
from tqdm import tqdm
import sys

# %%
# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
  #입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num+1
    else:
        return num+9*(num-1)

# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)

def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(start_page)
        print("생성url: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(page)
            urls.append(url)
        print("생성url: ", urls)
        return urls    

# html에서 원하는 속성 추출하는 함수 만들기 (기사, 추출하려는 속성값)
def news_attrs_crawler(articles,attrs):
    attrs_content=[]
    for i in articles:
        attrs_content.append(i.attrs[attrs])
    return attrs_content

# ConnectionError방지
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

#html생성해서 기사크롤링하는 함수 만들기(url): 링크를 반환
def articles_crawler(url):
    #html 불러오기
    original_html = requests.get(i,headers=headers)
    html = BeautifulSoup(original_html.text, "html.parser")

    url_naver = html.select("div.group_news > ul.list_news > li div.news_area > div.news_info > div.info_group > a.info")
    url = news_attrs_crawler(url_naver,'href')
    return url

# %%
#####뉴스크롤링 시작#####

#검색어 입력
search = input("검색할 키워드를 입력해주세요:")
#검색 시작할 페이지 입력
page = int(input("\n크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 시작 페이지: ",page,"페이지")   
#검색 종료할 페이지 입력
page2 = int(input("\n크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 종료 페이지: ",page2,"페이지")   


# naver url 생성
url = makeUrl(search,page,page2)

#뉴스 크롤러 실행
news_titles = []
news_url =[]
news_contents =[]
news_dates = []
for i in url:
    url = articles_crawler(url)
    news_url.append(url)


#제목, 링크, 내용 1차원 리스트로 꺼내는 함수 생성
def makeList(newlist, content):
    for i in content:
        for j in i:
            newlist.append(j)
    return newlist

    
#제목, 링크, 내용 담을 리스트 생성
news_url_1 = []

#1차원 리스트로 만들기(내용 제외)
makeList(news_url_1,news_url)

#NAVER 뉴스만 남기기
final_urls = []
for i in tqdm(range(len(news_url_1))):
    if "news.naver.com" in news_url_1[i]:
        final_urls.append(news_url_1[i])
    else:
        pass
# Out:
# 크롤링할 시작 페이지:  1 페이지
#
# 크롤링할 종료 페이지:  20 페이지
# 생성url:  ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=1', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=11', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=21', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=31', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=41', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=51', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=61', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=71', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=81', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=91', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=101', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=111', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=121', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=131', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=141', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=151', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=161', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=171', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=181', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=박&start=191']
# 100%|██████████| 337/337 [00:00<00:00, 291259.11it/s]

# %%
# 뉴스 내용 크롤링

for i in tqdm(final_urls):
    #각 기사 html get하기
    news = requests.get(i,headers=headers)
    news_html = BeautifulSoup(news.text,"html.parser")
    # 뉴스 제목 가져오기
    title = news_html.select_one("#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
    if title == None:
        title = news_html.select_one("#content > div.end_ct > div > h2")
    
    # 뉴스 본문 가져오기
    content = news_html.select("div#dic_area")
    if content == []:
        content = news_html.select("#articeBody")
        
    # 기사 텍스트만 가져오기
    # list합치기
    content = ''.join(str(content))

    # html태그제거 및 텍스트 다듬기
    pattern1 = '<[^>]*>'
    title = re.sub(pattern=pattern1, repl='', string=str(title))
    content = re.sub(pattern=pattern1, repl='', string=content)
    pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
    content = content.replace(pattern2, '')

    news_titles.append(title)
    news_contents.append(content)

    try:
        html_date = news_html.select_one("div#ct> div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > div > span")
        news_date = html_date.attrs['data-date-time']
    except AttributeError:
        news_date = news_html.select_one("#content > div.end_ct > div > div.article_info > span > em")
        news_date = re.sub(pattern=pattern1,repl='',string=str(news_date))
    # 날짜 가져오기
    news_dates.append(news_date)

print("검색된 기사 갯수: 총 ",(page2+1-page)*10,'개')
print("\n[뉴스 제목]")
print(news_titles)
print("\n[뉴스 링크]")
print(final_urls)
print("\n[뉴스 내용]")
print(news_contents)
print('news_title: ',len(news_titles))
print('news_url: ',len(final_urls))
print('news_contents: ',len(news_contents))
print('news_dates: ',len(news_dates))
# Out:
#   0%|          | 0/137 [00:00<?, ?it/s]
# 100%|██████████| 137/137 [01:39<00:00,  1.38it/s]
# 검색된 기사 갯수: 총  200 개
#
# [뉴스 제목]
# ['\n\t\t\t\'한영♥\' 박군, 다둥이 아빠 욕심까지? "비법 알려주세요"\n\t\t', '\n\t\t\t\'세컨하우스2\' 박군, 母생각에 울컥 "살아계셨더라면"\n\t\t', '\n\t\t\t[포토] 조인성, (박)경림누나 칭찬에 웃음이 터졌어요\n\t\t', 'None', 'None', '\n\t\t\t[가요소식] 산다라박, 다음 달 6년 만에 새 앨범 발매\n\t\t', '“감사원 더는 방치 못해”…野 ‘감사완박법’ 처리 선전포고', '\n\t\t\t산다라박, 6년 만에 본업…7월 스페셜 앨범 발매\n\t\t', 'None', 'None', '"에코프로는 618%나 올랐는데…" 돈 잃은 개미들 \'절규\' [박의명의 불개미 구조대]', "\n\t\t\t'세컨 하우스2' 일당백 일꾼 박군 출격\n\t\t", "\n\t\t\t20세기 원조 '김·나·박·이'부터 김병철까지…'유퀴즈' 러브 다이브 특집\n\t\t", '\n\t\t\t산다라박, 7월 데뷔 첫 솔로앨범 발표…2NE1 이후 6년만, 뮤지션 깜짝복귀\n\t\t', '\n\t\t\t[대중문화 단신] 산다라박, 7월 첫 솔로음원 발매 외\n\t\t', '\n\t\t\t산다라박, 말랐는데 반전 볼륨감…섹시美 뿜뿜\n\t\t', "\n\t\t\t'세컨하우스2' 최수종X박군, 흙벽 철거 中 붕괴 위험..'중단' [★밤TV]\n\t\t", '\n\t\t\t‘세컨 하우스2’ 박군, 최수종♥하희라 위해 지원사격 [MK★TV뷰]\n\t\t', '\n\t\t\t산다라박, 7월 솔로 싱글 발표...음원 작업 막바지\n\t\t', '\n\t\t\t박서진 VS 박지현, 박家 정면 승부..."박 터지게 싸워" (미스터로또)[종합]\n\t\t', '침수위험지 직접 점검한 박 시장…주민 “근본대책 세워달라”', "\n\t\t\t산다라박, 금발+핑크 크롭티 입고 '열심히' 강조···미모가 제일 열일 중\n\t\t", "벌써부터…정수기 '박氷 승부'", '\n\t\t\t‘일꾼의 탄생’ 가수 박군, ‘민원 특전사’ 변신\n\t\t', '\n\t\t\t산다라박, 말랐는데 볼륨감도 가졌네..시원한 휴가 패션\n\t\t', '\n\t\t\t"입국만 하면 3kg 쪄" 산다라박, 필리핀 먹방 여행에 \'만족\'\n\t\t', "박 터지는 '로봇 전쟁', LG유플러스 직원 180명이 일본으로 건너간 까닭은", '"박 책임, 김 매니저…미국 출장 간 김에 그랜드 캐니언이나 다녀오게"', '박 지사 “도정 신뢰 중요…실적 부풀려선 안 돼”', '\n\t\t\t산다라박 “젝스키스 vs H.O.T의 대결 같은 무대” (복면가왕)\n\t\t', '박 지사 “도정 신뢰 중요…실적 부풀려선 안 돼”', '“재능꾼 다 모였네” 영산대, 나태주‧박군 ‘태군노래자랑’ 촬영', '\n\t\t\t아내 한영보다 8㎝ 작은 박군 설움, 4㎝ 갭에도 쩔쩔(세컨하우스2)[결정적장면]\n\t\t', "[단독]기업가치 7000억원 수입육 기업 매물로 나왔다…'앵거스박 쇠고기'로 B2C 확장", '\n\t\t\t산다라박, 머리 얼마나 작길래? "모자 너무 커 고무줄로 묶어"\n\t\t', "\n\t\t\t'한영♥' 박군, '일꾼의 탄생' 합류…민원과 동시에 눈물\n\t\t", '\n\t\t\t박봄, 절친 산다라 박 부럽지 않은 동안 외모 자랑\n\t\t', '\n\t\t\t산다라박, 39kg 극세사 래시가드 자태..마른 몸에도 볼륨감\n\t\t', 'None', 'None', '\n\t\t\t이장우, 유리에 "데이트 가자"..존박도 \'바람났다\' 놀란 \'핑크빛 무드\'(\'장사천재\')[SC리뷰]\n\t\t', '\n\t\t\t나태주X박군, 진도에서 만난 패티김 (태군노래자랑)\n\t\t', "드라마 속 얘기인 줄 알았더니…현실판 '미생 박과장' 딱 걸렸다", '[간추린 경남] 박 지사 “도정 신뢰 중요…실적 부풀려선 안 돼” 외', '\n\t\t\t박군 ‘눈 지그시 감고 트롯’ [틀린그림찾기]\n\t\t', 'None', 'None', "하현우·존박·케이시 참여한 평택시 '안정리플레이 뮤직페스타' 성료", '\n\t\t\t납치 사건 휘말린 박군→모태범, 침수차량서 살아남을까 (생존게임 코드레드)\n\t\t', "[사설] 유엔기념공원 '핫플', 박 보훈부 장관에 거는 기대", '\n\t\t\t신봉선 산다라박 울었다, 옛 추억 갖고 온 가수 누구길래(복면가왕)\n\t\t', 'None', '\n\t\t\t하이량, 박군→양지은 찍고 또 찍고\n\t\t', '박 지사 “전기요금 차등제…경남 입장 반영해야”', '\n\t\t\t포승줄 묶인 채 끌려가는 박군, 감금위기(생존게임)\n\t\t', '박 시장 임기 들어 월평균 15건 체결…“동력 되지만 신뢰 하락 부작용”', '\n\t\t\t강수정, 80억 오션뷰 아파트에 새 4마리 태어나 "박씨 필요 없어"\n\t\t', '\n\t\t\t한영, ♥박군 성형 폭로…"쌍꺼풀 수술에 코는 두 번 했다" [RE:TV]\n\t\t', '\n\t\t\t박군-홍자 ‘완벽 조합’ [MK포토]\n\t\t', '\n\t\t\t박군, 한잔해 한잔해\n\t\t', '\n\t\t\t산다라박, 2NE1 데뷔초 떠오르는 ‘꽁지머리’..초동안 미모는 ‘덤’\n\t\t', "\n\t\t\t[Ms포토] 박군 '끝내주는 목소리로~'\n\t\t", '"멸공, 멸공, 멸공"…中 주식 몰빵한 개미들 \'절규\' [박의명의 불개미 구조대]', '\'이정근에 정치자금 전달\'…사업가 박씨 "3.3억원 중 1천만원만 인정"', '\n\t\t\t산다라박 여전히 개성 넘치는 헤어스타일, 2NE1 시절 때랑 똑같네\n\t\t', '자리 향하는 이재명-박과온', "케이메디허브 '소부장 기술지원사업' 선정… 의료소재 개발 박", 'None', '\n\t\t\t\'박군♥\' 한영 "결혼식 또 하고 싶다"…이다해 커플 보더니 폭탄 선언\n\t\t', 'None', 'None', '\n\t\t\t\'박군♥\'한영, 과거 사진 보며 한탄 "못 돌아가나봄..살 안 빠짐"\n\t\t', '‘박·정·천’ 민주당 올드보이들, 내년 총선 호남 복귀설 부상', "\n\t\t\t산다라박, 금발+핑크 크롭티 입고 '열심히' 강조···미모가 제일 열일 중\n\t\t", '\n\t\t\t2NE1 산다라박이 온다..."무대 그리워 컴백 결정"\n\t\t', "\n\t\t\t박군, 최수종♥하희라 위해 '세컨 하우스2' 출격…'한잔해' 춤으로 대동단결\n\t\t", "벌써부터…정수기 '박氷 승부'", '\n\t\t\t산다라박 7월 앨범 발매 예고 “드디어 솔로! 무대 그리웠다”[똑똑SNS]\n\t\t', '\n\t\t\t‘일꾼의 탄생’ 가수 박군, ‘민원 특전사’ 변신\n\t\t', '\n\t\t\t산다라박 7월 앨범 발매 예고 “드디어 솔로! 무대 그리웠다”[똑똑SNS]\n\t\t', '\n\t\t\t산다라박, 솔로 가수 컴백…7월 새 앨범 발표 준비\n\t\t', '\n\t\t\t‘일꾼의 탄생’ 가수 박군, ‘민원 특전사’ 변신\n\t\t', '\n\t\t\t산다라박, 말랐는데 볼륨감도 가졌네..시원한 휴가 패션\n\t\t', '\n\t\t\t[세컨 하우스2] 철거를 돕기 위해 찾아와준 박군을 위한 최수종의 즉석 콘서트?!...트위스트로 보답하는 박군\n\t\t', '\n\t\t\t"입국만 하면 3kg 쪄" 산다라박, 필리핀 먹방 여행에 \'만족\'\n\t\t', "박 터지는 '로봇 전쟁', LG유플러스 직원 180명이 일본으로 건너간 까닭은", "박 터지는 '로봇 전쟁', LG유플러스 직원 180명이 일본으로 건너간 까닭은", '"박 책임, 김 매니저…미국 출장 간 김에 그랜드 캐니언이나 다녀오게"', '\n\t\t\t산다라박, 극세사 팔다리..모태 마름 글발 미녀\n\t\t', '박 지사 “도정 신뢰 중요…실적 부풀려선 안 돼”', '\n\t\t\t산다라박 “젝스키스 vs H.O.T의 대결 같은 무대” (복면가왕)\n\t\t', '박 지사 “도정 신뢰 중요…실적 부풀려선 안 돼”', '“재능꾼 다 모였네” 영산대, 나태주‧박군 ‘태군노래자랑’ 촬영', '\n\t\t\t아내 한영보다 8㎝ 작은 박군 설움, 4㎝ 갭에도 쩔쩔(세컨하우스2)[결정적장면]\n\t\t', '\ ...
#
# [뉴스 링크]
선 다할 것”野, 감사위원회의 의결사항 공개토록작년 11월에 당론으로 개정안 발의朴 “감사원 국정조사도 추진할 것”\n\n\n\n 박광온 민주당 원내대표가 16일 국회 당 사무실에서 열린 최고위원회의에 참석하고 있다. [연합뉴스]더불어민주당이 전현위 국민권익위원장에 대한 감사원 보고서 의결과정 논란을 계기로 감사위원회 의결사항을 공개하고 내부회계·직무감찰결과를 국회에 보고하도록 하는 감사원법 개정안 처리 추진을 본격화한다.박광온 민주당 원내대표는 16일 국회에서 열린 최고위원회의에서 “지년 1년간 감사원은 중립성과 공정성, 투명성을 포기했고 국민 신뢰를 잃는 대신 정부 맞춤형 감사로 정권 눈에 들기에 급급했다. 더는 방치할 수 없다”며 “특단의 조치를 내리겠다”고 말했다.그는 이어 “감사원에 대한 개혁과 국민 감시가 철저해져야 한다는 여론이 더욱 강해지고 있다”며 “당론으로 발의한 감사원법 개정안을 통과시키기 위해 최선을 다하겠다”고 다짐했다민주당은 지난해 11월 당시 ‘윤석열정권 정치탄압대책위원회’ 위원장이던 박범계 의원을 중심으로 이른바 ‘감사완박법(감사원 권한 완전 박탈법)’으로 불리는 개정안을 당론으로 발의했다.감사원 최고 의사결정기관인 감사위원회의 의결사항을 공개하고, 수사기관 고발 시 감사위원회의 의결을 반드시 거치도록 하는 내용을 포함하고 있다. 아울러 감사 개시를 비롯한 감사 계획의 변경과 중간감사 결과 발표를 위해선 감사위원회 의결이 필요하고, 민간인은 주된 감사 대상이 될 수 없다는 조항도 포함돼 있다.관련법안은 작년 11월 국회 법제사법위원회에 상정돼 법안심사제1소위에 계류중이다.박광온 원내대표는 감사원에 대한 국정조사를 추진하겠다고 밝혔다.박 원내대표는 “전임 정부에서 임명된 기관장 표적감사, 전임 정부의 정책 성과를 지우기 위한 정치감사에 이르기까지의 실상을 밝히고 책임을 묻겠다”며 “무엇보다 윗선의 하명 감사가 있었는지가 매우 중요한 부분”이라고 강조했다.그는 이어 “OECD(경제협력개발기구) 34개국 가운데 감사원을 행정부, 특히 대통령 소속으로 둔 나라는 한국이 유일하다”며 “개헌을 통해 감사원을 완전한 독립기구로 바꿔야 한다”고 주장했다.이런 가운데 전현희 위원장과 감사원 사무처는 감사원장의 직무회피 제척여부를 두고 진실공방을 벌이고 있다.전현희 위원장은 이날 자신의 페이스북에 글을 올려 “감사원사무처는 6월 15일자 보도자료에서 권익위원장에 관한 감사위원회에서 감사원장 직무회피 제척여부에 관해 명백한 허위사실을 적시하 ...
# news_title:  137
# news_url:  137
# news_contents:  137
# news_dates:  137

# %%
###데이터 프레임으로 만들기###
import pandas as pd
from datetime import datetime, date, time

#데이터 프레임 만들기
news_df = pd.DataFrame({'date':news_dates,'title':news_titles,'link':final_urls,'content':news_contents})
news_df

#중복 행 지우기
news_df = news_df.drop_duplicates(keep='first',ignore_index=True)
print("중복 제거 후 행 개수: ",len(news_df))

#데이터 프레임 저장
# from datetime import datetime, date, time
now = datetime.now() 
news_df.to_csv('{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H%M%S')),encoding='utf-8',index=False)
# Out:
# 중복 제거 후 행 개수:  91
