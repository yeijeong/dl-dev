# %%
import yfinance as yf

# %% [markdown]
# ---
# ##### 'AAPL' 이라는 티커를 가진 종목의 주가를 start에 설정한 날짜부터 오늘까지 전부 받아올 수 있는 코드
#     - 만약 원하는 기간이 있다면 파라미터에 end = '2019-06-01'를 추가로 넣으면 된다.
#
# ---

# %%
# yf.download('AAPL',start = '2022-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  180.434296  \
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  178.144272
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  173.405685
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  170.510956
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.679489
# ...                ...         ...         ...         ...         ...
# 2023-06-15  183.960007  186.520004  183.779999  186.009995  186.009995
# 2023-06-16  186.729996  186.990005  184.270004  184.919998  184.919998
# 2023-06-20  184.410004  186.100006  184.410004  185.009995  185.009995
# 2023-06-21  184.899994  185.410004  182.589996  183.960007  183.960007
# 2023-06-22  183.740005  187.050003  183.669998  187.000000  187.000000
#
#                Volume
# Date
# ...

# %% [markdown]
# ---
# ##### 가져올 데이터 기간 지정
# ---

# %%
start = '2020-01-01'
end = '2023-06-22'

# %%
symbol='AAPL'

# %%
AAPL_df = yf.download(symbol, start, end)
AAPL_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   73.347923  \
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.634857
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   73.213615
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.869301
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   74.041489
# ...                ...         ...         ...         ...         ...
# 2023-06-14  183.369995  184.389999  182.020004  183.949997  183.949997
# 2023-06-15  183.960007  186.520004  183.779999  186.009995  186.009995
# 2023-06-16  186.729996  186.990005  184.270004  184.919998  184.919998
# 2023-06-20  184.410004  186.100006  184.410004  185.009995  185.009995
# 2023-06-21  184.899994  185.410004  182.589996  183.960007  183.960007
#
#                Volume
# Date
# ...

# %% [markdown]
# ---
# ##### 한 번에 여러 종목 받아오기

# %%
# 테슬라, 카카오, 마이크로소프트, 비트코인 달러 가격
symbol = ['TSLA','035720.KS','MSFT','BTC-USD']

df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  4 of 4 completed
#                Adj Close                                               Close
#                035720.KS       BTC-USD        MSFT        TSLA     035720.KS
# Date
# 2020-01-01           NaN   7200.174316         NaN         NaN           NaN  \
# 2020-01-02  30663.927734   6985.470215  155.422028   28.684000  30724.287109
# 2020-01-03  30663.927734   7344.884277  153.486755   29.534000  30724.287109
# 2020-01-04           NaN   7410.656738         NaN         NaN           NaN
# 2020-01-05           NaN   7411.317383         NaN         NaN           NaN
# ...                  ...           ...         ...         ...           ...
# 2023-06-17           NaN  26510.675781         NaN         NaN           NaN
# 2023-06-18           NaN  26336.212891         NaN         NaN           NaN
# 2023-06-19  52500.000000  26851.029297         NaN         NaN  52500.000000
# ...

# %% [markdown]
# ---
# ##### 원하는 데이터 종류 가져오깅

# %%
data['Close']
# Out:
#                   AAPL        MSFT
# Date
# 2022-01-03  182.009995  334.750000
# 2022-01-04  179.699997  329.010010
# 2022-01-05  174.919998  316.380005
# 2022-01-06  172.000000  313.880005
# 2022-01-07  172.169998  314.040009
# ...                ...         ...
# 2023-06-15  186.009995  348.100006
# 2023-06-16  184.919998  342.329987
# 2023-06-20  185.009995  338.049988
# 2023-06-21  183.960007  333.559998
# 2023-06-22  187.000000  339.709991
#
# [369 rows x 2 columns]

# %% [markdown]
# ---
# ##### yfinance로 주가 외 데이터 받아오기
#
#     - yf.Ticker() 함수를 통해 내가 데이터를 받고자 하는 기업의 티커를 전달해주자

# %%
aapl = yf.Ticker('AAPL')

# %% [markdown]
# ---
# - 배당 내역

# %%
aapl.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-05-06 00:00:00-04:00    0.230000
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# Name: Dividends, Length: 79, dtype: float64

# %% [markdown]
# ---
# - 주식분할 내역

# %%
aapl.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %% [markdown]
# ---
# - 애널리스트 평가 정보

# %%
# aapl.recommendations()
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 aapl.recommendations()
#
# File c:\Users\green\anaconda3\envs\pandas-dev\lib\site-packages\yfinance\ticker.py:146, in Ticker.recommendations(self)
#     144 @property
#     145 def recommendations(self):
# --> 146     return self.get_recommendations()
#
# File c:\Users\green\anaconda3\envs\pandas-dev\lib\site-packages\yfinance\base.py:1464, in TickerBase.get_recommendations(self, proxy, as_dict)
#    1462 def get_recommendations(self, proxy=None, as_dict=False):
#    1463     self._quote.proxy = proxy
# -> 1464     data = self._quote.recommendations
#    1465     if as_dict:
#    1466         return data.to_dict()
#
# File c:\Users\green\anaconda3\envs\pandas-dev\lib\site-packages\yfinance\scrapers\quote.py:577, in Quote.recommendations(self)
#     574 @property
# ...

# %%
# show news
msft.news
# Out:
# [{'uuid': 'd31aad7f-b7f2-3fb4-a58f-19212a6699d4',
#   'title': 'Nvidia Is Getting a Big Boost in a Fast-Growing Market, and It Is Not AI',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/d31aad7f-b7f2-3fb4-a58f-19212a6699d4/nvidia-is-getting-a-big-boost.html',
#   'providerPublishTime': 1687442940,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/YfjEnGWZ2v4uqlhWc5FoVw--~B/aD0xNDE0O3c9MjExOTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/d33afbc660e2674b2b20ebdf4634f4a6',
#      'width': 2119,
#      'height': 1414,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/cWoYb.rlciQjD49_1KikrQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/d33afbc660e2674b2b20ebdf4634f4a6',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA', 'MSFT']},
# ...

# %%
# ###데이터 프레임으로 만들기###
# import pandas as pd

# #데이터 프레임 만들기
# df = pd.DataFrame({'date':,'title':news_titles,'link':final_urls,'content':news_contents})
# news_df

# #중복 행 지우기
# news_df = news_df.drop_duplicates(keep='first',ignore_index=True)
# print("중복 제거 후 행 개수: ",len(news_df))

# #데이터 프레임 저장
# now = datetime.datetime.now() 
# news_df.to_csv('{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H시%M분%S초')),encoding='utf-8-sig',index=False)

# %%
df.to_csv('multi_assets.csv')
