# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client
import pandas as pd
import numpy as np

# %%
import pymysql
conn = pymysql.connect(
    host='34.64.240.96'
    , user='root'
    , password='tndusWkd1.'
    , db='final_project'
    , charset='utf8'
)
cur = conn.cursor()

# %%
# a = pd.DataFrame(data, columns=['시분초','시가','대비','체결량','거래량'])

list = []
zero_df = pd.DataFrame(columns=['시분초','시가','대비','체결량','거래량'])
#list2 = []
#zero_df2 = pd.DataFrame(columns=['코드', '이름', '시간', '현재가', '대비', '시가', '고가', '저가', '매도호가', '매수호가', '거래량', '거래대금'])
        
class CpEvent:
    instance = None
 
    def OnReceived(self):
        # time = CpEvent.instance.GetHeaderValue(3)  # 시간
        timess = CpEvent.instance.GetHeaderValue(18)  # 초
        exFlag = CpEvent.instance.GetHeaderValue(19)  # 예상체결 플래그
        cprice = CpEvent.instance.GetHeaderValue(13)  # 현재가
        diff = CpEvent.instance.GetHeaderValue(2)  # 대비
        cVol = CpEvent.instance.GetHeaderValue(17)  # 순간체결수량
        vol = CpEvent.instance.GetHeaderValue(9)  # 거래량
 
        if (exFlag == ord('1')):  # 동시호가 시간 (예상체결)
            # print("실시간(예상체결)", timess, "*", cprice, "대비", diff, "체결량", cVol, "거래량", vol)
            list.append([timess,cprice,diff,cVol,vol])
            app_df = pd.DataFrame(data=list, columns=['시분초','시가','대비','체결량','거래량'])
            df = pd.concat([zero_df,app_df], ignore_index=True)
            print(df)
            JusikTimess = df['시분초'].to_list()
            JusikCprice = df['시가'].to_list()
            JusikDiff = df['대비'].to_list()
            JusikCVol = df['체결량'].to_list()
            JusikVol = df['거래량'].to_list()
            print(JusikTimess)
            for timess, cprice, diff, cvol, vol in zip(JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol):
                sql = "INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES (%s, %s, %s, %s, %s)" % ("'"+str(timess)+"'", "'"+str(cprice)+"'", "'"+str(diff)+"'", "'"+str(cvol)+"'","'"+str(vol)+"'")
                print(sql)
                cur.execute(sql)
            conn.commit()
           
            
        elif (exFlag == ord('2')):  # 장중(체결)
            #print("실시간(장중 체결)", timess, cprice, "대비", diff, "체결량", cVol, "거래량", vol)
            #print("실시간(예상체결)", timess, "*", cprice, "대비", diff, "체결량", cVol, "거래량", vol)
            list.append([timess,cprice,diff,cVol,vol])
            app_df = pd.DataFrame(data=list, columns=['시분초','시가','대비','체결량','거래량'])
            df = pd.concat([zero_df,app_df], ignore_index=True)
            print(df)
            JusikTimess = df['시분초'].to_list()
            JusikCprice = df['시가'].to_list()
            JusikDiff = df['대비'].to_list()
            JusikCVol = df['체결량'].to_list()
            JusikVol = df['거래량'].to_list()
            print(JusikTimess)
            for timess, cprice, diff, cvol, vol in zip(JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol):
                sql = "INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES (%s, %s, %s, %s, %s)" % ("'"+str(timess)+"'", "'"+str(cprice)+"'", "'"+str(diff)+"'", "'"+str(cvol)+"'","'"+str(vol)+"'")
                print(sql)
                cur.execute(sql)
            conn.commit()

class CpStockCur:
    def Subscribe(self, code):
        self.objStockCur = win32com.client.Dispatch("DsCbo1.StockCur")
        win32com.client.WithEvents(self.objStockCur, CpEvent)
        self.objStockCur.SetInputValue(0, code)
        CpEvent.instance = self.objStockCur
        self.objStockCur.Subscribe()
 
    def Unsubscribe(self):
        self.objStockCur.Unsubscribe()
 
 
 
class CpStockMst:
    def Request(self, code):
        # 연결 여부 체크
        objCpCybos = win32com.client.Dispatch("CpUtil.CpCybos")
        bConnect = objCpCybos.IsConnect
        if (bConnect == 0):
            print("PLUS가 정상적으로 연결되지 않음. ")
            return False
 
        # 현재가 객체 구하기
        objStockMst = win32com.client.Dispatch("DsCbo1.StockMst")
        objStockMst.SetInputValue(0, code)  # 종목 코드 - 한화에어로스페이스
        objStockMst.BlockRequest()
 
        # 현재가 통신 및 통신 에러 처리
        rqStatus = objStockMst.GetDibStatus()
        rqRet = objStockMst.GetDibMsg1()
        print("통신상태", rqStatus, rqRet)
        if rqStatus != 0:
            return False
 
        # 현재가 정보 조회
        code = objStockMst.GetHeaderValue(0)  # 종목코드
        name = objStockMst.GetHeaderValue(1)  # 종목명
        time = objStockMst.GetHeaderValue(4)  # 시간
        cprice = objStockMst.GetHeaderValue(11)  # 종가
        diff = objStockMst.GetHeaderValue(12)  # 대비
        open = objStockMst.GetHeaderValue(13)  # 시가
        high = objStockMst.GetHeaderValue(14)  # 고가
        low = objStockMst.GetHeaderValue(15)  # 저가
        offer = objStockMst.GetHeaderValue(16)  # 매도호가
        bid = objStockMst.GetHeaderValue(17)  # 매수호가
        vol = objStockMst.GetHeaderValue(18)  # 거래량
        vol_value = objStockMst.GetHeaderValue(19)  # 거래대금
 
        print("코드 이름 시간 현재가 대비 시가 고가 저가 매도호가 매수호가 거래량 거래대금")
        print(code, name, time, cprice, diff, open, high, low, offer, bid, vol, vol_value)
        #list2.append([code, name, time, cprice, diff, open, high, low, offer, bid, vol, vol_value])
        #app_df2 = pd.DataFrame(data=list2, columns=['시분초','시가','대비','체결량','거래량'])
        #df2 = pd.concat([zero_df2,app_df2], ignore_index=True)
        #print(df2)
        
        return True
 
 
class MyWindow(QMainWindow):
 
    def __init__(self):
        super().__init__()
        self.setWindowTitle("PLUS API TEST")
        self.setGeometry(300, 300, 300, 150)
        self.isRq = False
        self.objStockMst = CpStockMst()
        self.objStockCur = CpStockCur()
 
        btn1 = QPushButton("요청 시작", self)
        btn1.move(20, 20)
        btn1.clicked.connect(self.btn1_clicked)
 
        btn2 = QPushButton("요청 종료", self)
        btn2.move(20, 70)
        btn2.clicked.connect(self.btn2_clicked)
        # a = pd.DataFrame(data, columns=['시분초','시가','대비','체결량','거래량'])
 
        btn3 = QPushButton("종료", self)
        btn3.move(20, 120)
        btn3.clicked.connect(self.btn3_clicked)

 
    def StopSubscribe(self):
        if self.isRq:
            self.objStockCur.Unsubscribe()
        self.isRq = False
 
    def btn1_clicked(self):
        testCode = "A012450"
        if (self.objStockMst.Request(testCode) == False):
            exit()
 
        # 한화에어로스페이스 실시간 현재가 요청
        self.objStockCur.Subscribe(testCode)

    
        print("빼기빼기=====================================")
        print("실시간 현재가 요청 시작")
        self.isRq = True 
        
    #     JusikTimess = zero_df['시분초'].to_list()
    #     JusikCprice = zero_df['시가'].to_list()
    #     JusikDiff = zero_df['대비'].to_list()
    #     JusikCVol = zero_df['체결량'].to_list()
    #     JusikVol = zero_df['거래량'].to_list()
    #     print(JusikTimess)
    #     for timess, cprice, diff, cvol, vol in zip(JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol):
    #         sql = "INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusicDiff, JusikCVol, JusikVol) VALUES (%s, %s, %s, %s, %s)" % ("'"+timess+"'", "'"+cprice+"'", "'"+diff+"'", "'"+cvol+"'","'"+vol+"'")
    #         print(sql)
    #         cur.execute(sql)
    # conn.commit()


    def btn2_clicked(self):
        self.StopSubscribe()
 
 
    def btn3_clicked(self):
        self.StopSubscribe()
        exit()
        
 
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exec_()


conn.close()
# Out:
# 통신상태 0 0027 조회가 완료되었습니다.(stock.new.mst)
# 코드 이름 시간 현재가 대비 시가 고가 저가 매도호가 매수호가 거래량 거래대금
# A012450 한화에어로스페이스 1434 132000 500 135500 135600 130600 132000 131900 477065 6341302
# 빼기빼기=====================================
# 실시간 현재가 요청 시작
#       시분초      시가   대비 체결량     거래량
# 0  143448  132000  500   1  477066
# [143448]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
#       시분초      시가   대비 체결량     거래량
# 0  143448  132000  500   1  477066
# 1  143451  132000  500  10  477076
# [143448, 143451]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
#       시분초      시가   대비 체결량     거래량
# 0  143448  132000  500   1  477066
# 1  143451  132000  500  10  477076
# 2  143451  132000  500   1  477077
# [143448, 143451, 143451]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
#       시분초      시가   대비 체결량     거래량
# 0  143448  132000  500   1  477066
# 1  143451  132000  500  10  477076
# 2  143451  132000  500   1  477077
# 3  143452  132000  500   5  477082
# [143448, 143451, 143451, 143452]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
#       시분초      시가   대비 체결량     거래량
# 0  143448  132000  500   1  477066
# 1  143451  132000  500  10  477076
# 2  143451  132000  500   1  477077
# 3  143452  132000  500   5  477082
# 4  143456  132000  500   5  477087
# [143448, 143451, 143451, 143452, 143456]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
#       시분초      시가   대비 체결량     거래량
# 0  143448  132000  500   1  477066
# 1  143451  132000  500  10  477076
# 2  143451  132000  500   1  477077
# 3  143452  132000  500   5  477082
# 4  143456  132000  500   5  477087
# 5  143457  132000  500   1  477088
# [143448, 143451, 143451, 143452, 143456, 143457]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
#       시분초      시가   대비 체결량     거래량
# 0  143448  132000  500   1  477066
# 1  143451  132000  500  10  477076
# 2  143451  132000  500   1  477077
# 3  143452  132000  500   5  477082
# 4  143456  132000  500   5  477087
# 5  143457  132000  500   1  477088
# 6  143457  132000  500   4  477092
# [143448, 143451, 143451, 143452, 143456, 143457, 143457]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '4', '477092')

# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143538', '132000', '500', '250', '477378')
#        시분초      시가   대비  체결량     거래량
# 0   143448  132000  500    1  477066
# 1   143451  132000  500   10  477076
# 2   143451  132000  500    1  477077
# 3   143452  132000  500    5  477082
# 4   143456  132000  500    5  477087
# 5   143457  132000  500    1  477088
# 6   143457  132000  500    4  477092
# 7   143503  132000  500    1  477093
# 8   143514  132000  500    5  477098
# 9   143514  132000  500    4  477102
# 10  143527  132000  500   17  477119
# 11  143527  132000  500    1  477120
# 12  143528  131900  400    5  477125
# 13  143534  132000  500    1  477126
# 14  143536  132000  500    1  477127
# 15  143536  132000  500    1  477128
# 16  143538  132000  500  250  477378
# 17  143539  132000  500    1  477379
# [143448, 143451, 143451, 143452, 143456, 143457, 143457, 143503, 143514, 143514, 143527, 143527, 143528, 143534, 143536, 143536, 143538, 143539]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '4', '477092')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143503', '132000', '500', '1', '477093')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '5', '477098')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '4', '477102')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '17', '477119')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '1', '477120')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143528', '131900', '400', '5', '477125')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143534', '132000', '500', '1', '477126')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477127')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477128')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143538', '132000', '500', '250', '477378')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '132000', '500', '1', '477379')
#        시분초      시가   대비  체결량     거래량
# 0   143448  132000  500    1  477066
# 1   143451  132000  500   10  477076
# 2   143451  132000  500    1  477077
# 3   143452  132000  500    5  477082
# 4   143456  132000  500    5  477087
# 5   143457  132000  500    1  477088
# 6   143457  132000  500    4  477092
# 7   143503  132000  500    1  477093
# 8   143514  132000  500    5  477098
# 9   143514  132000  500    4  477102
# 10  143527  132000  500   17  477119
# 11  143527  132000  500    1  477120
# 12  143528  131900  400    5  477125
# 13  143534  132000  500    1  477126
# 14  143536  132000  500    1  477127
# 15  143536  132000  500    1  477128
# 16  143538  132000  500  250  477378
# 17  143539  132000  500    1  477379
# 18  143539  131900  400   10  477389
# [143448, 143451, 143451, 143452, 143456, 143457, 143457, 143503, 143514, 143514, 143527, 143527, 143528, 143534, 143536, 143536, 143538, 143539, 143539]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '4', '477092')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143503', '132000', '500', '1', '477093')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '5', '477098')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '4', '477102')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '17', '477119')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '1', '477120')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143528', '131900', '400', '5', '477125')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143534', '132000', '500', '1', '477126')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477127')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477128')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143538', '132000', '500', '250', '477378')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '132000', '500', '1', '477379')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '131900', '400', '10', '477389')
#        시분초      시가   대비  체결량     거래량
# 0   143448  132000  500    1  477066
# 1   143451  132000  500   10  477076
# 2   143451  132000  500    1  477077
# 3   143452  132000  500    5  477082
# 4   143456  132000  500    5  477087
# 5   143457  132000  500    1  477088
# 6   143457  132000  500    4  477092
# 7   143503  132000  500    1  477093
# 8   143514  132000  500    5  477098
# 9   143514  132000  500    4  477102
# 10  143527  132000  500   17  477119
# 11  143527  132000  500    1  477120
# 12  143528  131900  400    5  477125
# 13  143534  132000  500    1  477126
# 14  143536  132000  500    1  477127
# 15  143536  132000  500    1  477128
# 16  143538  132000  500  250  477378
# 17  143539  132000  500    1  477379
# 18  143539  131900  400   10  477389
# 19  143543  132000  500    1  477390
# [143448, 143451, 143451, 143452, 143456, 143457, 143457, 143503, 143514, 143514, 143527, 143527, 143528, 143534, 143536, 143536, 143538, 143539, 143539, 143543]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '4', '477092')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143503', '132000', '500', '1', '477093')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '5', '477098')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '4', '477102')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '17', '477119')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '1', '477120')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143528', '131900', '400', '5', '477125')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143534', '132000', '500', '1', '477126')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477127')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477128')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143538', '132000', '500', '250', '477378')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '132000', '500', '1', '477379')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '131900', '400', '10', '477389')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143543', '132000', '500', '1', '477390')
#        시분초      시가   대비  체결량     거래량
# 0   143448  132000  500    1  477066
# 1   143451  132000  500   10  477076
# 2   143451  132000  500    1  477077
# 3   143452  132000  500    5  477082
# 4   143456  132000  500    5  477087
# 5   143457  132000  500    1  477088
# 6   143457  132000  500    4  477092
# 7   143503  132000  500    1  477093
# 8   143514  132000  500    5  477098
# 9   143514  132000  500    4  477102
# 10  143527  132000  500   17  477119
# 11  143527  132000  500    1  477120
# 12  143528  131900  400    5  477125
# 13  143534  132000  500    1  477126
# 14  143536  132000  500    1  477127
# 15  143536  132000  500    1  477128
# 16  143538  132000  500  250  477378
# 17  143539  132000  500    1  477379
# 18  143539  131900  400   10  477389
# 19  143543  132000  500    1  477390
# 20  143548  131900  400    9  477399
# [143448, 143451, 143451, 143452, 143456, 143457, 143457, 143503, 143514, 143514, 143527, 143527, 143528, 143534, 143536, 143536, 143538, 143539, 143539, 143543, 143548]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '4', '477092')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143503', '132000', '500', '1', '477093')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '5', '477098')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '4', '477102')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '17', '477119')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '1', '477120')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143528', '131900', '400', '5', '477125')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143534', '132000', '500', '1', '477126')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477127')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477128')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143538', '132000', '500', '250', '477378')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '132000', '500', '1', '477379')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '131900', '400', '10', '477389')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143543', '132000', '500', '1', '477390')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143548', '131900', '400', '9', '477399')
#        시분초      시가   대비  체결량     거래량
# 0   143448  132000  500    1  477066
# 1   143451  132000  500   10  477076
# 2   143451  132000  500    1  477077
# 3   143452  132000  500    5  477082
# 4   143456  132000  500    5  477087
# 5   143457  132000  500    1  477088
# 6   143457  132000  500    4  477092
# 7   143503  132000  500    1  477093
# 8   143514  132000  500    5  477098
# 9   143514  132000  500    4  477102
# 10  143527  132000  500   17  477119
# 11  143527  132000  500    1  477120
# 12  143528  131900  400    5  477125
# 13  143534  132000  500    1  477126
# 14  143536  132000  500    1  477127
# 15  143536  132000  500    1  477128
# 16  143538  132000  500  250  477378
# 17  143539  132000  500    1  477379
# 18  143539  131900  400   10  477389
# 19  143543  132000  500    1  477390
# 20  143548  131900  400    9  477399
# 21  143548  132000  500    5  477404
# [143448, 143451, 143451, 143452, 143456, 143457, 143457, 143503, 143514, 143514, 143527, 143527, 143528, 143534, 143536, 143536, 143538, 143539, 143539, 143543, 143548, 143548]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '4', '477092')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143503', '132000', '500', '1', '477093')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '5', '477098')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '4', '477102')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '17', '477119')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '1', '477120')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143528', '131900', '400', '5', '477125')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143534', '132000', '500', '1', '477126')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477127')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477128')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143538', '132000', '500', '250', '477378')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '132000', '500', '1', '477379')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '131900', '400', '10', '477389')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143543', '132000', '500', '1', '477390')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143548', '131900', '400', '9', '477399')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143548', '132000', '500', '5', '477404')
#        시분초      시가   대비  체결량     거래량
# 0   143448  132000  500    1  477066
# 1   143451  132000  500   10  477076
# 2   143451  132000  500    1  477077
# 3   143452  132000  500    5  477082
# 4   143456  132000  500    5  477087
# 5   143457  132000  500    1  477088
# 6   143457  132000  500    4  477092
# 7   143503  132000  500    1  477093
# 8   143514  132000  500    5  477098
# 9   143514  132000  500    4  477102
# 10  143527  132000  500   17  477119
# 11  143527  132000  500    1  477120
# 12  143528  131900  400    5  477125
# 13  143534  132000  500    1  477126
# 14  143536  132000  500    1  477127
# 15  143536  132000  500    1  477128
# 16  143538  132000  500  250  477378
# 17  143539  132000  500    1  477379
# 18  143539  131900  400   10  477389
# 19  143543  132000  500    1  477390
# 20  143548  131900  400    9  477399
# 21  143548  132000  500    5  477404
# 22  143552  132000  500    1  477405
# ...
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143604', '132000', '500', '20', '477441')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143607', '132000', '500', '1', '477442')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143608', '132000', '500', '1', '477443')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '132000', '500', '6', '477449')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '131900', '400', '1', '477450')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '132000', '500', '1', '477451')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '131900', '400', '1', '477452')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143619', '132000', '500', '1', '477453')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143620', '132000', '500', '37', '477490')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143622', '132000', '500', '5', '477495')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143626', '131900', '400', '5', '477500')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143626', '132000', '500', '30', '477530')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143629', '132000', '500', '8', '477538')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143632', '132000', '500', '1', '477539')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143637', '132000', '500', '13', '477552')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '1', '477553')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '2', '477555')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '1', '477556')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '4', '477560')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143643', '132000', '500', '12', '477572')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143644', '132000', '500', '1', '477573')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143647', '132000', '500', '2', '477575')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143648', '132000', '500', '9', '477584')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143653', '132000', '500', '2', '477586')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143654', '132000', '500', '11', '477597')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143654', '132000', '500', '12', '477609')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143656', '132000', '500', '4', '477613')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143659', '132000', '500', '1', '477614')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143700', '131900', '400', '6', '477620')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143700', '131900', '400', '2', '477622')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143700', '131900', '400', '11', '477633')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '132000', '500', '12', '477645')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '132000', '500', '37', '477682')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '131900', '400', '4', '477686')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '132000', '500', '1', '477687')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143702', '132000', '500', '12', '477699')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143704', '132000', '500', '1', '477700')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143709', '132000', '500', '14', '477714')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143709', '132000', '500', '22', '477736')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143715', '132000', '500', '12', '477748')
#        시분초      시가   대비 체결량     거래량
# 0   143448  132000  500   1  477066
# 1   143451  132000  500  10  477076
# 2   143451  132000  500   1  477077
# 3   143452  132000  500   5  477082
# 4   143456  132000  500   5  477087
# ..     ...     ...  ...  ..     ...
# 64  143704  132000  500   1  477700
# 65  143709  132000  500  14  477714
# 66  143709  132000  500  22  477736
# 67  143715  132000  500  12  477748
# 68  143715  132000  500   1  477749
#
# [69 rows x 5 columns]
# [143448, 143451, 143451, 143452, 143456, 143457, 143457, 143503, 143514, 143514, 143527, 143527, 143528, 143534, 143536, 143536, 143538, 143539, 143539, 143543, 143548, 143548, 143552, 143552, 143556, 143558, 143559, 143602, 143604, 143607, 143608, 143609, 143609, 143609, 143609, 143619, 143620, 143622, 143626, 143626, 143629, 143632, 143637, 143642, 143642, 143642, 143642, 143643, 143644, 143647, 143648, 143653, 143654, 143654, 143656, 143659, 143700, 143700, 143700, 143701, 143701, 143701, 143701, 143702, 143704, 143709, 143709, 143715, 143715]
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143448', '132000', '500', '1', '477066')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '10', '477076')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143451', '132000', '500', '1', '477077')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143452', '132000', '500', '5', '477082')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143456', '132000', '500', '5', '477087')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '1', '477088')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143457', '132000', '500', '4', '477092')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143503', '132000', '500', '1', '477093')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '5', '477098')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143514', '132000', '500', '4', '477102')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '17', '477119')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143527', '132000', '500', '1', '477120')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143528', '131900', '400', '5', '477125')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143534', '132000', '500', '1', '477126')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477127')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143536', '132000', '500', '1', '477128')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143538', '132000', '500', '250', '477378')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '132000', '500', '1', '477379')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143539', '131900', '400', '10', '477389')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143543', '132000', '500', '1', '477390')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143548', '131900', '400', '9', '477399')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143548', '132000', '500', '5', '477404')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143552', '132000', '500', '1', '477405')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143552', '132000', '500', '5', '477410')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143556', '132000', '500', '1', '477411')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143558', '132000', '500', '1', '477412')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143559', '132000', '500', '1', '477413')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143602', '132000', '500', '8', '477421')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143604', '132000', '500', '20', '477441')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143607', '132000', '500', '1', '477442')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143608', '132000', '500', '1', '477443')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '132000', '500', '6', '477449')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '131900', '400', '1', '477450')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '132000', '500', '1', '477451')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143609', '131900', '400', '1', '477452')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143619', '132000', '500', '1', '477453')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143620', '132000', '500', '37', '477490')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143622', '132000', '500', '5', '477495')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143626', '131900', '400', '5', '477500')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143626', '132000', '500', '30', '477530')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143629', '132000', '500', '8', '477538')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143632', '132000', '500', '1', '477539')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143637', '132000', '500', '13', '477552')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '1', '477553')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '2', '477555')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '1', '477556')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143642', '132000', '500', '4', '477560')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143643', '132000', '500', '12', '477572')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143644', '132000', '500', '1', '477573')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143647', '132000', '500', '2', '477575')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143648', '132000', '500', '9', '477584')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143653', '132000', '500', '2', '477586')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143654', '132000', '500', '11', '477597')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143654', '132000', '500', '12', '477609')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143656', '132000', '500', '4', '477613')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143659', '132000', '500', '1', '477614')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143700', '131900', '400', '6', '477620')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143700', '131900', '400', '2', '477622')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143700', '131900', '400', '11', '477633')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '132000', '500', '12', '477645')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '132000', '500', '37', '477682')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '131900', '400', '4', '477686')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143701', '132000', '500', '1', '477687')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143702', '132000', '500', '12', '477699')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143704', '132000', '500', '1', '477700')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143709', '132000', '500', '14', '477714')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143709', '132000', '500', '22', '477736')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143715', '132000', '500', '12', '477748')
# INSERT INTO jusik_tic_chart (JusikTimess, JusikCprice, JusikDiff, JusikCVol, JusikVol) VALUES ('143715', '132000', '500', '1', '477749')

# %%
    # def real_jusik_tic():

    #     JusikTimess = zero_df['시분초'].to_list
    #     JusikCprice = zero_df['시가'].to_list
    #     JusikDiff = zero_df['대비'].to_list
    #     JusikCVol = zero_df['체결량'].to_list
    #     JusikVol = zero_df['거래량'].to_list

    #     for timess, cprice, diff, cvol, vol in zip(JusikTimess,JusikCprice,JusikDiff,JusikCVol,JusikVol):
    #         sql = "INSERT INTO jusik_tic_chart (JusikTimess,JusikCprice,JusikDiff,JusikCVol,JusikVol) VALUES (%s, %s, %s, %s, %s)" % ("'"+시분초+"'", "'"+시가+"'", "'"+대비+"'", "'"+체결량+"'", "'"+거래량+"'")
    #         print(sql)
    #         cur.execute(sql)

    #     conn.commit()
