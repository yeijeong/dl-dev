# %%
import urllib.request
from bs4 import BeautifulSoup
from urllib import parse
from datetime import datetime
import datetime

import pandas as pd
import time

import pythoncom
import time

import pymysql

conn = pymysql.connect(
    host='34.64.240.96'
    , user='root'
    , password='tndusWkd1.'
    , db='final_project'
    , charset='utf8'
)
cur = conn.cursor()

# %%
basic_url = "https://finance.naver.com/sise/" # 코스피
exchange_url = "https://finance.naver.com/marketindex/" # 환율


# 현재 시간을 기록

stoptime = datetime.datetime.now().time()
while True:
    if stoptime.strftime('%p') == 'PM' and stoptime.hour == 3 and stoptime.minute >= 30: # 오후 3시 반 이후인지 확인
        break # 3시 30에 멈추는 코드
    else:
        fp = urllib.request.urlopen(basic_url) # 3시30이 아니면 계속 실행
        source = fp.read()
        fp.close() 

        soup = BeautifulSoup(source, 'html.parser')
        soup = soup.findAll("span",class_="num")
        kospi_value = soup[1].string #코스피 지수
        # now = pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
        
        #환율 실시간
        exchange_url = "https://finance.naver.com/marketindex/"
        fp = urllib.request.urlopen(exchange_url)
        source = fp.read()
        fp.close()

        soup = BeautifulSoup(source, 'html.parser')
        soup = soup.findAll("span",class_="value")

        # 결과값을 변수에 저장
        exchange = soup[0].string #미국환율 지수
        now = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        re_time = now

        # df = pd.DataFrame([{'re_time': now, 'kospi': kospi_value, 'exchange': exchange}])
        # print(df)
        sql = "INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES (%s, %s, %s)" % ("'"+now+"'", "'"+kospi_value+"'", "'"+exchange+"'")
        cur.execute(sql)
        print(sql)
        conn.commit()

        time.sleep(40)
# Out:
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 11:59:14', '2,601.73', '1,268.50')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 11:59:55', '2,601.73', '1,268.50')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:00:37', '2,601.71', '1,268.70')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:01:19', '2,600.93', '1,268.70')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:02:00', '2,600.93', '1,268.70')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:02:42', '2,600.74', '1,269.10')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:03:24', '2,601.80', '1,268.90')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:04:05', '2,601.64', '1,268.90')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:04:47', '2,601.64', '1,268.90')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:05:29', '2,600.74', '1,268.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:06:11', '2,601.21', '1,268.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:06:52', '2,601.21', '1,268.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:07:34', '2,601.32', '1,268.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:08:17', '2,601.53', '1,268.90')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:08:58', '2,601.53', '1,269.10')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:09:40', '2,602.77', '1,268.50')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:10:22', '2,601.63', '1,268.50')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:11:04', '2,601.49', '1,268.70')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:11:45', '2,601.49', '1,268.50')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:12:27', '2,602.04', '1,268.50')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:13:08', '2,602.51', '1,268.30')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:13:50', '2,602.51', '1,268.30')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:14:32', '2,603.35', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:15:13', '2,602.86', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:15:55', '2,602.86', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:16:36', '2,602.26', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:17:18', '2,602.97', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:17:59', '2,602.97', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:18:41', '2,602.43', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:19:22', '2,602.50', '1,268.20')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:20:04', '2,603.09', '1,268.20')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:20:45', '2,603.09', '1,268.20')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:21:27', '2,602.12', '1,268.20')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:22:08', '2,603.01', '1,268.20')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:22:50', '2,603.01', '1,268.20')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:23:31', '2,602.62', '1,268.20')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:24:13', '2,603.36', '1,268.30')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:24:54', '2,603.36', '1,268.30')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:25:36', '2,603.18', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:26:17', '2,602.89', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:26:58', '2,602.89', '1,267.80')
# INSERT INTO kospi_exchage_real (Ymd_Time, Kospi, Exchange) VALUES ('2023-07-19 12:27:40', '2,603.07', '1,268.00')
