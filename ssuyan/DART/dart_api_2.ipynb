# %% [markdown]
# ##### 참고 url : https://progr-account.tistory.com/32
# - 기업 개황 불러오기

# %%
### 필요한 모듈
from urllib.request import urlopen
from io import BytesIO
from zipfile import ZipFile
import xml.etree.ElementTree as ET

# %% [markdown]
# ##### 기업 개황 불러오기 : 각각 검색하여 하나씩 조회하기

# %%
### 회사고유번호 데이터 불러오기
url = 'https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key=3d218f72d3a558aa85ff91f2a0f2d720e3158223'
with urlopen(url) as zipresp:
    with ZipFile(BytesIO(zipresp.read())) as zfile:
        zfile.extractall('corp_num')

# %%
### 압축파일 안의 xml 파일 읽기
tree = ET.parse('./corp_num/CORPCODE.xml')
root = tree.getroot()

# %%
### 회사 이름으로 회사 고유번호 찾기
def find_corp_num(find_name):
    for country in root.iter("list"):
        if country.findtext("corp_name") == find_name:
            return country.findtext("corp_code")

# %%
find_corp_num('삼성전자')
# Out:
# '00126380'

# %%
### 모듈 import
import requests

def load_data(**kwargs):
    ### 본인의 인정키 입력
    crtfc_key = "3d218f72d3a558aa85ff91f2a0f2d720e3158223"
    ### load_data 함수 입력을 통해 corp_code 를 받기로 한다.
    corp_code = kwargs['corp_code']
    
    ###기업개황 요청하면
    if kwargs['request'] == 'company':
        
        ### 기업개황 요청 url
        url = 'https://opendart.fss.or.kr/api/company.json?crtfc_key='+crtfc_key+'&corp_code='+corp_code
        
        ### HTTP 요청
        r = requests.get(url)
        
        ### 요청한 데이터는 json형태이기 때문에 json으로 읽어줍니다.
        company_data = r.json()
        
        ### 기업개황을 요청했을 때 기업개황에 대한 자료를 반환합니다.
        return company_data

# %%
load_data(request='company', corp_code=find_corp_num('삼성전자'))
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '한종희, 경계현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.samsung.com/sec',
#  'ir_url': '',
#  'phn_no': '02-2255-0114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %% [markdown]
# ##### 기업개황 불러오기 : 상장된 모든 기업의 개황정보 다운로드 -> pickle을 이용하여 파일 내에서 검색

# %%
### stock_code 가 있는 기업의 corp_code만 code_list에 추가
### 상장회사가 아닌경우 기업개황 외의 API 서비스가 제공되지 않기때문
code_list=[]
for x in range(len(root)):
    
    #root[0][0].tag = 'corp_code'
    #root[0][1].tag = 'corp_name'
    #root[0][2].tag = 'stock_code'
    
    ### stock_cdoe 가 없는게 아니라면 => stock_code가 있다면
    if root[x][2].text != " ":
        code_list.append(root[x][0].text)
### stock_code 가 있는 기업의 갯수 확인        
len(code_list)
# Out:
# 3588

# %%
### xml 모듈 import
import xml.etree.ElementTree as ET

import warnings
warnings.filterwarnings('ignore')

### xml 파일 읽기
tree = ET.parse('./corp_num/CORPCODE.xml')
root = tree.getroot()

# %%
### stock_code 가 있는 기업의 corp_code만 code_list에 추가
### 상장회사가 아닌경우 기업개황 외의 API 서비스가 제공되지 않기때문
code_list=[]
for x in range(len(root)):
    
    #root[0][0].tag = 'corp_code'
    #root[0][1].tag = 'corp_name'
    #root[0][2].tag = 'stock_code'
    
    ### stock_cdoe 가 없는게 아니라면 => stock_code가 있다면
    if root[x][2].text is not " ":
        code_list.append(root[x][0].text)
### stock_code 가 있는 기업의 갯수 확인        
len(code_list)
# Out:
# 3588

# %%
### HTTP 요청
import requests

### 기업개황 불러오기 함수
def load_data(corp_code):
    ### 본인의 인정키 입력
    crtfc_key = "3d218f72d3a558aa85ff91f2a0f2d720e3158223"
    ### 기업개황 요청 url
    url = 'https://opendart.fss.or.kr/api/company.json?crtfc_key='+crtfc_key+'&corp_code='+corp_code
    ### HTTP 요청
    r = requests.get(url, verify=False)
    ### 요청한 데이터는 json형태이기 때문에 json으로 읽어줍니다.
    company_data = r.json()
    ### 기업개황을 요청했을 때 기업개황에 대한 자료를 dict type 으로 반환합니다.
    return company_data

# %%
### 진행상황을 표시해줄 모듈 import
from tqdm import tqdm_notebook

### 기업 개황을 담을 list 생성
company_condition_list = []

### 3179개 기업황을 불러오는데는 시간이 오래 걸리므로 tqdm 모듈을 사용해 진행상황을 표시하겠습니다.
for corp_code in tqdm_notebook(code_list):
    ### load_data 함수를 통해 불러온 기업개황 dict를 company_dict을 변수로 저장합니다.
    company_dict = load_data(corp_code)
    ### 기업개황 리스트에 company_dict를 추가합니다.
    company_condition_list.append(company_dict)
# Out:
#   0%|          | 0/3588 [00:00<?, ?it/s]

# %%
### pickle 모듈 import
import pickle

### pickle 모듈을 통해 list 저장
with open('./corp_num/company_condition_list.txt','wb') as f:
       pickle.dump(company_condition_list,f)

# %%
### Pnadas DataFrame 모듈 import
import pandas as pd

pd_data = pd.DataFrame.from_dict(company_condition_list)
pd_data
# Out:
#      status message corp_code         corp_name  \
# 0       000      정상  00260985              한빛네트
# 1       000      정상  00264529           (주)엔플렉스
# 2       000      정상  00358545         (주)동서정보기술
# 3       000      정상  00231567        주식회사 애드모바일
# 4       000      정상  00247939            (주)씨모스
# ...     ...     ...       ...               ...
# 3583    000      정상  00296078          (주)에이피에스
# 3584    000      정상  01118643  (주)로보쓰리에이아이앤로보틱스
# 3585    000      정상  00624518         (주)다산솔루에타
# 3586    000      정상  01065679         (주)알비케이그룹
# 3587    000      정상  00624378        (주)마이크로투나노
#
#                                   corp_name_eng     stock_name stock_code  \
# 0                               HanbitNet, Inc.           한빛네트     036720
# 1                                    Nplex,Inc.           엔플렉스     040130
# 2     Dong Seo Information Technology Co., Ltd.         동서정보기술     055000
# 3                                                        애드모바일     032600
# 4     creative master of semiconductor. co.,ltd            씨모스     037600
# ...                                         ...            ...        ...
# 3583                                   APS Inc.            APS     054620
# 3584               Robo3 Ai & Robotics co., Ltd  로보쓰리에이아이앤로보틱스     238500
# 3585                     Dasan Solueta Co.,Ltd.         다산솔루에타     154040
# 3586                             RBK GROUP INC.         알비케이그룹     215790
# 3587                           MICRO2NANO, INC.        마이크로투나노     424980
#
#                  ceo_nm corp_cls       jurir_no     bizr_no  \
# 0                   강승환        E  1101111443079  2088124283
# 1                 이 정 학        E  1101111601750  2208156354
# 2                   이희봉        E  1101111259525  2208103653
# 3                   김용석        E  1101111166837  1208151156
# 4                   유인엽        E  1201110118077  1398120545
# ...                 ...      ...            ...         ...
# 3583                정기로        K  1101111315286  2298122962
# 3584  심종헌, 박영근(각자 대표이사)        N  1101112858483  2068184723
# 3585                양삼주        K  1351110065750  1238189952
# 3586                 한혁        K  1101115658640  4478700025
# 3587                황규호        K  1101112059031  1198141599
#
#                                   adres                 hm_url  \
# 0                    서울특별시 종로구 익선동 30-6      www.hanbitnet.com
# 1              서울특별시 강남구 논현동 98 동익빌딩 2층      www.gamekorea.net
# 2                  서울특별시 강남구 대치동 997-4   http://www.dsit.co.kr
# 3          서울특별시 강서구 가양동 1458-9 동남빌딩 2층       www.kdline.co.kr
# 4                   인천광역시 남동구 고잔동 685-6       www.cmos21.co.kr
# ...                                 ...                    ...
# 3583     경기도 화성시 동탄면 동탄산단9길 23-12 (동탄면)  www.apsholdings.co.kr
# 3584  서울특별시 강남구 봉은사로18길 47(역삼동622-7) 전층          www.robo3.com
# 3585           경기도 화성시 마도면 해운로 498-42 -        www.solueta.com
# 3586  인천광역시 연수구 송도미래로 30 송도스마트밸리 E-2206
# 3587      경기도 용인시 처인구 이동읍 덕성산단2로50번길 43         micro2nano.com
#
#                                  ir_url             phn_no          fax_no  \
# 0                                             02-3668-0114    02-3668-0112
# 1                                           (02) 3453-7111  (02) 3453-7345
# 2                                        02-565-4510 (220)    02-3453-4552
# 3                                        02-518-0101 (변광섭)     02-518-0133
# 4                                           032-814-0981-4    032-814-0985
# ...                                 ...                ...             ...
# 3583                                          031-776-1800    031-776-1900
# 3584                      www.robo3.com        02-544-9145     02-544-9146
# 3585  http://www.solueta.com/kr/m51.php       031-508-2655    031-508-2606
# 3586                                           02-750-5644
# 3587                                          031-659-7900    031-659-7979
#
#      induty_code    est_dt acc_mt
# 0          58221  19970722     12
# 1          58221  19981030     12
# 2          58221  19960410     12
# 3          58221  19950614     12
# 4          29294  19950509     12
# ...          ...       ...    ...
# 3583       64992  19960829     12
# 3584         739  20030917     12
# 3585        2629  20030627     12
# 3586         264  20150306     12
# 3587       26129  20000828     12
#
# [3588 rows x 19 columns]

# %%
with open('./corp_num/company_condition_list.txt','rb') as f:
	company_condition_list=pickle.load(f) ### 상장기업 기업개황을 company_condition_list에 저장
len(company_condition_list)
# Out:
# 3588

# %%
print(type(company_condition_list[0])) ### list 요소의 type 확인
print(company_condition_list[0].keys()) ### dict key list 확인
# Out:
# <class 'dict'>
# dict_keys(['status', 'message', 'corp_code', 'corp_name', 'corp_name_eng', 'stock_name', 'stock_code', 'ceo_nm', 'corp_cls', 'jurir_no', 'bizr_no', 'adres', 'hm_url', 'ir_url', 'phn_no', 'fax_no', 'induty_code', 'est_dt', 'acc_mt'])

# %%
### 함수 생성 : 조건에 맞는 회사의 기업개황 list 반환
def find_condition(**kwargs):
    
    ### 저장된 상장기업 개황 list 불러오기
    with open('company_condition_list.txt','rb') as f:
        company_condition_list=pickle.load(f)
    
    ### 결과값을 반환할 list
    return_list = []
    
    try:
        ### 필수입력사항
        key = kwargs['key'] # 기업개황 dict 의 조건에 맞는 key
        value = kwargs['value'] # 기업개황 dict 의 조건에 맞는 value
    except:
        key = None
        value  = None
    
    ### 선택입력사항
    ### select == same 이면 value 와 일치하는것만
    ### select is not same 이면 value 가 포함된 모든것을 return 합니다.
    try:
        select = kwargs['select']
        print(select)
    except:
        select = None

    ### select == all 이면 모든 기업개황 반환
    if select == 'all': 
        return_list = company_condition_list

    ### select == same 이면 value 와 일치하는것만
    elif select == 'same':
        for company_condition in  company_condition_list:
            if value == company_condition[key]:
                return_list.append(company_condition)

    ### select is not same 이면 value 가 포함된 모든것
    else :
        for company_condition in company_condition_list:
            if value in company_condition[key]:
                return_list.append(company_condition)

    return return_list

# %%
# 모든 회사의 기업개황 불러오기
find_condition(select='all')
# Out:
# all
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00260985',
#   'corp_name': '한빛네트',
#   'corp_name_eng': 'HanbitNet, Inc.',
#   'stock_name': '한빛네트',
#   'stock_code': '036720',
#   'ceo_nm': '강승환',
#   'corp_cls': 'E',
#   'jurir_no': '1101111443079',
#   'bizr_no': '2088124283',
#   'adres': '서울특별시 종로구 익선동 30-6',
#   'hm_url': 'www.hanbitnet.com',
#   'ir_url': '',
#   'phn_no': '02-3668-0114',
#   'fax_no': '02-3668-0112',
#   'induty_code': '58221',
#   'est_dt': '19970722',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00264529',
#   'corp_name': '(주)엔플렉스',
#   'corp_name_eng': 'Nplex,Inc.',
#   'stock_name': '엔플렉스',
#   'stock_code': '040130',
#   'ceo_nm': '이 정 학',
#   'corp_cls': 'E',
#   'jurir_no': '1101111601750',
#   'bizr_no': '2208156354',
#   'adres': '서울특별시 강남구 논현동 98 동익빌딩 2층',
#   'hm_url': 'www.gamekorea.net',
#   'ir_url': '',
#   'phn_no': '(02) 3453-7111',
#   'fax_no': '(02) 3453-7345',
#   'induty_code': '58221',
#   'est_dt': '19981030',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00358545',
#   'corp_name': '(주)동서정보기술',
#   'corp_name_eng': 'Dong Seo Information Technology Co., Ltd.',
#   'stock_name': '동서정보기술',
#   'stock_code': '055000',
#   'ceo_nm': '이희봉',
#   'corp_cls': 'E',
#   'jurir_no': '1101111259525',
#   'bizr_no': '2208103653',
#   'adres': '서울특별시 강남구 대치동 997-4 ',
#   'hm_url': 'http://www.dsit.co.kr',
#   'ir_url': '',
#   'phn_no': '02-565-4510 (220)',
#   'fax_no': '02-3453-4552',
#   'induty_code': '58221',
#   'est_dt': '19960410',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00231567',
#   'corp_name': '주식회사 애드모바일',
#   'corp_name_eng': '',
#   'stock_name': '애드모바일',
#   'stock_code': '032600',
#   'ceo_nm': '김용석',
#   'corp_cls': 'E',
#   'jurir_no': '1101111166837',
#   'bizr_no': '1208151156',
#   'adres': '서울특별시 강서구 가양동 1458-9 동남빌딩 2층',
#   'hm_url': 'www.kdline.co.kr',
#   'ir_url': '',
#   'phn_no': '02-518-0101 (변광섭)',
#   'fax_no': '02-518-0133',
#   'induty_code': '58221',
#   'est_dt': '19950614',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00247939',
#   'corp_name': '(주)씨모스',
#   'corp_name_eng': 'creative master of semiconductor. co.,ltd',
#   'stock_name': '씨모스',
#   'stock_code': '037600',
#   'ceo_nm': '유인엽',
#   'corp_cls': 'E',
#   'jurir_no': '1201110118077',
#   'bizr_no': '1398120545',
#   'adres': '인천광역시 남동구 고잔동 685-6',
#   'hm_url': 'www.cmos21.co.kr',
#   'ir_url': '',
#   'phn_no': '032-814-0981-4',
#   'fax_no': '032-814-0985',
#   'induty_code': '29294',
#   'est_dt': '19950509',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00359614',
#   'corp_name': '(주)리더컴',
#   'corp_name_eng': 'LEADER COMM.Co.,Ltd',
#   'stock_name': '리더컴',
#   'stock_code': '056140',
#   'ceo_nm': '박문기',
#   'corp_cls': 'E',
#   'jurir_no': '1101111571755',
#   'bizr_no': '2208153788',
#   'adres': '경기도 화성시 장안면 수촌리 877-23',
#   'hm_url': 'http://leadercomm.co.kr',
#   'ir_url': '',
#   'phn_no': '031-351-3751',
#   'fax_no': '031-351-3750',
#   'induty_code': '26410',
#   'est_dt': '19980801',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00153551',
#   'corp_name': '(주)허메스홀딩스',
#   'corp_name_eng': 'Hermesholdings Co.,LTD',
#   'stock_name': '허메스홀딩스',
#   'stock_code': '012400',
#   'ceo_nm': '김광선',
#   'corp_cls': 'E',
#   'jurir_no': '1101110216047',
#   'bizr_no': '1198105220',
#   'adres': '서울특별시 강남구 삼성동 159 코엑스상사전시장 C-28 ',
#   'hm_url': 'www.hermesholdings.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2071-0900',
#   'fax_no': '02-2071-0901',
#   'induty_code': '26429',
#   'est_dt': '19770705',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00344746',
#   'corp_name': '(주)유티엑스',
#   'corp_name_eng': 'UTX CO.,LTD.',
#   'stock_name': '유티엑스',
#   'stock_code': '045880',
#   'ceo_nm': '이성암',
#   'corp_cls': 'E',
#   'jurir_no': '1201110163250',
#   'bizr_no': '1398134831',
#   'adres': '서울특별시 금천구 가산동 371-28 우림라이온스밸리 B동 13층 ',
#   'hm_url': 'www.i-utx.com',
#   'ir_url': '',
#   'phn_no': '02-2103-3000',
#   'fax_no': '02-2103-3100',
#   'induty_code': '26410',
#   'est_dt': '19971212',
#   'acc_mt': '09'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00261188',
#   'corp_name': '(주)글로포스트',
#   'corp_name_eng': 'Glopost CO., Ltd.',
#   'stock_name': '글로포스트',
#   'stock_code': '037830',
#   'ceo_nm': '문원호',
#   'corp_cls': 'E',
#   'jurir_no': '1101111569958',
#   'bizr_no': '2148624959',
#   'adres': '서울특별시 서초구 잠원동 28-1 ',
#   'hm_url': 'www.glopost.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2106-7500',
#   'fax_no': '025110877',
#   'induty_code': '58221',
#   'est_dt': '19980728',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00268020',
#   'corp_name': '(주)쏠라엔텍',
#   'corp_name_eng': 'SOLAR & TECH CO., LTD.',
#   'stock_name': '쏠라엔텍',
#   'stock_code': '030390',
#   'ceo_nm': '김 재 철, 이 동 화 (각자대표)',
#   'corp_cls': 'E',
#   'jurir_no': '1101110191900',
#   'bizr_no': '1168120163',
#   'adres': '서울특별시 서초구 서초동 1677-14 케이비빌딩 4,5층 ',
#   'hm_url': 'www.dubank.co.kr',
#   'ir_url': '',
#   'phn_no': '02-525-1110',
#   'fax_no': '02-525-2420',
#   'induty_code': '46599',
#   'est_dt': '19760216',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00269287',
#   'corp_name': '(주)보홍',
#   'corp_name_eng': 'Bohong Co.,Ltd.',
#   'stock_name': '보홍',
#   'stock_code': '041320',
#   'ceo_nm': '이근욱',
#   'corp_cls': 'E',
#   'jurir_no': '1101110990980',
#   'bizr_no': '1058161543',
#   'adres': '서울특별시 강남구 논현동 251 ',
#   'hm_url': 'www.bohongcorp.com',
#   'ir_url': '',
#   'phn_no': '02-3496-4400',
#   'fax_no': '02-521-0594',
#   'induty_code': '46521',
#   'est_dt': '19931206',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00475286',
#   'corp_name': '동북아1호선박투자회사',
#   'corp_name_eng': 'DongBukaNO1ShipInvst',
#   'stock_name': '동북아1호선박투자회사',
#   'stock_code': '078420',
#   'ceo_nm': '김연신',
#   'corp_cls': 'E',
#   'jurir_no': '1801110473809',
#   'bizr_no': '6078167664',
#   'adres': '부산광역시 사상구 모라동 795-22',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '02-746-7000',
#   'fax_no': '02-746-7006',
#   'induty_code': '71531',
#   'est_dt': '20040116',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00250775',
#   'corp_name': '에듀아크',
#   'corp_name_eng': 'EDU ARK Co., Ltd.',
#   'stock_name': '에듀아크',
#   'stock_code': '046350',
#   'ceo_nm': '한데이브경환',
#   'corp_cls': 'E',
#   'jurir_no': '1201110063868',
#   'bizr_no': '1378101130',
#   'adres': '인천광역시 서구 가좌동 178-196 ',
#   'hm_url': 'edu-ark.com',
#   'ir_url': '',
#   'phn_no': '02-798-5910',
#   'fax_no': '027985922',
#   'induty_code': '2622',
#   'est_dt': '19910114',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00114321',
#   'corp_name': '(주)데코',
#   'corp_name_eng': 'Deco',
#   'stock_name': '데코',
#   'stock_code': '013650',
#   'ceo_nm': '박성경',
#   'corp_cls': 'E',
#   'jurir_no': '1101110242985',
#   'bizr_no': '2148107256',
#   'adres': '서울특별시 송파구 오금동 24-2번지 ',
#   'hm_url': 'www.deco.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2145-1372',
#   'fax_no': '02  -2145-1367',
#   'induty_code': '14112',
#   'est_dt': '19781209',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00191108',
#   'corp_name': '(주)엘앤씨피',
#   'corp_name_eng': 'L&CP CO.,Ltd',
#   'stock_name': '엘앤씨피',
#   'stock_code': '015390',
#   'ceo_nm': '최형석',
#   'corp_cls': 'E',
#   'jurir_no': '1201110038697',
#   'bizr_no': '1228116626',
#   'adres': '충청북도 충주시 주덕읍 당우리 822-13 ',
#   'hm_url': 'www.kysys.co.kr',
#   'ir_url': '',
#   'phn_no': '02-337-9090',
#   'fax_no': '032-548-3916',
#   'induty_code': '20491',
#   'est_dt': '19810309',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00167378',
#   'corp_name': '(주)희훈디앤지',
#   'corp_name_eng': 'HEEHOON DESIGN & GLOBAL.CO.LTD',
#   'stock_name': '희훈디앤지',
#   'stock_code': '019640',
#   'ceo_nm': '김재혁, 허  헌',
#   'corp_cls': 'E',
#   'jurir_no': '1101110513609',
#   'bizr_no': '1118110864',
#   'adres': '서울특별시 강남구 논현동 66-11 ',
#   'hm_url': 'www.heehoon.co.kr',
#   'ir_url': '',
#   'phn_no': '02-512-2081',
#   'fax_no': '02  -337 -6324',
#   'induty_code': '42',
#   'est_dt': '19861217',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00225210',
#   'corp_name': '(주)퓨쳐인포넷',
#   'corp_name_eng': 'Future Infonet, Inc.',
#   'stock_name': '퓨쳐인포넷',
#   'stock_code': '058690',
#   'ceo_nm': '류원기',
#   'corp_cls': 'E',
#   'jurir_no': '1101110828933',
#   'bizr_no': '2118643393',
#   'adres': '서울특별시 강남구 대치동 1001-13,14,15 ',
#   'hm_url': 'www.futureinfonet.com',
#   'ir_url': '',
#   'phn_no': '(02)3441-5300',
#   'fax_no': '(02)517-8610',
#   'induty_code': '58221',
#   'est_dt': '19920113',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00223346',
#   'corp_name': '(주)쓰리디넷',
#   'corp_name_eng': '3D NET Co.,Ltd.',
#   'stock_name': '쓰리디넷',
#   'stock_code': '035400',
#   'ceo_nm': '민봉기',
#   'corp_cls': 'E',
#   'jurir_no': '1101110829501',
#   'bizr_no': '2148607080',
#   'adres': '서울특별시 강남구 개포동 1228-1 세영빌딩 5층',
#   'hm_url': 'vsst.com',
#   'ir_url': '',
#   'phn_no': '070-7435-8500',
#   'fax_no': '02-804-2399',
#   'induty_code': '58221',
#   'est_dt': '19920115',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00174129',
#   'corp_name': '(주)제일저축은행',
#   'corp_name_eng': 'Jeil Savings Bank',
#   'stock_name': '제일저축은행',
#   'stock_code': '024100',
#   'ceo_nm': '이용준',
#   'corp_cls': 'E',
#   'jurir_no': '1101110090350',
#   'bizr_no': '2158133698',
#   'adres': '서울특별시 송파구 가락동 99-3',
#   'hm_url': 'www.jeilbank.co.kr',
#   'ir_url': '',
#   'phn_no': '02-405-2000',
#   'fax_no': '02)449-8457',
#   'induty_code': '64131',
#   'est_dt': '19680622',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00114826',
#   'corp_name': '제일창업투자(주)',
#   'corp_name_eng': 'Korea First Venture Capital Corporation',
#   'stock_name': '제일창업투자',
#   'stock_code': '026540',
#   'ceo_nm': '황순태',
#   'corp_cls': 'E',
#   'jurir_no': '1701110044834',
#   'bizr_no': '5018111538',
#   'adres': '서울특별시 중구 충무로 2가 64-5 ',
#   'hm_url': 'www.kfvc.co.kr',
#   'ir_url': '',
#   'phn_no': '02  -775 -7302',
#   'fax_no': '02  -775 -7305',
#   'induty_code': '64209',
#   'est_dt': '19900524',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00173333',
#   'corp_name': '(주)현대DSF',
#   'corp_name_eng': 'HYUNDAI DSF CO.,LTD',
#   'stock_name': '현대DSF',
#   'stock_code': '016510',
#   'ceo_nm': '하병호(河炳鎬)',
#   'corp_cls': 'E',
#   'jurir_no': '1812110002811',
#   'bizr_no': '6208100730',
#   'adres': '울산광역시 남구 삼산동 1521-1',
#   'hm_url': 'www.e-hyundai.com',
#   'ir_url': '',
#   'phn_no': '052-228-2233',
#   'fax_no': '052)228-1334',
#   'induty_code': '47111',
#   'est_dt': '19821126',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00687599',
#   'corp_name': '(주)네프로아이티',
#   'corp_name_eng': 'NEPRO IT CO., LTD.',
#   'stock_name': '네프로아이티',
#   'stock_code': '950030',
#   'ceo_nm': '카나이 타케시',
#   'corp_cls': 'E',
#   'jurir_no': '',
#   'bizr_no': '24377',
#   'adres': '일본 도쿄도 주오구 쿄바시 1-11-8번지 니시긴빌딩 5층',
#   'hm_url': 'www.nepro.jp/it/',
#   'ir_url': '',
#   'phn_no': '81-3-6803-3980',
#   'fax_no': '03-6803-3981',
#   'induty_code': '63991',
#   'est_dt': '20000209',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00256292',
#   'corp_name': '(주)자강',
#   'corp_name_eng': 'ZAKANG Inc',
#   'stock_name': '자강',
#   'stock_code': '036790',
#   'ceo_nm': '최준우',
#   'corp_cls': 'E',
#   'jurir_no': '1101111303728',
#   'bizr_no': '2138626745',
#   'adres': '경기도 성남시 분당구 야탑동 514-1 신도리코BD 6F ',
#   'hm_url': 'www.zakang.co.kr',
#   'ir_url': '',
#   'phn_no': '031 -789 -9058',
#   'fax_no': '031-707-1525',
#   'induty_code': '2642',
#   'est_dt': '19960731',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00271431',
#   'corp_name': '케이엠에스(주)',
#   'corp_name_eng': 'KMS Co., Ltd',
#   'stock_name': '케이엠에스',
#   'stock_code': '038830',
#   'ceo_nm': '이태현',
#   'corp_cls': 'E',
#   'jurir_no': '1101110954829',
#   'bizr_no': '1198116256',
#   'adres': '경기도 안양시 동안구 관양동 900-1 폴리켐빌딩 4층 ',
#   'hm_url': 'www.kmscorp.co.kr',
#   'ir_url': '',
#   'phn_no': '031-424-0093',
#   'fax_no': '02-3463-1006',
#   'induty_code': '2642',
#   'est_dt': '19930701',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00154727',
#   'corp_name': '(주)에버리소스',
#   'corp_name_eng': 'EVER RESOURCES INC.',
#   'stock_name': '에버리소스',
#   'stock_code': '020070',
#   'ceo_nm': '김영수',
#   'corp_cls': 'E',
#   'jurir_no': '1201110041492',
#   'bizr_no': '1398114868',
#   'adres': '인천광역시 남동구 논현동 448-1 예성아이라이프 804 ',
#   'hm_url': 'www.ever-res.com',
#   'ir_url': '',
#   'phn_no': '02-508-0104',
#   'fax_no': '02-508-0189',
#   'induty_code': '46510',
#   'est_dt': '19870701',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00246189',
#   'corp_name': '제이에스(주)',
#   'corp_name_eng': 'JS Company Limited',
#   'stock_name': '제이에스',
#   'stock_code': '037110',
#   'ceo_nm': '임은섭',
#   'corp_cls': 'E',
#   'jurir_no': '1312110003653',
#   'bizr_no': '1268116157',
#   'adres': '경기도 이천시 호법면 안평리 67-2 ',
#   'hm_url': 'www.korfirst.co.kr',
#   'ir_url': '',
#   'phn_no': '031-638-8731(215)',
#   'fax_no': '02-532-0310',
#   'induty_code': '2642',
#   'est_dt': '19940905',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00154204',
#   'corp_name': '태창기업(주)',
#   'corp_name_eng': 'TAECHANG ENTERPRISE CO.,LTD',
#   'stock_name': '태창기업',
#   'stock_code': '007490',
#   'ceo_nm': '김희주',
#   'corp_cls': 'E',
#   'jurir_no': '1801110018663',
#   'bizr_no': '6218105102',
#   'adres': '경상남도 고성군 회화면 배둔리 87번지',
#   'hm_url': 'www.tce.co.kr',
#   'ir_url': '',
#   'phn_no': '055-672-3657',
#   'fax_no': '055-672-3627',
#   'induty_code': '13401',
#   'est_dt': '19560901',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00152631',
#   'corp_name': '(주)에이치비이에너지',
#   'corp_name_eng': 'HBE ENERGY CO.,LTD',
#   'stock_name': '에이치비이에너지',
#   'stock_code': '017300',
#   'ceo_nm': '한상업',
#   'corp_cls': 'E',
#   'jurir_no': '1753110001281',
#   'bizr_no': '5138102065',
#   'adres': '경상북도 구미시공단동 170',
#   'hm_url': 'www.kds21.com',
#   'ir_url': '',
#   'phn_no': '02-2016-6227',
#   'fax_no': '02-2016-6239',
#   'induty_code': '26',
#   'est_dt': '19831020',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00107923',
#   'corp_name': '남한제지(주)',
#   'corp_name_eng': 'NAMHAN PAPER CO.,LTD',
#   'stock_name': '남한제지',
#   'stock_code': '001950',
#   'ceo_nm': '최 홍',
#   'corp_cls': 'E',
#   'jurir_no': '1101110027303',
#   'bizr_no': '2088118156',
#   'adres': '대전광역시 대덕구 신탄진동 100-1',
#   'hm_url': 'www.kyesung.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3668-6705',
#   'fax_no': '02-738-9472',
#   'induty_code': '1712',
#   'est_dt': '19570225',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00358095',
#   'corp_name': '(주)코어비트',
#   'corp_name_eng': 'COREBIT',
#   'stock_name': '코어비트',
#   'stock_code': '056850',
#   'ceo_nm': '김지태',
#   'corp_cls': 'E',
#   'jurir_no': '1301110022929',
#   'bizr_no': '1248121692',
#   'adres': '서울특별시 강남구 논현동 61-5 디엠씨씨빌딩 801호 ',
#   'hm_url': 'www.corebit.co.kr',
#   'ir_url': '',
#   'phn_no': '02-544-1500',
#   'fax_no': '02-544-1560',
#   'induty_code': '58221',
#   'est_dt': '19930923',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00510215',
#   'corp_name': '동북아8호선박투자회사',
#   'corp_name_eng': 'Dongbuka No.8 Ship Investment Company',
#   'stock_name': '동북아8호선박투자회사',
#   'stock_code': '082110',
#   'ceo_nm': '김연신',
#   'corp_cls': 'E',
#   'jurir_no': '1801110501709',
#   'bizr_no': '6068189078',
#   'adres': '부산광역시 사상구 모라동 795-22',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '02-746-7000',
#   'fax_no': '02-746-7006',
#   'induty_code': '71531',
#   'est_dt': '20041119',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00347619',
#   'corp_name': '한국통신데이타(주)',
#   'corp_name_eng': 'Korea Telecom Data Inc.',
#   'stock_name': '한국통신데이타',
#   'stock_code': '045760',
#   'ceo_nm': '진 병 현',
#   'corp_cls': 'E',
#   'jurir_no': '1101111631103',
#   'bizr_no': '2098121969',
#   'adres': '서울특별시 서초구 방배동 792-10 일건빌딩 402호',
#   'hm_url': 'www.ktdata.co.kr',
#   'ir_url': '',
#   'phn_no': '02-571-6162',
#   'fax_no': '02-571-6163',
#   'induty_code': '58221',
#   'est_dt': '19990108',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00372013',
#   'corp_name': '(주)케너텍',
#   'corp_name_eng': 'KENERTEC CO., LTD.',
#   'stock_name': '케너텍',
#   'stock_code': '062730',
#   'ceo_nm': '정복임',
#   'corp_cls': 'E',
#   'jurir_no': '1101111465213',
#   'bizr_no': '1168165855',
#   'adres': '경상북도 포항시 북구 청하면 이가리 366 ',
#   'hm_url': 'www.kenertec.co.kr',
#   'ir_url': '',
#   'phn_no': '(054)261-8040',
#   'fax_no': '054-261-6080',
#   'induty_code': '291',
#   'est_dt': '19970924',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00353735',
#   'corp_name': '(주)다휘',
#   'corp_name_eng': 'DAHUI Co., Ltd.',
#   'stock_name': '다휘',
#   'stock_code': '055250',
#   'ceo_nm': '이근훈',
#   'corp_cls': 'E',
#   'jurir_no': '1159110011511',
#   'bizr_no': '4108130850',
#   'adres': '서울특별시 강남구 청담동 92-3 삼이빌딩 6층 ',
#   'hm_url': 'www.dahui.co.kr',
#   'ir_url': '',
#   'phn_no': '02-501-4694',
#   'fax_no': '02-501-4694',
#   'induty_code': '291',
#   'est_dt': '19950412',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00186540',
#   'corp_name': '코오롱아이넷(주)',
#   'corp_name_eng': "KOLON I' NETWORKS CORP.",
#   'stock_name': '코오롱아이넷',
#   'stock_code': '022520',
#   'ceo_nm': '박동문',
#   'corp_cls': 'E',
#   'jurir_no': '1101110712350',
#   'bizr_no': '1108125442',
#   'adres': '서울특별시 금천구 가산동 533-2 롯데센터 ',
#   'hm_url': 'www.koloninet.com',
#   'ir_url': '',
#   'phn_no': '02-2028-9200',
#   'fax_no': '(02)3660-7373',
#   'induty_code': '58221',
#   'est_dt': '19900720',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00128759',
#   'corp_name': '캠브리지코오롱(주)',
#   'corp_name_eng': 'CAMBRIDGE KOLON CO.,LTD',
#   'stock_name': '캠브리지코오롱',
#   'stock_code': '004620',
#   'ceo_nm': '오원선',
#   'corp_cls': 'E',
#   'jurir_no': '1341110000517',
#   'bizr_no': '1238100559',
#   'adres': '경기도 과천시 별양동 1-22 ',
#   'hm_url': 'www.cambridge.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3677-8140',
#   'fax_no': '02-584-9268',
#   'induty_code': '14111',
#   'est_dt': '19660610',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00535588',
#   'corp_name': '네오세미테크(주)',
#   'corp_name_eng': 'Neosemitech Corporation',
#   'stock_name': '네오세미테크',
#   'stock_code': '089240',
#   'ceo_nm': '공동대표이사 박동창, 송준석, 김근',
#   'corp_cls': 'E',
#   'jurir_no': '1501110040779',
#   'bizr_no': '3018137791',
#   'adres': '인천광역시 연수구 송도동 7-14 ',
#   'hm_url': 'www.neosemitech.com',
#   'ir_url': '',
#   'phn_no': '032-720-1100',
#   'fax_no': '032-720-1107',
#   'induty_code': '2612',
#   'est_dt': '19990805',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00264981',
#   'corp_name': '(주)디에이치패션',
#   'corp_name_eng': 'D.H FASHION CORP.',
#   'stock_name': '디에이치패션',
#   'stock_code': '045260',
#   'ceo_nm': '이장훈',
#   'corp_cls': 'E',
#   'jurir_no': '1101111468952',
#   'bizr_no': '2118625852',
#   'adres': '서울특별시 강남구 삼성동 159 코엑스상사전시장 C-100-4 ',
#   'hm_url': 'www.enerlands.com',
#   'ir_url': '',
#   'phn_no': '02-6000-7824',
#   'fax_no': '02-6000-3728',
#   'induty_code': '467',
#   'est_dt': '19971004',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00231521',
#   'corp_name': '(주)핸디소프트',
#   'corp_name_eng': 'HandySoft Corp.',
#   'stock_name': '핸디소프트',
#   'stock_code': '032380',
#   'ceo_nm': '권석호',
#   'corp_cls': 'E',
#   'jurir_no': '1101110747943',
#   'bizr_no': '1148145926',
#   'adres': '서울특별시 서초구 서초동 1602-5번지 로얄타워 8층~12층,15층 ',
#   'hm_url': 'www.handysoft.co.kr',
#   'ir_url': '',
#   'phn_no': '02  -3479-5640',
#   'fax_no': '02  -3479-5599',
#   'induty_code': '58221',
#   'est_dt': '19910210',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00159908',
#   'corp_name': '케이엠에이치(주)',
#   'corp_name_eng': 'KMH Co., Ltd.',
#   'stock_name': '케이엠에이치',
#   'stock_code': '009690',
#   'ceo_nm': '김선근',
#   'corp_cls': 'E',
#   'jurir_no': '1101110161333',
#   'bizr_no': '1198104667',
#   'adres': '경기도 안양시 동안구 관양동 799 안양메가밸리 405,812',
#   'hm_url': 'www.kmholdings.co.kr',
#   'ir_url': '',
#   'phn_no': '031-420-4730',
#   'fax_no': '02)865-1050',
#   'induty_code': '28302',
#   'est_dt': '19740307',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00259493',
#   'corp_name': '(주)씨엘엘씨디',
#   'corp_name_eng': 'CL LCD CO., LTD.',
#   'stock_name': '씨엘엘씨디',
#   'stock_code': '035710',
#   'ceo_nm': '이양호',
#   'corp_cls': 'E',
#   'jurir_no': '1101111053935',
#   'bizr_no': '2118642297',
#   'adres': '서울특별시 송파구 가락본동 120-1 성호빌딩 3충 ',
#   'hm_url': 'www.cllcd.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3401-9048',
#   'fax_no': '02-3401-9049',
#   'induty_code': '47919',
#   'est_dt': '19940705',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00359641',
#   'corp_name': '(주)현대푸드시스템',
#   'corp_name_eng': 'HYUNDAI FOOD SYSTEM',
#   'stock_name': '현대푸드시스템',
#   'stock_code': '114410',
#   'ceo_nm': '이규성',
#   'corp_cls': 'E',
#   'jurir_no': '1345110037695',
#   'bizr_no': '1358135309',
#   'adres': '서울특별시 강동구 암사동 선사로 111번지 ',
#   'hm_url': 'www.hyundaifoodsystem.com',
#   'ir_url': '',
#   'phn_no': '3015-0241',
#   'fax_no': '02-3448-2230',
#   'induty_code': '56130',
#   'est_dt': '19991223',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00103325',
#   'corp_name': '(주)고제',
#   'corp_name_eng': 'KOJE Co.,Ltd.',
#   'stock_name': '고제',
#   'stock_code': '002540',
#   'ceo_nm': '설기원',
#   'corp_cls': 'E',
#   'jurir_no': '1101110036990',
#   'bizr_no': '2168100429',
#   'adres': '충청남도 천안시 동면 송연리 174-1',
#   'hm_url': 'www.koje.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2111-2000',
#   'fax_no': '02-3430-2039',
#   'induty_code': '10795',
#   'est_dt': '19581205',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00161639',
#   'corp_name': '메리츠종합금융(주)',
#   'corp_name_eng': 'Meritz Investment Bank',
#   'stock_name': '메리츠종합금융',
#   'stock_code': '012420',
#   'ceo_nm': '김동훈',
#   'corp_cls': 'E',
#   'jurir_no': '1101110216360',
#   'bizr_no': '2018105382',
#   'adres': '서울특별시 중구 태평로1가 84번지 서울파이낸스센터 5층',
#   'hm_url': 'www.imeritzbank.com',
#   'ir_url': '',
#   'phn_no': '02-777-7711',
#   'fax_no': '(02)777-7710',
#   'induty_code': '64919',
#   'est_dt': '19770713',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00211271',
#   'corp_name': '제넥셀세인(주)',
#   'corp_name_eng': 'GENEXEL-SEIN INC.',
#   'stock_name': '제넥셀세인',
#   'stock_code': '034660',
#   'ceo_nm': '이 문 일',
#   'corp_cls': 'E',
#   'jurir_no': '1341110030316',
#   'bizr_no': '1388103183',
#   'adres': '대전광역시 유성구 구성동 23 한국과학기술원 E18동 2층 ',
#   'hm_url': 'www.genexel.com',
#   'ir_url': '',
#   'phn_no': '02 - 575 - 1141',
#   'fax_no': '02-2090-1999',
#   'induty_code': '27111',
#   'est_dt': '19900211',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00388272',
#   'corp_name': '(주)쓰리디월드',
#   'corp_name_eng': '3D world Co., Ltd.',
#   'stock_name': '쓰리디월드',
#   'stock_code': '065340',
#   'ceo_nm': '문용훈 (단독대표)',
#   'corp_cls': 'E',
#   'jurir_no': '1341110072649',
#   'bizr_no': '1238155559',
#   'adres': '서울특별시 금천구 가산동 680번지 우림라이온스밸리2차 7층 ',
#   'hm_url': 'www.dmtechnology.co.kr',
#   'ir_url': '',
#   'phn_no': '02-864-2975',
#   'fax_no': '02-864-2976',
#   'induty_code': '26',
#   'est_dt': '20000320',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00264796',
#   'corp_name': '(주)스톰이앤에프',
#   'corp_name_eng': 'Stom EnF Co.,Ltd.',
#   'stock_name': '스톰이앤에프',
#   'stock_code': '043680',
#   'ceo_nm': '이준',
#   'corp_cls': 'E',
#   'jurir_no': '1601110041733',
#   'bizr_no': '3148109777',
#   'adres': '서울특별시 강남구 논현동 267-15 봄빌딩 B동 ',
#   'hm_url': 'www.dechocolateentf.com',
#   'ir_url': '',
#   'phn_no': '02-513-5000',
#   'fax_no': '02-549-4600',
#   'induty_code': '5911',
#   'est_dt': '19940819',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00134909',
#   'corp_name': '(주)소예',
#   'corp_name_eng': 'SOYEA Corporation',
#   'stock_name': '소예',
#   'stock_code': '035010',
#   'ceo_nm': '이재성',
#   'corp_cls': 'E',
#   'jurir_no': '1311110002045',
#   'bizr_no': '1298102424',
#   'adres': '경기도 성남시 분당구 서현동 254-4 여암빌딩 3층 ',
#   'hm_url': 'www.soyea.com',
#   'ir_url': '',
#   'phn_no': '031-740-4220',
#   'fax_no': '031-744-0312',
#   'induty_code': '467',
#   'est_dt': '19740307',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00236368',
#   'corp_name': '(주)엠엔에프씨',
#   'corp_name_eng': 'M&FC CO.,LTD.',
#   'stock_name': '엠엔에프씨',
#   'stock_code': '048640',
#   'ceo_nm': '조성우 단독대표',
#   'corp_cls': 'E',
#   'jurir_no': '1648110007452',
#   'bizr_no': '3128117946',
#   'adres': '서울특별시 마포구 상암동 디엠씨비6-2 트루텍빌딩4층 ',
#   'hm_url': 'www.dong-woo.com',
#   'ir_url': '',
#   'phn_no': '031-650-2200',
#   'fax_no': '-    -',
#   'induty_code': '22214',
#   'est_dt': '19941212',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00684547',
#   'corp_name': '하이트맥주(주)',
#   'corp_name_eng': 'HITE BREWERY CO., LTD.',
#   'stock_name': '하이트맥주',
#   'stock_code': '103150',
#   'ceo_nm': '박문덕, 김지현',
#   'corp_cls': 'E',
#   'jurir_no': '1101113927427',
#   'bizr_no': '2118815168',
#   'adres': '서울특별시 강남구 청담동 132-12',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '3219-0114',
#   'fax_no': '02-515-0006',
#   'induty_code': '11',
#   'est_dt': '20080701',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00251385',
#   'corp_name': '(주)보광티에스',
#   'corp_name_eng': 'Bokwang TS Co.,LTD.',
#   'stock_name': '보광티에스',
#   'stock_code': '066690',
#   'ceo_nm': ' 손 성 욱',
#   'corp_cls': 'E',
#   'jurir_no': '1746110032166',
#   'bizr_no': '5068128617',
#   'adres': '경상북도 칠곡군 석적면 중리 408-1 ',
#   'hm_url': 'bkts.co.kr',
#   'ir_url': '',
#   'phn_no': '02-6093-0165',
#   'fax_no': '02-546-3678',
#   'induty_code': '2592',
#   'est_dt': '19980510',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00262682',
#   'corp_name': '(주)아인스엠앤엠',
#   'corp_name_eng': "Ein's M&M CO., LTD",
#   'stock_name': '아인스엠앤엠',
#   'stock_code': '040740',
#   'ceo_nm': '김수겸',
#   'corp_cls': 'E',
#   'jurir_no': '1101111697832',
#   'bizr_no': '2208161779',
#   'adres': '서울특별시 강남구 논현동 231-13 팍스타워 5층 ',
#   'hm_url': 'www.taewon.com',
#   'ir_url': '',
#   'phn_no': '(02)2017-0000',
#   'fax_no': '02-3448-0139',
#   'induty_code': '59111',
#   'est_dt': '19990514',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00234555',
#   'corp_name': '씨엔씨엔터프라이즈(주)',
#   'corp_name_eng': 'C&C ENTERPRISE CO.,LTD',
#   'stock_name': '씨엔씨엔터프라이즈',
#   'stock_code': '038420',
#   'ceo_nm': '임신상',
#   'corp_cls': 'E',
#   'jurir_no': '1101111044182',
#   'bizr_no': '1208162556',
#   'adres': '서울특별시 서초구 양재동 2-44 서원빌딩 3층',
#   'hm_url': 'www.cncen.com',
#   'ir_url': '',
#   'phn_no': '070-7405-9723',
#   'fax_no': '02-542-2192',
#   'induty_code': '292',
#   'est_dt': '19940608',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00507257',
#   'corp_name': '(주)아이알디',
#   'corp_name_eng': 'International Resources Development Co.,Ltd',
#   'stock_name': '아이알디',
#   'stock_code': '084810',
#   'ceo_nm': '권오남',
#   'corp_cls': 'E',
#   'jurir_no': '1101111775745',
#   'bizr_no': '2148638583',
#   'adres': '충청남도 천안시 성정동 1268번지 ',
#   'hm_url': 'www.e-ird.com',
#   'ir_url': '',
#   'phn_no': '041-551-0185',
#   'fax_no': '02-554-9468',
#   'induty_code': '29271',
#   'est_dt': '19990917',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00417963',
#   'corp_name': '(주)바이나믹',
#   'corp_name_eng': 'BYNAMIC CO., LTD.',
#   'stock_name': '바이나믹',
#   'stock_code': '067850',
#   'ceo_nm': '오승석',
#   'corp_cls': 'E',
#   'jurir_no': '1101111774622',
#   'bizr_no': '2208167263',
#   'adres': '서울특별시 강남구 역삼동 830-9 영광빌딩 3층 ',
#   'hm_url': 'www.yellowfilm.com',
#   'ir_url': '',
#   'phn_no': '02-511-7747',
#   'fax_no': '02-511-6636',
#   'induty_code': '59114',
#   'est_dt': '19990916',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00543523',
#   'corp_name': '(주)코크렙제7호위탁관리부동산투자회사',
#   'corp_name_eng': 'KOCREF REIT 7',
#   'stock_name': '코크렙제7호위탁관리부동산투자회사',
#   'stock_code': '086720',
#   'ceo_nm': '이광옥',
#   'corp_cls': 'E',
#   'jurir_no': '1101113329631',
#   'bizr_no': '1078670548',
#   'adres': '서울특별시 강남구 역삼동 736-1',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '02-787-0063',
#   'fax_no': '786-6622',
#   'induty_code': '68112',
#   'est_dt': '20051025',
#   'acc_mt': '04'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00300566',
#   'corp_name': '엔빅스(주)',
#   'corp_name_eng': 'ENBIGS Co., Ltd.',
#   'stock_name': '엔빅스',
#   'stock_code': '054170',
#   'ceo_nm': '이명노',
#   'corp_cls': 'E',
#   'jurir_no': '1101110890023',
#   'bizr_no': '1168147366',
#   'adres': '서울특별시 영등포구 여의도동 14-3 엔빅스빌딩 ',
#   'hm_url': 'www.enbigs.com',
#   'ir_url': '',
#   'phn_no': '02-3787-3787',
#   'fax_no': '02)3775-3983',
#   'induty_code': '62021',
#   'est_dt': '19920917',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00299376',
#   'corp_name': '(주)선팩테크',
#   'corp_name_eng': 'SUNPACKTECH CO., LTD.',
#   'stock_name': '선팩테크',
#   'stock_code': '054010',
#   'ceo_nm': '최민석',
#   'corp_cls': 'E',
#   'jurir_no': '1701110116964',
#   'bizr_no': '5038132918',
#   'adres': '강원도 횡성군 공근면 초원리 660-1 ',
#   'hm_url': 'www.ubtron.net',
#   'ir_url': '',
#   'phn_no': '070-8644-5100',
#   'fax_no': '054-473-5984',
#   'induty_code': '2629',
#   'est_dt': '19970225',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00112068',
#   'corp_name': '마이크로닉스(주)',
#   'corp_name_eng': 'MICRONIX CO',
#   'stock_name': '마이크로닉스',
#   'stock_code': '001190',
#   'ceo_nm': '이한영',
#   'corp_cls': 'E',
#   'jurir_no': '1901110000155',
#   'bizr_no': '3018120252',
#   'adres': '충청북도 진천군 이월면 미잠리 122-23',
#   'hm_url': 'www.daeyu.com',
#   'ir_url': '',
#   'phn_no': '02-3438-0700',
#   'fax_no': '02-544-5118',
#   'induty_code': '13109',
#   'est_dt': '19540507',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00257194',
#   'corp_name': '(주)블루스톤디앤아이',
#   'corp_name_eng': 'Blue Stone D&I Co., Ltd.',
#   'stock_name': '블루스톤디앤아이',
#   'stock_code': '033720',
#   'ceo_nm': '김영렬, 김영기',
#   'corp_cls': 'E',
#   'jurir_no': '1101110850382',
#   'bizr_no': '1208151379',
#   'adres': '서울특별시 강남구 역삼동 607-13 삼정빌딩((주)아윌패스 빌딩) 5층 ',
#   'hm_url': 'www.intus.co.kr',
#   'ir_url': '',
#   'phn_no': '02  -508 -1700',
#   'fax_no': '02  -516 -1539',
#   'induty_code': '58221',
#   'est_dt': '19920410',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00477372',
#   'corp_name': '(주)신지소프트',
#   'corp_name_eng': 'SINJISOFTCorporation',
#   'stock_name': '신지소프트',
#   'stock_code': '078700',
#   'ceo_nm': '강 근 호',
#   'corp_cls': 'E',
#   'jurir_no': '1101111916836',
#   'bizr_no': '1058609765',
#   'adres': '서울특별시 용산구 한남동 123번지 고뫄스빌딩 5층 ',
#   'hm_url': 'www.sinjisoft.com',
#   'ir_url': '',
#   'phn_no': '(02)711-6550',
#   'fax_no': '02-711-6545',
#   'induty_code': '58221',
#   'est_dt': '20000328',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00465410',
#   'corp_name': '(주)맥쿼리센트럴오피스기업구조조정부동산투자회사',
#   'corp_name_eng': 'MACQUARIE CENTRAL OFFICE CORPORATE',
#   'stock_name': '맥쿼리센트럴오피스기업구조조정부동산투자회사',
#   'stock_code': '076850',
#   'ceo_nm': '대표이사 조주현,김정호',
#   'corp_cls': 'E',
#   'jurir_no': '1101112914342',
#   'bizr_no': '1048184859',
#   'adres': '서울특별시 중구 소공동 소공동한화빌딩 6층',
#   'hm_url': 'http://www.macquarie.co.kr/property',
#   'ir_url': '',
#   'phn_no': '02-3705-8716',
#   'fax_no': '02-3782-2888',
#   'induty_code': '68112',
#   'est_dt': '20031212',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00331760',
#   'corp_name': '테스텍(주)',
#   'corp_name_eng': 'Testech Incorporation',
#   'stock_name': '테스텍',
#   'stock_code': '048510',
#   'ceo_nm': '하 상 원',
#   'corp_cls': 'E',
#   'jurir_no': '1615110021380',
#   'bizr_no': '3128134270',
#   'adres': '경기도 화성시 동탄면 오산리 830번지 ',
#   'hm_url': 'www.testech.co.kr',
#   'ir_url': '',
#   'phn_no': '031-371-5500',
#   'fax_no': '041 -529 -3003',
#   'induty_code': '29271',
#   'est_dt': '19961102',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00200761',
#   'corp_name': '(주)중앙디자인',
#   'corp_name_eng': 'Joong Ang Design Co., Ltd',
#   'stock_name': '중앙디자인',
#   'stock_code': '030030',
#   'ceo_nm': '변인근, 임명환, 최의종(각자대표)',
#   'corp_cls': 'E',
#   'jurir_no': '1101110760937',
#   'bizr_no': '1048126539',
#   'adres': '서울특별시 중구 남창동 51-1 ',
#   'hm_url': 'www.jad.co.kr',
#   'ir_url': '',
#   'phn_no': '(02)311-6414',
#   'fax_no': '(02)311-6426',
#   'induty_code': '73201',
#   'est_dt': '19910322',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00268297',
#   'corp_name': '(주)에코페트로시스템',
#   'corp_name_eng': 'ECOPETRO SYSTEM Co., Ltd.',
#   'stock_name': '에코페트로시스템',
#   'stock_code': '042870',
#   'ceo_nm': '김성욱',
#   'corp_cls': 'E',
#   'jurir_no': '1501110030093',
#   'bizr_no': '3018130686',
#   'adres': '서울특별시 성동구 성수2가 315-58 한서빌딩 7층 ',
#   'hm_url': 'http://www.ilryung.co.kr',
#   'ir_url': '',
#   'phn_no': '02-511-6964',
#   'fax_no': '02-511-6977',
#   'induty_code': '46800',
#   'est_dt': '19970721',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00161301',
#   'corp_name': '한림창업투자(주)',
#   'corp_name_eng': 'Hallim Venture Capital',
#   'stock_name': '한림창업투자',
#   'stock_code': '021060',
#   'ceo_nm': '최석찬, 강성교',
#   'corp_cls': 'E',
#   'jurir_no': '1601110015572',
#   'bizr_no': '3058109360',
#   'adres': '서울특별시 서초구 반포동 49-5 주호빌딩 7층 ',
#   'hm_url': 'www.hallimventure.com',
#   'ir_url': '',
#   'phn_no': '02  -511 -6102',
#   'fax_no': '02  -511 -6108',
#   'induty_code': '64209',
#   'est_dt': '19880928',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00237260',
#   'corp_name': '(주)헤쎄나',
#   'corp_name_eng': 'Hecenat Co.,Ltd',
#   'stock_name': '헤쎄나',
#   'stock_code': '036270',
#   'ceo_nm': '오 정 완, 윤 상 섭(공동대표이사)',
#   'corp_cls': 'E',
#   'jurir_no': '1243110028898',
#   'bizr_no': '1348123488',
#   'adres': '경기도 안산시 원시동 776-3 ',
#   'hm_url': 'www.ados.co.kr',
#   'ir_url': '',
#   'phn_no': '02-517-8350',
#   'fax_no': '031 -493 -2525',
#   'induty_code': '2642',
#   'est_dt': '19900716',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00297970',
#   'corp_name': '미래에셋굿라이프혼합형자녀를위한투자회사10-1',
#   'corp_name_eng': 'MIRAEASSETGOODLIFEBALANCEDFUND10-1',
#   'stock_name': '미래에셋굿라이프혼합형자녀를위한투자회사10-1',
#   'stock_code': '037510',
#   'ceo_nm': '미래에셋자산운용투자자문(주)',
#   'corp_cls': 'E',
#   'jurir_no': '1101111815228',
#   'bizr_no': '2118689098',
#   'adres': '서울특별시 영등포구 여의도동 45-1 미래에셋빌딩 ',
#   'hm_url': 'www.mirae.co.kr',
#   'ir_url': '',
#   'phn_no': '-    -',
#   'fax_no': '-    -',
#   'induty_code': '64201',
#   'est_dt': '19991124',
#   'acc_mt': '11'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00107358',
#   'corp_name': '(주)일공공일안경콘택트',
#   'corp_name_eng': '1001 OPTICAL Co., Ltd',
#   'stock_name': '일공공일안경콘택트',
#   'stock_code': '032030',
#   'ceo_nm': '윤병노',
#   'corp_cls': 'E',
#   'jurir_no': '1801110057182',
#   'bizr_no': '6228106249',
#   'adres': '서울특별시 영등포구 문래동3가 54-66 에이스하이테크시티 4동 504호 ',
#   'hm_url': 'www.1001optical.com',
#   'ir_url': '',
#   'phn_no': '02-3454-1001',
#   'fax_no': '02-3454-1543',
#   'induty_code': '46493',
#   'est_dt': '19850531',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00115427',
#   'corp_name': '(주)신동방CP',
#   'corp_name_eng': 'ShinDongBang CP Corporation',
#   'stock_name': '신동방CP',
#   'stock_code': '004660',
#   'ceo_nm': '이재호(대표이사)',
#   'corp_cls': 'E',
#   'jurir_no': '1101110068555',
#   'bizr_no': '1078134789',
#   'adres': '경기도 안산시 상록구 팔곡이동 27번지',
#   'hm_url': 'www.sdbcp.com',
#   'ir_url': '',
#   'phn_no': '031-400-3000',
#   'fax_no': '031-437-0303',
#   'induty_code': '10620',
#   'est_dt': '19660617',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00267474',
#   'corp_name': '(주)지앤알',
#   'corp_name_eng': 'G&R Inc.',
#   'stock_name': '지앤알',
#   'stock_code': '043630',
#   'ceo_nm': '박준오',
#   'corp_cls': 'E',
#   'jurir_no': '1748110007503',
#   'bizr_no': '5158105068',
#   'adres': '광주광역시 북구 월출동 970-106 ',
#   'hm_url': 'www.gnrinc.kr',
#   'ir_url': '',
#   'phn_no': '02-2105-7123',
#   'fax_no': '02-2105-7121',
#   'induty_code': '27112',
#   'est_dt': '19930730',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00134051',
#   'corp_name': '(주)셀런',
#   'corp_name_eng': 'CELRUN CO.,LTD',
#   'stock_name': '셀런',
#   'stock_code': '013240',
#   'ceo_nm': '송성호',
#   'corp_cls': 'E',
#   'jurir_no': '1701110013966',
#   'bizr_no': '5138103235',
#   'adres': '광주광역시 북구 오룡동 1110-22',
#   'hm_url': 'www.celrun.com',
#   'ir_url': '',
#   'phn_no': '02-2045-6614',
#   'fax_no': '02-2045-6891',
#   'induty_code': '26',
#   'est_dt': '19780412',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00596066',
#   'corp_name': '한국 베트남15-1유전 해외자원개발투자회사',
#   'corp_name_eng': 'Korea Vietnam15-1Oil Overseas Resources Development Fund',
#   'stock_name': '한국베트남15-1유전해외자원개발투자회사',
#   'stock_code': '093820',
#   'ceo_nm': '한국투자신탁운용',
#   'corp_cls': 'E',
#   'jurir_no': '1101113553785',
#   'bizr_no': '1078684173',
#   'adres': '서울특별시 영등포구 여의도동 15-24',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '02-2168-0436',
#   'fax_no': '02-2168-0484',
#   'induty_code': '64201',
#   'est_dt': '20061101',
#   'acc_mt': '01'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00347363',
#   'corp_name': '(주)에이치원바이오',
#   'corp_name_eng': 'H1BIO Corp.',
#   'stock_name': '에이치원바이오',
#   'stock_code': '052310',
#   'ceo_nm': 'Robin Carl Tampoe',
#   'corp_cls': 'E',
#   'jurir_no': '1101111325160',
#   'bizr_no': '2118643511',
#   'adres': '서울특별시 강남구 삼성동 77-11,12 ',
#   'hm_url': 'www.drimone.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2105-6700',
#   'fax_no': '02-2105-6789',
#   'induty_code': '58221',
#   'est_dt': '19960925',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00150226',
#   'corp_name': '(주)씨앤중공업',
#   'corp_name_eng': 'C&HEAVY INDUSTRIES CO.,LTD',
#   'stock_name': '씨앤중공업',
#   'stock_code': '008400',
#   'ceo_nm': '임 갑 표',
#   'corp_cls': 'E',
#   'jurir_no': '1101110302440',
#   'bizr_no': '1198107062',
#   'adres': '전라남도 목포시 연산동 1282',
#   'hm_url': 'www.cnhi.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3706-4318',
#   'fax_no': '02-864-7678',
#   'induty_code': '30203',
#   'est_dt': '19730108',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00152914',
#   'corp_name': 'FnC코오롱(주)',
#   'corp_name_eng': 'FnC KOLON CORP',
#   'stock_name': 'FnC코오롱',
#   'stock_code': '001370',
#   'ceo_nm': '제환석',
#   'corp_cls': 'E',
#   'jurir_no': '1101110003973',
#   'bizr_no': '2028144656',
#   'adres': '서울특별시 중구 무교동 코오롱빌딩 14층',
#   'hm_url': 'www.fnckolon.com',
#   'ir_url': '',
#   'phn_no': '02-3677-8133',
#   'fax_no': '02-3677-7513',
#   'induty_code': '1419',
#   'est_dt': '19541217',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00158839',
#   'corp_name': '(주)제너비오믹스',
#   'corp_name_eng': 'Xana-BiomiX Co., LTD.',
#   'stock_name': '제너비오믹스',
#   'stock_code': '017010',
#   'ceo_nm': '최수용',
#   'corp_cls': 'E',
#   'jurir_no': '1101110350762',
#   'bizr_no': '2148119937',
#   'adres': '서울특별시 서초구 서초동 1666-11 예원빌딩 ',
#   'hm_url': 'www.oval.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2051-5830',
#   'fax_no': '02-2051-5831',
#   'induty_code': '27214',
#   'est_dt': '19830530',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00159281',
#   'corp_name': '(주)케드콤',
#   'corp_name_eng': 'KEDCOM CO.,LTD',
#   'stock_name': '케드콤',
#   'stock_code': '011050',
#   'ceo_nm': '김학전',
#   'corp_cls': 'E',
#   'jurir_no': '1101110191752',
#   'bizr_no': '1058103112',
#   'adres': '서울특별시 마포구 도화동 22',
#   'hm_url': 'www.kedcom.com',
#   'ir_url': '',
#   'phn_no': '02-718-4851',
#   'fax_no': '031-489-2429',
#   'induty_code': '2642',
#   'est_dt': '19760213',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00210537',
#   'corp_name': '(주)지엔텍홀딩스',
#   'corp_name_eng': 'GENTECH HOLDINGS Co., Ltd.',
#   'stock_name': '지엔텍홀딩스',
#   'stock_code': '065410',
#   'ceo_nm': '정 봉 규',
#   'corp_cls': 'E',
#   'jurir_no': '1746110009892',
#   'bizr_no': '5068107984',
#   'adres': '서울특별시 강남구 역삼동 737 강남파이낸스센터 28층 ',
#   'hm_url': 'www.gentechholdings.com',
#   'ir_url': '',
#   'phn_no': '(02)2016-0700',
#   'fax_no': '(054)278-1493',
#   'induty_code': '74100',
#   'est_dt': '19900326',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00240370',
#   'corp_name': '동부씨엔아이(주)',
#   'corp_name_eng': 'Dongbu CNI Co.,Ltd.',
#   'stock_name': '동부씨엔아이',
#   'stock_code': '044640',
#   'ceo_nm': '김준기,이봉',
#   'corp_cls': 'E',
#   'jurir_no': '1101111054339',
#   'bizr_no': '2118603751',
#   'adres': '서울특별시 강남구 삼성동 154-17 ',
#   'hm_url': 'www.dongbucni.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2136-6000',
#   'fax_no': '02-2136-6006',
#   'induty_code': '58221',
#   'est_dt': '19940706',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00247887',
#   'corp_name': '(주)아이피에스',
#   'corp_name_eng': 'IPSLtd.',
#   'stock_name': '아이피에스',
#   'stock_code': '051820',
#   'ceo_nm': '이문용',
#   'corp_cls': 'E',
#   'jurir_no': '1347110016439',
#   'bizr_no': '1258118225',
#   'adres': '경기도 평택시 지제동 33번지 ',
#   'hm_url': 'www.ips-tech.com',
#   'ir_url': '',
#   'phn_no': '031-659-2126',
#   'fax_no': '031-655-7115',
#   'induty_code': '29271',
#   'est_dt': '19960327',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00268358',
#   'corp_name': '(주)에스브이에이치',
#   'corp_name_eng': 'SVH co., Ltd.',
#   'stock_name': '에스브이에이치',
#   'stock_code': '046240',
#   'ceo_nm': '김형기',
#   'corp_cls': 'E',
#   'jurir_no': '1801110241743',
#   'bizr_no': '6018132319',
#   'adres': '서울특별시 서초구 서초동 1585-13 성현빌딩 ',
#   'hm_url': 'www.edu.co.kr',
#   'ir_url': '',
#   'phn_no': '02-573-6911',
#   'fax_no': '02-554-9677',
#   'induty_code': '58221',
#   'est_dt': '19970926',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00316488',
#   'corp_name': '(주)제이콤',
#   'corp_name_eng': 'Jcommunications Co., Ltd.',
#   'stock_name': '제이콤',
#   'stock_code': '060750',
#   'ceo_nm': '한광선',
#   'corp_cls': 'E',
#   'jurir_no': '1352110004813',
#   'bizr_no': '1388116640',
#   'adres': '경기도 의왕시 오전동 124-4 ',
#   'hm_url': 'www.jcomco.com',
#   'ir_url': '',
#   'phn_no': '031-428-7200',
#   'fax_no': '031-451-2994',
#   'induty_code': '2642',
#   'est_dt': '19980501',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00264130',
#   'corp_name': '(주)옥션',
#   'corp_name_eng': 'EBAY AUCTION CO., LTD',
#   'stock_name': '옥션',
#   'stock_code': '043790',
#   'ceo_nm': '박주만',
#   'corp_cls': 'E',
#   'jurir_no': '1101111253569',
#   'bizr_no': '2148602085',
#   'adres': '서울특별시 서초구 서초동 1303-22 교보타워',
#   'hm_url': 'www.auction.co.kr',
#   'ir_url': '',
#   'phn_no': '02-530-9750',
#   'fax_no': '02-530-9747',
#   'induty_code': '4610',
#   'est_dt': '19960322',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00540304',
#   'corp_name': '(주)네이쳐글로벌',
#   'corp_name_eng': 'NatureGlobal Inc.',
#   'stock_name': '네이쳐글로벌',
#   'stock_code': '088020',
#   'ceo_nm': '박지우',
#   'corp_cls': 'E',
#   'jurir_no': '1101111965875',
#   'bizr_no': '2148658541',
#   'adres': '경기도 성남시 분당구 정자동 25-1 인텔리지1 킨스타워 4층 ',
#   'hm_url': 'www.pentamicro.com',
#   'ir_url': '',
#   'phn_no': '031-713-4170',
#   'fax_no': '031-713-4174',
#   'induty_code': '2611',
#   'est_dt': '20000510',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00617299',
#   'corp_name': 'GB 블루오션베트남주식혼합형 투자회사 1호',
#   'corp_name_eng': 'GB Blue Ocean VIETNAM EQUITY BALANCED FUND [1]',
#   'stock_name': 'GB블루오션베트남주식혼합형투자회사1호',
#   'stock_code': '094950',
#   'ceo_nm': '(주)골든브릿지자산운용',
#   'corp_cls': 'E',
#   'jurir_no': '1101113593757',
#   'bizr_no': '1078686680',
#   'adres': '서울특별시 영등포구 여의도동 익스콘벤처빌딩 4층',
#   'hm_url': '_',
#   'ir_url': '',
#   'phn_no': '02-2168-0416',
#   'fax_no': '02-2168-0484',
#   'induty_code': '64201',
#   'est_dt': '20070105',
#   'acc_mt': '01'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00262275',
#   'corp_name': '엠씨티티코어(주)',
#   'corp_name_eng': 'MCTT CORE Inc.',
#   'stock_name': '엠씨티티코어',
#   'stock_code': '052210',
#   'ceo_nm': '김영기',
#   'corp_cls': 'E',
#   'jurir_no': '1101111368938',
#   'bizr_no': '2208142296',
#   'adres': '서울특별시 강남구 논현동 201-6 노벨테크빌딩 12층 ',
#   'hm_url': 'www.mcttcore.net',
#   'ir_url': '',
#   'phn_no': '02-515-2937',
#   'fax_no': '02)515-2947',
#   'induty_code': '26410',
#   'est_dt': '19970123',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00200798',
#   'corp_name': '(주)에이스 앤 파트너스',
#   'corp_name_eng': 'Ace & Partners',
#   'stock_name': '에이스앤파트너스',
#   'stock_code': '032930',
#   'ceo_nm': '구관영',
#   'corp_cls': 'E',
#   'jurir_no': '1101110305858',
#   'bizr_no': '1308131462',
#   'adres': '인천광역시 남동구 논현동 451-3 남동공단 24블럭 5롯트',
#   'hm_url': 'www.acetech.co.kr',
#   'ir_url': '',
#   'phn_no': '032 -610 -3574',
#   'fax_no': '032-810-5505',
#   'induty_code': '2642',
#   'est_dt': '19820105',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00335924',
#   'corp_name': '(주)지앤디윈텍',
#   'corp_name_eng': 'GND WINTECH CO.,LTD.',
#   'stock_name': '지앤디윈텍',
#   'stock_code': '061050',
#   'ceo_nm': '정대윤',
#   'corp_cls': 'E',
#   'jurir_no': '1101111552812',
#   'bizr_no': '1198127980',
#   'adres': '충청남도 아산시 배방면 휴대리 37-1 ',
#   'hm_url': 'www.eurasiarnt.com',
#   'ir_url': '',
#   'phn_no': '(041)539-2640',
#   'fax_no': '041-539-2626',
#   'induty_code': '2642',
#   'est_dt': '19980605',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00111591',
#   'corp_name': '인터피온반도체',
#   'corp_name_eng': 'INTERPION SEM CONDUCTOR CO.,LTD',
#   'stock_name': '인터피온반도체',
#   'stock_code': '014010',
#   'ceo_nm': '최상철',
#   'corp_cls': 'E',
#   'jurir_no': '1115110001788',
#   'bizr_no': '1278102976',
#   'adres': '경기도 부천시 원미구 약대동 192번지 테크노파크 2단지 관리동401호',
#   'hm_url': 'www.interpion.co.kr',
#   'ir_url': '',
#   'phn_no': '032-234-3928',
#   'fax_no': '032-234-3939',
#   'induty_code': '2612',
#   'est_dt': '19790412',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00189343',
#   'corp_name': '(주)솔로몬저축은행',
#   'corp_name_eng': 'SOLOMON SAVINGS BANK',
#   'stock_name': '솔로몬저축은행',
#   'stock_code': '007800',
#   'ceo_nm': '임석, 정일대',
#   'corp_cls': 'E',
#   'jurir_no': '1101110128341',
#   'bizr_no': '2018145384',
#   'adres': '서울특별시 강남구 대치동 889-11 대치빌딩',
#   'hm_url': 'www.solomonbank.com',
#   'ir_url': '',
#   'phn_no': '02-2022-8000',
#   'fax_no': '02-2022-8008',
#   'induty_code': '64131',
#   'est_dt': '19720406',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00252588',
#   'corp_name': '(주)엠트론스토리지테크놀로지',
#   'corp_name_eng': 'MTRON STORAGE TECHNOLOGY CO.,LTD.',
#   'stock_name': '엠트론스토리지테크놀로지',
#   'stock_code': '046320',
#   'ceo_nm': '정유석',
#   'corp_cls': 'E',
#   'jurir_no': '1101110736194',
#   'bizr_no': '2208104803',
#   'adres': '경기도 성남시 중원구 상대원동 307-2 선택시티Ⅱ 807호 ',
#   'hm_url': 'www.mtron.net',
#   'ir_url': '',
#   'phn_no': '02-3430-3000',
#   'fax_no': '02-3430-3039',
#   'induty_code': '46510',
#   'est_dt': '19901212',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00267997',
#   'corp_name': '(주)에스티앤아이',
#   'corp_name_eng': 'ST&I Co., Ltd.',
#   'stock_name': '에스티앤아이',
#   'stock_code': '031800',
#   'ceo_nm': '김영곤',
#   'corp_cls': 'E',
#   'jurir_no': '1344110006030',
#   'bizr_no': '3038111384',
#   'adres': '경기도 화성시 동탄면 금곡리 583 ',
#   'hm_url': 'www.stnicorp.com',
#   'ir_url': '',
#   'phn_no': '031-372-4671',
#   'fax_no': '031-546-5441',
#   'induty_code': '2611',
#   'est_dt': '19940530',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00367376',
#   'corp_name': '(주)사이노젠',
#   'corp_name_eng': 'Cynogen',
#   'stock_name': '사이노젠',
#   'stock_code': '064060',
#   'ceo_nm': '주광선',
#   'corp_cls': 'E',
#   'jurir_no': '1101110739487',
#   'bizr_no': '2208106247',
#   'adres': '충청남도 천안시 입장면 가산리 273번지 ',
#   'hm_url': 'www.ctc-filter.com',
#   'ir_url': '',
#   'phn_no': '041-589-1300',
#   'fax_no': '041-588-1360',
#   'induty_code': '29174',
#   'est_dt': '19901227',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00299686',
#   'corp_name': '(주)유퍼트',
#   'corp_name_eng': 'UPERT, INC.',
#   'stock_name': '유퍼트',
#   'stock_code': '060670',
#   'ceo_nm': '조준희 / 하현',
#   'corp_cls': 'E',
#   'jurir_no': '1101110527650',
#   'bizr_no': '1238124982',
#   'adres': '충청남도 연기군 전의면 신방리 59 ',
#   'hm_url': 'www.upert.co.kr',
#   'ir_url': '',
#   'phn_no': '(041)863-6812',
#   'fax_no': '02-519-1941',
#   'induty_code': '2811',
#   'est_dt': '19870415',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00463050',
#   'corp_name': '(주)엑스로드',
#   'corp_name_eng': 'XROAD Co., Ltd.',
#   'stock_name': '엑스로드',
#   'stock_code': '074140',
#   'ceo_nm': '황규형',
#   'corp_cls': 'E',
#   'jurir_no': '1101111841926',
#   'bizr_no': '2208174221',
#   'adres': '서울특별시 강남구 신사동 503번지5 호두원빌딩6,7층 ',
#   'hm_url': 'www.myxroad.com',
#   'ir_url': '',
#   'phn_no': '02)3014-1500',
#   'fax_no': '02-548-0379',
#   'induty_code': '26429',
#   'est_dt': '20000104',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00238913',
#   'corp_name': '(주)선우중공업',
#   'corp_name_eng': 'SUNWOO HEAVY INDUSTRIES CO.,LTD',
#   'stock_name': '선우중공업',
#   'stock_code': '068770',
# ...
#   'corp_name_eng': 'WONLIM CORPORATION',
#   'stock_name': '원림',
#   'stock_code': '005820',
#   'ceo_nm': '신성엽',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110095152',
#   'bizr_no': '1198101618',
#   'adres': '서울특별시 서초구  남부순환로 2495 원림빌딩 9층',
#   'hm_url': 'www.wonlim.co.kr',
#   'ir_url': '',
#   'phn_no': '02-523-9236',
#   'fax_no': '02-581-6543',
#   'induty_code': '13225',
#   'est_dt': '19681028',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01267222',
#   'corp_name': '주식회사 캐리소프트',
#   'corp_name_eng': 'CARRIESOFT Co., Ltd.',
#   'stock_name': '캐리소프트',
#   'stock_code': '317530',
#   'ceo_nm': '박창신',
#   'corp_cls': 'K',
#   'jurir_no': '1101115551646',
#   'bizr_no': '1138691776',
#   'adres': '서울특별시 구로구 디지털로31길 20, 에이스테크노타워5차 1101호',
#   'hm_url': 'www.carriesoft.com',
#   'ir_url': 'www.carriesoft.com',
#   'phn_no': '02-2289-1452',
#   'fax_no': '02-865-0201',
#   'induty_code': '59111',
#   'est_dt': '20141030',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01158632',
#   'corp_name': '주식회사 진코스텍',
#   'corp_name_eng': 'JINCOSTECH CO.,LTD.',
#   'stock_name': '진코스텍',
#   'stock_code': '250030',
#   'ceo_nm': '김임준',
#   'corp_cls': 'N',
#   'jurir_no': '1314110243742',
#   'bizr_no': '1348668063',
#   'adres': '경기도 시흥시 군자천로237번길, 31 2나 604호 (정왕동)',
#   'hm_url': 'www.jincostech.com ',
#   'ir_url': '',
#   'phn_no': '031-433-5575',
#   'fax_no': '031-401-9489',
#   'induty_code': '20423',
#   'est_dt': '20100615',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00293886',
#   'corp_name': '(주)위닉스',
#   'corp_name_eng': 'WINIX INC.',
#   'stock_name': '위닉스',
#   'stock_code': '044340',
#   'ceo_nm': '윤희종, 윤철민',
#   'corp_cls': 'K',
#   'jurir_no': '1301110026260',
#   'bizr_no': '1338122434',
#   'adres': '경기도 시흥시 공단1대로 295(정왕동) 시화공단 3나 607호',
#   'hm_url': 'www.e-winix.co.kr',
#   'ir_url': '',
#   'phn_no': '031 -499 -5085',
#   'fax_no': '0314982618',
#   'induty_code': '28519',
#   'est_dt': '19860922',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00911229',
#   'corp_name': '(주)라온테크',
#   'corp_name_eng': 'RAONTEC Inc.',
#   'stock_name': '라온테크',
#   'stock_code': '232680',
#   'ceo_nm': '김원경',
#   'corp_cls': 'K',
#   'jurir_no': '1201110216699',
#   'bizr_no': '1218135936',
#   'adres': '경기도 수원시 권선구 산업로156번길 88-4',
#   'hm_url': 'www.raonrobot.com/',
#   'ir_url': '',
#   'phn_no': '031-201-0000',
#   'fax_no': '031-227-1500',
#   'induty_code': '29280',
#   'est_dt': '20000314',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00162780',
#   'corp_name': '한일건설(주)',
#   'corp_name_eng': 'HANIL ENGINEERING & CONSTRUCTION CO.,LTD.',
#   'stock_name': '한일건설',
#   'stock_code': '006440',
#   'ceo_nm': '양승권, 손영호',
#   'corp_cls': 'E',
#   'jurir_no': '1101110016190',
#   'bizr_no': '2208122460',
#   'adres': '서울특별시 강남구 남부순환로 2708 (도곡동, 매산빌딩) 6층',
#   'hm_url': 'www.hanilenc.com',
#   'ir_url': '',
#   'phn_no': '02-527-7000',
#   'fax_no': '02-527-7171',
#   'induty_code': '4111',
#   'est_dt': '19700220',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01582228',
#   'corp_name': '교보11호기업인수목적 주식회사',
#   'corp_name_eng': 'Kyobo 11 Special Purpose Acquisition Company',
#   'stock_name': '교보11호스팩',
#   'stock_code': '397880',
#   'ceo_nm': '이규연',
#   'corp_cls': 'K',
#   'jurir_no': '1101117980158',
#   'bizr_no': '2678702257',
#   'adres': '서울특별시 영등포구 의사당대로 97',
#   'hm_url': '',
#   'ir_url': '',
#   'phn_no': '02-3771-9424',
#   'fax_no': '',
#   'induty_code': '661',
#   'est_dt': '20210804',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00183215',
#   'corp_name': '케이디지엠텍(주)',
#   'corp_name_eng': 'alti-electronics co., ltd.',
#   'stock_name': '케이디지엠텍',
#   'stock_code': '032290',
#   'ceo_nm': '안태일',
#   'corp_cls': 'E',
#   'jurir_no': '1348110002147',
#   'bizr_no': '1248130696',
#   'adres': '경상북도 구미시 1공단로9길 85 (공단동, (주)알티전자)',
#   'hm_url': 'www.alti-e.co.kr',
#   'ir_url': '',
#   'phn_no': '054-468-5325',
#   'fax_no': '054-465-3104',
#   'induty_code': '26410',
#   'est_dt': '19721023',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00363769',
#   'corp_name': '한국전자금융(주)',
#   'corp_name_eng': 'NICE Total Cash Management Co., Ltd',
#   'stock_name': '한국전자금융',
#   'stock_code': '063570',
#   'ceo_nm': '구자성',
#   'corp_cls': 'K',
#   'jurir_no': '1101111848980',
#   'bizr_no': '2148645634',
#   'adres': '서울특별시 마포구 새창로 7 6층, 7층, 8층(도화동)',
#   'hm_url': 'www.nicetcm.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2122-5400',
#   'fax_no': '02-2122-5513',
#   'induty_code': '759',
#   'est_dt': '20000111',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00175650',
#   'corp_name': '케이씨더블류 (주)',
#   'corp_name_eng': 'Kyung Chang Wiper Corporation',
#   'stock_name': '케이씨더블류',
#   'stock_code': '068060',
#   'ceo_nm': '손 일 호',
#   'corp_cls': 'E',
#   'jurir_no': '1701110033093',
#   'bizr_no': '5038109421',
#   'adres': '대구광역시 달서구  성서공단북로 262 KCW(주)',
#   'hm_url': 'www.kc.co.kr',
#   'ir_url': '',
#   'phn_no': '053-721-1043',
#   'fax_no': '053-718-2401',
#   'induty_code': '68112',
#   'est_dt': '19880108',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01139497',
#   'corp_name': '주식회사 에스제이켐',
#   'corp_name_eng': 'SJ-CHEM Co., Ltd.',
#   'stock_name': '에스제이켐',
#   'stock_code': '217910',
#   'ceo_nm': '배동수',
#   'corp_cls': 'N',
#   'jurir_no': '1647110011772',
#   'bizr_no': '3078120911',
#   'adres': '전라북도 익산시 왕궁면 무왕로 2243-23',
#   'hm_url': 'www.sj-chem.com/',
#   'ir_url': '',
#   'phn_no': '041-881-9454',
#   'fax_no': '041-881-9457',
#   'induty_code': '201',
#   'est_dt': '20031009',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00860730',
#   'corp_name': '에이자기관리부동산투자회사(주)',
#   'corp_name_eng': 'A SELF-ADMINISTERED REAL ESTATE INVESTMENT TRUST INC.',
#   'stock_name': '에이리츠',
#   'stock_code': '140910',
#   'ceo_nm': '김종국 (단독 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101114464501',
#   'bizr_no': '1058750280',
#   'adres': '서울특별시 강남구 언주로 711 9층(논현동, 건설공제조합)',
#   'hm_url': 'www.areit.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2077-5800',
#   'fax_no': '02-2077-5877',
#   'induty_code': '68121',
#   'est_dt': '20101104',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00146232',
#   'corp_name': '일성건설(주)',
#   'corp_name_eng': 'ILSUNG CONSTRUCTION CO.,LTD',
#   'stock_name': '일성건설',
#   'stock_code': '013360',
#   'ceo_nm': '유필상',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110234776',
#   'bizr_no': '1058129640',
#   'adres': '인천광역시 남동구  인하로507번길 80 (구월동, 태광프라자402호)',
#   'hm_url': 'www.ilsungconst.co.kr',
#   'ir_url': '',
#   'phn_no': '032-429-3270',
#   'fax_no': '719-3474',
#   'induty_code': '41221',
#   'est_dt': '19780623',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01359736',
#   'corp_name': '(주)프로이천',
#   'corp_name_eng': 'PRO2000 CO.,LTD.',
#   'stock_name': '프로이천',
#   'stock_code': '321260',
#   'ceo_nm': '임이빈',
#   'corp_cls': 'K',
#   'jurir_no': '1101117042271',
#   'bizr_no': '7698601155',
#   'adres': '경기도 군포시 고산로148번길 17 군포IT밸리 411호',
#   'hm_url': '',
#   'ir_url': '',
#   'phn_no': '02-368-6296',
#   'fax_no': '02-368-6744',
#   'induty_code': '261',
#   'est_dt': '20190313',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01003040',
#   'corp_name': '(주)케이사인',
#   'corp_name_eng': 'KSIGN CO., Ltd.',
#   'stock_name': '케이사인',
#   'stock_code': '192250',
#   'ceo_nm': '최승락',
#   'corp_cls': 'K',
#   'jurir_no': '1101115300647',
#   'bizr_no': '1148713936',
#   'adres': '서울특별시 강남구 선릉로 577 b1,5층',
#   'hm_url': '없음',
#   'ir_url': 'www.ksign.com',
#   'phn_no': '02-591-2390',
#   'fax_no': '02-564-1627',
#   'induty_code': '58221',
#   'est_dt': '20131226',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01117918',
#   'corp_name': '(주)셀젠텍',
#   'corp_name_eng': 'CELLGENTEK Co., Ltd',
#   'stock_name': '셀젠텍',
#   'stock_code': '258250',
#   'ceo_nm': '김회율',
#   'corp_cls': 'N',
#   'jurir_no': '2001110168265',
#   'bizr_no': '4098172807',
#   'adres': '충청북도 청주시 흥덕구 오송읍 오송생명2로 110-6 셀젠텍',
#   'hm_url': 'cellgentek.co.kr',
#   'ir_url': '',
#   'phn_no': '043-232-9482',
#   'fax_no': '042-822-9484',
#   'induty_code': '582',
#   'est_dt': '20020802',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01203507',
#   'corp_name': '(주)에스엠비나',
#   'corp_name_eng': 'SMVINA Co.,Ltd.',
#   'stock_name': '에스엠비나',
#   'stock_code': '299670',
#   'ceo_nm': '윤동률',
#   'corp_cls': 'N',
#   'jurir_no': '1101115928366',
#   'bizr_no': '8548700198',
#   'adres': '서울특별시 마포구 마포대로 38 6층 601호(도화동, 일신빌딩)',
#   'hm_url': 'www.smvina.co.kr',
#   'ir_url': '',
#   'phn_no': '02-6953-7020',
#   'fax_no': '02-713-7030',
#   'induty_code': '14112',
#   'est_dt': '20151224',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00145260',
#   'corp_name': '율촌화학(주)',
#   'corp_name_eng': 'YOULCHON CHEMICAL CO.,LTD',
#   'stock_name': '율촌화학',
#   'stock_code': '008730',
#   'ceo_nm': '송녹정,신동윤',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110145147',
#   'bizr_no': '1188101288',
#   'adres': '서울특별시 동작구 여의대방로 112 도연관 15층',
#   'hm_url': 'www.youlchon.com',
#   'ir_url': '',
#   'phn_no': '02-822-0022',
#   'fax_no': '02-821-0956',
#   'induty_code': '22231',
#   'est_dt': '19730501',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00241236',
#   'corp_name': '(주)씨엘인터내셔널',
#   'corp_name_eng': 'CLinternational Co., Ltd.',
#   'stock_name': '씨엘인터내셔널',
#   'stock_code': '037340',
#   'ceo_nm': '이종훈',
#   'corp_cls': 'E',
#   'jurir_no': '1101111299125',
#   'bizr_no': '2208126447',
#   'adres': '경기도 성남시 중원구 둔촌대로457번길 27 (상대원동, 성남우림라이온스밸리) 1차 12층',
#   'hm_url': 'clinternational.kr/',
#   'ir_url': '',
#   'phn_no': '031-777-7330',
#   'fax_no': '031-777-7311',
#   'induty_code': '2642',
#   'est_dt': '19960719',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00114686',
#   'corp_name': '(주)동구바이오제약',
#   'corp_name_eng': 'DongKoo Bio & Pharma Co., Ltd.',
#   'stock_name': '동구바이오제약',
#   'stock_code': '006620',
#   'ceo_nm': '조용준',
#   'corp_cls': 'K',
#   'jurir_no': '1101110352156',
#   'bizr_no': '1138103336',
#   'adres': '서울특별시 송파구 법원로 114, B동 14층',
#   'hm_url': 'www.dongkoo.com',
#   'ir_url': '',
#   'phn_no': '02-2684-5421',
#   'fax_no': '02-2681-1880',
#   'induty_code': '21210',
#   'est_dt': '19830701',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00118965',
#   'corp_name': '(주)티에이치엔',
#   'corp_name_eng': 'THN CORPORATION',
#   'stock_name': '티에이치엔',
#   'stock_code': '019180',
#   'ceo_nm': '이광연, 채승훈',
#   'corp_cls': 'Y',
#   'jurir_no': '1701110022781',
#   'bizr_no': '5038119351',
#   'adres': '대구광역시 달서구 성서로71길 43',
#   'hm_url': 'www.th-net.co.kr',
#   'ir_url': '',
#   'phn_no': '053-583-3001',
#   'fax_no': '053) 587-9388',
#   'induty_code': '289',
#   'est_dt': '19860723',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01406618',
#   'corp_name': '(주)비올',
#   'corp_name_eng': 'VIOL Co., Ltd.',
#   'stock_name': '비올',
#   'stock_code': '335890',
#   'ceo_nm': '이상진',
#   'corp_cls': 'K',
#   'jurir_no': '1101117221677',
#   'bizr_no': '1268682517',
#   'adres': '경기도 성남시 분당구 판교로 744 분당테크노파크 C동 808호,809호',
#   'hm_url': 'www.viol.co.kr',
#   'ir_url': '',
#   'phn_no': '031-8017-7893',
#   'fax_no': '02-6915-5804',
#   'induty_code': '271',
#   'est_dt': '20190902',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00660459',
#   'corp_name': '나노씨엠에스(주)',
#   'corp_name_eng': 'NANOCMS CO., LTD',
#   'stock_name': '나노씨엠에스',
#   'stock_code': '247660',
#   'ceo_nm': '김시석',
#   'corp_cls': 'K',
#   'jurir_no': '1648110026753',
#   'bizr_no': '3128162155',
#   'adres': '충청남도 천안시 서북구 직산읍 4산단4로 48',
#   'hm_url': 'www.nanocms.co.kr',
#   'ir_url': '',
#   'phn_no': '041-587-3901',
#   'fax_no': '041-587-3905',
#   'induty_code': '2629',
#   'est_dt': '20030417',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00125488',
#   'corp_name': '삼륭물산(주)',
#   'corp_name_eng': 'Samryoong',
#   'stock_name': '삼륭물산',
#   'stock_code': '014970',
#   'ceo_nm': '조홍로',
#   'corp_cls': 'K',
#   'jurir_no': '1156110001401',
#   'bizr_no': '1288103148',
#   'adres': '경기도 파주시 월롱면 통일로644번길 35',
#   'hm_url': 'www.srpack.com',
#   'ir_url': '',
#   'phn_no': '02-499-0091',
#   'fax_no': '032-321-1851',
#   'induty_code': '17223',
#   'est_dt': '19800825',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00605328',
#   'corp_name': '씨앤지하이테크(주)',
#   'corp_name_eng': 'C&G Hi Tech Co., Ltd',
#   'stock_name': '씨앤지하이테크',
#   'stock_code': '264660',
#   'ceo_nm': '홍사문',
#   'corp_cls': 'K',
#   'jurir_no': '1348110072786',
#   'bizr_no': '1248198492',
#   'adres': '경기도 안성시 원곡면 승량길 162',
#   'hm_url': 'www.cnghitech.com',
#   'ir_url': '',
#   'phn_no': '031-659-9803',
#   'fax_no': '0316549229',
#   'induty_code': '29271',
#   'est_dt': '20020716',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00687711',
#   'corp_name': '한국철강(주)',
#   'corp_name_eng': 'KISCO Corp.',
#   'stock_name': '한국철강',
#   'stock_code': '104700',
#   'ceo_nm': '문종인, 이수하 (각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1942110094318',
#   'bizr_no': '6098184470',
#   'adres': '경상남도 창원시 성산구  공단로103번길 12 한국철강(주)',
#   'hm_url': 'www.kisco.co.kr',
#   'ir_url': '',
#   'phn_no': '055-260-0500',
#   'fax_no': '02-705-4525',
#   'induty_code': '2411',
#   'est_dt': '20080903',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00260879',
#   'corp_name': '카페24(주)',
#   'corp_name_eng': 'Cafe24 Corp.',
#   'stock_name': '카페24',
#   'stock_code': '042000',
#   'ceo_nm': '이재석',
#   'corp_cls': 'K',
#   'jurir_no': '1101111698145',
#   'bizr_no': '1188120586',
#   'adres': '서울특별시 동작구 보라매로5길 15',
#   'hm_url': 'www.cafe24.com',
#   'ir_url': '',
#   'phn_no': '02-3284-0300',
#   'fax_no': '02-3284-3188',
#   'induty_code': '63112',
#   'est_dt': '19990517',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00138747',
#   'corp_name': '(주)아세아텍',
#   'corp_name_eng': 'ASIA TECHNOLOGY Co., Ltd.',
#   'stock_name': '아세아텍',
#   'stock_code': '050860',
#   'ceo_nm': '김신길',
#   'corp_cls': 'K',
#   'jurir_no': '1741110000098',
#   'bizr_no': '5148100212',
#   'adres': '대구 달성군 유가면 금리 168',
#   'hm_url': 'www.asiakor.com',
#   'ir_url': '',
#   'phn_no': '053-580-7777',
#   'fax_no': '053.580.7700',
#   'induty_code': '29210',
#   'est_dt': '19780909',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00861100',
#   'corp_name': '아이케이세미콘(주)',
#   'corp_name_eng': 'IK Semicon Co., Ltd.',
#   'stock_name': '아이케이세미콘',
#   'stock_code': '149010',
#   'ceo_nm': '윤경덕',
#   'corp_cls': 'N',
#   'jurir_no': '1101112016635',
#   'bizr_no': '1138162903',
#   'adres': '서울특별시 마포구 성암로 179 8층 (상암동,한샘상암)',
#   'hm_url': 'www.iksemi.com',
#   'ir_url': '',
#   'phn_no': '02-3153-7090',
#   'fax_no': '02-3152-7090',
#   'induty_code': '2611',
#   'est_dt': '20000704',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00112907',
#   'corp_name': '코원에너지서비스(주)',
#   'corp_name_eng': 'Ko-one energy service co.,ltd.',
#   'stock_name': '코원에너지서비스',
#   'stock_code': '026870',
#   'ceo_nm': '대표이사 사극진',
#   'corp_cls': 'E',
#   'jurir_no': '1101110235617',
#   'bizr_no': '1208114525',
#   'adres': '서울특별시 강남구 남부순환로 3165 코원에너지서비스(주)',
#   'hm_url': 'www.ko-one.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3410-8000',
#   'fax_no': '3410-8080',
#   'induty_code': '35200',
#   'est_dt': '19780707',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00304915',
#   'corp_name': '코리아에셋투자증권(주)',
#   'corp_name_eng': 'KOREA ASSET INVESTMENT SECURITIES CO.,LTD.',
#   'stock_name': '코리아에셋투자증권',
#   'stock_code': '190650',
#   'ceo_nm': '기동호, 김은섭',
#   'corp_cls': 'K',
#   'jurir_no': '1101111844970',
#   'bizr_no': '1208197564',
#   'adres': '서울특별시 영등포구 여의나루로 57',
#   'hm_url': 'www.kasset.co.kr',
#   'ir_url': 'www.kasset.co.kr',
#   'phn_no': '02-550-6200',
#   'fax_no': '550-6203',
#   'induty_code': '66121',
#   'est_dt': '20000106',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01652970',
#   'corp_name': '하나금융23호기업인수목적 주식회사',
#   'corp_name_eng': 'Hana Financial Twenty-three SPAC',
#   'stock_name': '하나금융23호스팩',
#   'stock_code': '427950',
#   'ceo_nm': '박기일',
#   'corp_cls': 'K',
#   'jurir_no': '1101118261911',
#   'bizr_no': '6608102420',
#   'adres': '서울특별시 영등포구 의사당대로 82',
#   'hm_url': '',
#   'ir_url': '',
#   'phn_no': '02-3771-3754',
#   'fax_no': '',
#   'induty_code': '661',
#   'est_dt': '20220411',
#   'acc_mt': '12'},
#  ...]

# %%
# 주소를 포함한 회사 검색
result_list = find_condition(key = 'adres', value='부산진구')
print(len(result_list))
result_list
# Out:
# 2
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00100939',
#   'corp_name': '강남제비스코(주)',
#   'corp_name_eng': 'KANGNAM JEVISCO CO.,LTD',
#   'stock_name': '강남제비스코',
#   'stock_code': '000860',
#   'ceo_nm': '황익준,김재현(각자대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110003391',
#   'bizr_no': '6058103330',
#   'adres': '부산광역시 부산진구 중앙대로 639 18층(범천동, 엠디엠타워)',
#   'hm_url': 'www.jevisco.com',
#   'ir_url': '',
#   'phn_no': '051-892-4221',
#   'fax_no': '051-892-5576',
#   'induty_code': '20411',
#   'est_dt': '19520716',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00646732',
#   'corp_name': '(주)진양홀딩스',
#   'corp_name_eng': 'CHINYANG HOLDINGS CORPORATION',
#   'stock_name': '진양홀딩스',
#   'stock_code': '100250',
#   'ceo_nm': '양준영, 최창호(각자대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110618091',
#   'bizr_no': '6058186253',
#   'adres': '부산광역시 부산진구 새싹로 73 -',
#   'hm_url': 'cyholdings.kr',
#   'ir_url': '',
#   'phn_no': '051-809-8813',
#   'fax_no': '0553822592',
#   'induty_code': '222',
#   'est_dt': '20080107',
#   'acc_mt': '12'}]

# %%
# 업종코드가 일치하는 회사 검색
result_list = find_condition(key = 'induty_code', value='30', select = 'same')
print(len(result_list))
result_list
# Out:
# same
# 7
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00679730',
#   'corp_name': '(주)파브코',
#   'corp_name_eng': 'PYUNG HWA ANTI-VIBRATION SYSTEM CO., LTD.',
#   'stock_name': '파브코',
#   'stock_code': '101990',
#   'ceo_nm': '조남일',
#   'corp_cls': 'E',
#   'jurir_no': '1701110355257',
#   'bizr_no': '5148164841',
#   'adres': '대구광역시 달성군 논공읍 논공로 597',
#   'hm_url': 'pavco.co.kr',
#   'ir_url': '',
#   'phn_no': '053-610-7000',
#   'fax_no': '053-615-0566',
#   'induty_code': '30',
#   'est_dt': '20080508',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00106650',
#   'corp_name': '(주)카스코',
#   'corp_name_eng': 'KOREA AUTOMOTIVE SYSTEMS CO.,LTD',
#   'stock_name': '카스코',
#   'stock_code': '005330',
#   'ceo_nm': '이정',
#   'corp_cls': 'E',
#   'jurir_no': '1942110002593',
#   'bizr_no': '6098106829',
#   'adres': '경상남도 창원시 성산동 72번지',
#   'hm_url': 'www.kasco21.co.kr',
#   'ir_url': '',
#   'phn_no': '055-268-3500',
#   'fax_no': '0551-261-3340',
#   'induty_code': '30',
#   'est_dt': '19671209',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00165565',
#   'corp_name': '(주)디에스피이엔티',
#   'corp_name_eng': 'DSP Ent Co., Ltd.',
#   'stock_name': '디에스피이엔티',
#   'stock_code': '016040',
#   'ceo_nm': '함제열',
#   'corp_cls': 'E',
#   'jurir_no': '1301110010312',
#   'bizr_no': '1348105215',
#   'adres': '서울특별시 강남구 대치동 891-52 동보빌딩 5층 ',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '02-508-2655',
#   'fax_no': '02-508-2675',
#   'induty_code': '30',
#   'est_dt': '19820510',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00125628',
#   'corp_name': '삼목강업(주)',
#   'corp_name_eng': 'SAMMOK KANG UP CO.,LTD.',
#   'stock_name': '삼목강업',
#   'stock_code': '158380',
#   'ceo_nm': '한재열',
#   'corp_cls': 'E',
#   'jurir_no': '1101110021628',
#   'bizr_no': '1348107644',
#   'adres': '경기도 안산시 단원구 해안로 354(초지동)',
#   'hm_url': 'www.sammokspring.co.kr',
#   'ir_url': '',
#   'phn_no': '031-412-0316',
#   'fax_no': '031-491-0891',
#   'induty_code': '30',
#   'est_dt': '19700401',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00334244',
#   'corp_name': '덴소코리아주식회사',
#   'corp_name_eng': 'DENSOKOREAAUTOMOTIVECORPORATION',
#   'stock_name': '덴소코리아',
#   'stock_code': '047060',
#   'ceo_nm': '김경섭',
#   'corp_cls': 'E',
#   'jurir_no': '1942110000141',
#   'bizr_no': '6098101877',
#   'adres': '경상남도 창원시 성산구 웅남로 630 (성산동)',
#   'hm_url': 'www.densops.co.kr',
#   'ir_url': '',
#   'phn_no': '055-600-9553',
#   'fax_no': '055-600-9516',
#   'induty_code': '30',
#   'est_dt': '20000801',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00116806',
#   'corp_name': '주식회사 하스코',
#   'corp_name_eng': 'HASCO.CO.,LTD',
#   'stock_name': '하스코',
#   'stock_code': '012760',
#   'ceo_nm': '김동후',
#   'corp_cls': 'E',
#   'jurir_no': '1345110002135',
#   'bizr_no': '1358102394',
#   'adres': '경기도 안성시 공단1로 121 (신건지동)',
#   'hm_url': 'www.dongapm.co.kr',
#   'ir_url': 'http://www.has-co.co.kr',
#   'phn_no': '031-672-2462',
#   'fax_no': '031-672-2464',
#   'induty_code': '30',
#   'est_dt': '19771207',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00430089',
#   'corp_name': '삼보오토(주)',
#   'corp_name_eng': 'SAMBOAUTO. Co., Ltd',
#   'stock_name': '삼보오토',
#   'stock_code': '070080',
#   'ceo_nm': '최찬규',
#   'corp_cls': 'E',
#   'jurir_no': '1314110133612',
#   'bizr_no': '1348192156',
#   'adres': '경기도 안산시 단원구 해봉로 195',
#   'hm_url': 'www.samboauto.com',
#   'ir_url': '',
#   'phn_no': '031-489-9405',
#   'fax_no': '031-489-9499',
#   'induty_code': '30',
#   'est_dt': '20021113',
#   'acc_mt': '12'}]

# %%
# 유가증권 시장에 속하는 회사의 기업개황
result_list = find_condition(key = 'corp_cls', value='Y')
len(result_list)
result_list
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00600013',
#   'corp_name': '미래에셋맵스 아시아퍼시픽 부동산공모 1호 투자회사',
#   'corp_name_eng': 'MIRAEASSETMAPS ASIA PACIFIC REAL ESTATE 1 INVESTMENT COMPANY',
#   'stock_name': '맵스리얼티1',
#   'stock_code': '094800',
#   'ceo_nm': '미래에셋자산운용(주)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101113595852',
#   'bizr_no': '1078686211',
#   'adres': '서울 영등포구 여의도동 미래에셋빌딩 45-1',
#   'hm_url': 'www.miraeasset.com',
#   'ir_url': '',
#   'phn_no': '02-1577-1640',
#   'fax_no': '02-769-7816',
#   'induty_code': '642',
#   'est_dt': '20070109',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00435297',
#   'corp_name': '맥쿼리한국인프라투융자회사',
#   'corp_name_eng': 'Macquarie Korea Infrastructure Fund',
#   'stock_name': '맥쿼리인프라',
#   'stock_code': '088980',
#   'ceo_nm': '맥쿼리자산운용(주)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112672586',
#   'bizr_no': '1048177509',
#   'adres': '서울특별시 종로구 우정국로 26 A동 18층(공평동, 센트로폴리스)',
#   'hm_url': 'www.macquarie.com/kr/kr/mkif/index.html',
#   'ir_url': '',
#   'phn_no': '02-3705-8565',
#   'fax_no': '02-3770-4444',
#   'induty_code': '64201',
#   'est_dt': '20021212',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00173944',
#   'corp_name': '(주)우진',
#   'corp_name_eng': 'WOOJIN INC',
#   'stock_name': '우진',
#   'stock_code': '105840',
#   'ceo_nm': '이재상, 백승한 각자대표',
#   'corp_cls': 'Y',
#   'jurir_no': '1345110001814',
#   'bizr_no': '1358105713',
#   'adres': '경기도 화성시 동부대로970번길 110',
#   'hm_url': 'www.woojininc.com',
#   'ir_url': '',
#   'phn_no': '031-379-3114',
#   'fax_no': '031-379-3131',
#   'induty_code': '27216',
#   'est_dt': '19800513',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00109286',
#   'corp_name': '(주)대동',
#   'corp_name_eng': 'DAEDONG CORPORATION',
#   'stock_name': '대동',
#   'stock_code': '000490',
#   'ceo_nm': '김준식, 원유현',
#   'corp_cls': 'Y',
#   'jurir_no': '1911110000104',
#   'bizr_no': '5148106690',
#   'adres': '대구광역시 달성군 논공읍 논공중앙로34길 35 35',
#   'hm_url': 'www.daedong.co.kr',
#   'ir_url': '',
#   'phn_no': '053-610-3000',
#   'fax_no': '(02) 583-3646',
#   'induty_code': '29210',
#   'est_dt': '19470520',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00129350',
#   'corp_name': '삼화콘덴서공업(주)',
#   'corp_name_eng': 'SAMWHA CAPACITOR CO.,LTD',
#   'stock_name': '삼화콘덴서공업',
#   'stock_code': '001820',
#   'ceo_nm': '오영주, 박진',
#   'corp_cls': 'Y',
#   'jurir_no': '1345110003696',
#   'bizr_no': '1358102429',
#   'adres': '경기도 용인시 처인구  남사면 경기동로 227',
#   'hm_url': 'www.samwha.com',
#   'ir_url': '',
#   'phn_no': '031-332-6441',
#   'fax_no': '031-332-7661',
#   'induty_code': '26291',
#   'est_dt': '19560814',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00144252',
#   'corp_name': '(주)유니온',
#   'corp_name_eng': 'UNION CORPORATION',
#   'stock_name': '유니온',
#   'stock_code': '000910',
#   'ceo_nm': '이건영, 이우선',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110200579',
#   'bizr_no': '1048124962',
#   'adres': '서울특별시 중구  소공로 94 OCI빌딩 13층',
#   'hm_url': 'www.unioncement.com',
#   'ir_url': '',
#   'phn_no': '02-3455-8793',
#   'fax_no': '(02) 757 - 3807~8',
#   'induty_code': '23311',
#   'est_dt': '19521206',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00303217',
#   'corp_name': '(주)우진플라임',
#   'corp_name_eng': 'WOOJIN PLAIMM CO.,LTD',
#   'stock_name': '우진플라임',
#   'stock_code': '049800',
#   'ceo_nm': '김익환',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110822993',
#   'bizr_no': '1318139905',
#   'adres': '충청북도 보은군 장안면 우진플라임로 100 본관동',
#   'hm_url': 'www.woojinplaimm.com',
#   'ir_url': 'http://www.woojinplaimm.com/kor/main/index.php',
#   'phn_no': '043-540-9000',
#   'fax_no': '043-543-1140',
#   'induty_code': '292',
#   'est_dt': '19920103',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00134723',
#   'corp_name': '페이퍼코리아(주)',
#   'corp_name_eng': 'PaperCorea Inc.',
#   'stock_name': '페이퍼코리아',
#   'stock_code': '001020',
#   'ceo_nm': '권육상',
#   'corp_cls': 'Y',
#   'jurir_no': '2111110000042',
#   'bizr_no': '4018100013',
#   'adres': '전라북도 군산시 외항로 1245 페이퍼코리아(주)',
#   'hm_url': 'www.papercorea.co.kr',
#   'ir_url': '',
#   'phn_no': '063-440-5000',
#   'fax_no': '02-730-0371',
#   'induty_code': '17121',
#   'est_dt': '19530606',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00167192',
#   'corp_name': '(주)넥센',
#   'corp_name_eng': 'NEXEN CORPORATION',
#   'stock_name': '넥센',
#   'stock_code': '005720',
#   'ceo_nm': '강병중, 강호찬, 배중열',
#   'corp_cls': 'Y',
#   'jurir_no': '1846110000583',
#   'bizr_no': '6188115827',
#   'adres': '경상남도 김해시  김해대로 2595',
#   'hm_url': 'www.nexencorp.co.kr',
#   'ir_url': '',
#   'phn_no': '055-333-0771',
#   'fax_no': '055-333-0778',
#   'induty_code': '221',
#   'est_dt': '19680910',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01036446',
#   'corp_name': '(주)서연이화',
#   'corp_name_eng': 'SEOYON E-HWA CO.,LTD.',
#   'stock_name': '서연이화',
#   'stock_code': '200880',
#   'ceo_nm': '강용석',
#   'corp_cls': 'Y',
#   'jurir_no': '1101115455476',
#   'bizr_no': '2208882958',
#   'adres': '경기도 안양시 동안구 부림로170번길 41-22 (관양동)',
#   'hm_url': 'www.seoyoneh.com',
#   'ir_url': '',
#   'phn_no': '031-420-3200',
#   'fax_no': '031-420-3170',
#   'induty_code': '303',
#   'est_dt': '20140702',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00112970',
#   'corp_name': '대한방직(주)',
#   'corp_name_eng': 'TAIHAN TEXTILE CO.,LTD',
#   'stock_name': '대한방직',
#   'stock_code': '001070',
#   'ceo_nm': '설 범, 김 인호',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110019350',
#   'bizr_no': '1168133353',
#   'adres': '서울특별시 중구 중림로 48 (중림동, 성준빌딩)',
#   'hm_url': 'www.thtc.co.kr',
#   'ir_url': '',
#   'phn_no': '02-368-0114',
#   'fax_no': '02-368-0461',
#   'induty_code': '132',
#   'est_dt': '19530810',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00129554',
#   'corp_name': '(주)갤럭시아 에스엠',
#   'corp_name_eng': 'Galaxia SM, INC.',
#   'stock_name': '갤럭시아에스엠',
#   'stock_code': '011420',
#   'ceo_nm': '이반석',
#   'corp_cls': 'Y',
#   'jurir_no': '1301110008771',
#   'bizr_no': '1348102367',
#   'adres': '서울특별시 강남구  학동로 311 미성빌딩 7층',
#   'hm_url': 'galaxiasme.com',
#   'ir_url': '',
#   'phn_no': '02-775-1300',
#   'fax_no': '02-775-1301',
#   'induty_code': '911',
#   'est_dt': '19750506',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00361008',
#   'corp_name': '에이치에스디엔진(주)',
#   'corp_name_eng': 'HSD Engine Co., Ltd.',
#   'stock_name': 'HSD엔진',
#   'stock_code': '082740',
#   'ceo_nm': '고영열',
#   'corp_cls': 'Y',
#   'jurir_no': '1942110038423',
#   'bizr_no': '6098140128',
#   'adres': '경상남도 창원시 성산구 공단로 67 (신촌동)',
#   'hm_url': 'www.hsdengine.com',
#   'ir_url': '',
#   'phn_no': '055-260-6000',
#   'fax_no': '055-260-6899',
#   'induty_code': '29111',
#   'est_dt': '19991230',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00163691',
#   'corp_name': '(주)유수홀딩스',
#   'corp_name_eng': 'EUSU HOLDINGS CO., LTD.',
#   'stock_name': '유수홀딩스',
#   'stock_code': '000700',
#   'ceo_nm': '송영규',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110003262',
#   'bizr_no': '1168135822',
#   'adres': '서울특별시 영등포구 여의나루로 60 9층 (여의도동, 포스트타워)',
#   'hm_url': 'www.eusu-holdings.com',
#   'ir_url': '',
#   'phn_no': '02-6716-3000',
#   'fax_no': '3770-6742',
#   'induty_code': '715',
#   'est_dt': '19500101',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00197759',
#   'corp_name': '미래산업(주)',
#   'corp_name_eng': 'MIRAE CORPORATION',
#   'stock_name': '미래산업',
#   'stock_code': '025560',
#   'ceo_nm': '선종업',
#   'corp_cls': 'Y',
#   'jurir_no': '1243110030413',
#   'bizr_no': '3128115889',
#   'adres': '충청남도 천안시 서북구 백석공단7로 65 (백석동)',
#   'hm_url': 'www.mirae.co.kr',
#   'ir_url': '',
#   'phn_no': '041-621-5070',
#   'fax_no': '041)559-8789',
#   'induty_code': '27219',
#   'est_dt': '19901226',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00113492',
#   'corp_name': '깨끗한나라(주)',
#   'corp_name_eng': 'KleanNara Co., Ltd.',
#   'stock_name': '깨끗한나라',
#   'stock_code': '004540',
#   'ceo_nm': '최현수, 김민환',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110063779',
#   'bizr_no': '2018112618',
#   'adres': '서울특별시 용산구 한남대로 98 일신빌딩 4층',
#   'hm_url': 'www.kleannara.com',
#   'ir_url': '',
#   'phn_no': '02-2270-9200',
#   'fax_no': '02-2270-9242',
#   'induty_code': '1712',
#   'est_dt': '19660307',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00260392',
#   'corp_name': '대원전선(주)',
#   'corp_name_eng': 'DAWON CABLE CO.,LTD',
#   'stock_name': '대원전선',
#   'stock_code': '006340',
#   'ceo_nm': '서명환',
#   'corp_cls': 'Y',
#   'jurir_no': '1348110001181',
#   'bizr_no': '1248105047',
#   'adres': '충청남도 예산군  고덕면 호음덕령길 92',
#   'hm_url': 'www.daewoncable.co.kr',
#   'ir_url': '',
#   'phn_no': '041-339-3400',
#   'fax_no': '041-339-3406',
#   'induty_code': '28302',
#   'est_dt': '19691129',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00111421',
#   'corp_name': '(주)휴니드테크놀러지스',
#   'corp_name_eng': 'HUNEED TECHNOLOGIES',
#   'stock_name': '휴니드테크놀러지스',
#   'stock_code': '005870',
#   'ceo_nm': '신종석',
#   'corp_cls': 'Y',
#   'jurir_no': '1341110005202',
#   'bizr_no': '1238106174',
#   'adres': '인천광역시 연수구  벤처로 87',
#   'hm_url': 'www.huneed.com',
#   'ir_url': '',
#   'phn_no': '032-457-6000',
#   'fax_no': '032-457-6040',
#   'induty_code': '2642',
#   'est_dt': '19681211',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00128980',
#   'corp_name': '삼호개발(주)',
#   'corp_name_eng': 'SAMHO DEVELOPMENT CO',
#   'stock_name': '삼호개발',
#   'stock_code': '010960',
#   'ceo_nm': '심재범',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110190340',
#   'bizr_no': '2208114806',
#   'adres': '충청남도 당진시  면천면 면천로 183',
#   'hm_url': 'www.samhodev.co.kr/',
#   'ir_url': '',
#   'phn_no': '02-2046-7722',
#   'fax_no': '02-556-5777',
#   'induty_code': '421',
#   'est_dt': '19760115',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00149354',
#   'corp_name': '(주)종근당홀딩스',
#   'corp_name_eng': 'CHONGKUNDANG HOLDINGS CORP.',
#   'stock_name': '종근당홀딩스',
#   'stock_code': '001630',
#   'ceo_nm': '김태영',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110028955',
#   'bizr_no': '1138106667',
#   'adres': '서울특별시 서대문구  충정로 8 종근당빌딩',
#   'hm_url': 'www.ckd-holdings.com',
#   'ir_url': 'www.ckd-holdings.com',
#   'phn_no': '02-6373-0600',
#   'fax_no': '02-6373-0659',
#   'induty_code': '212',
#   'est_dt': '19560110',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00486705',
#   'corp_name': '아주스틸(주)',
#   'corp_name_eng': 'AJUSTEEL CO.,LTD.',
#   'stock_name': '아주스틸',
#   'stock_code': '139990',
#   'ceo_nm': '이학연',
#   'corp_cls': 'Y',
#   'jurir_no': '1760110020145',
#   'bizr_no': '5138116496',
#   'adres': '경상북도 구미시 4공단로 321',
#   'hm_url': 'www.ajusteel.com',
#   'ir_url': '',
#   'phn_no': '054-714-3657',
#   'fax_no': '054-714-3010',
#   'induty_code': '2419',
#   'est_dt': '19991029',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00153524',
#   'corp_name': '태림포장(주)',
#   'corp_name_eng': 'Tailim Packaging Co., Ltd',
#   'stock_name': '태림포장',
#   'stock_code': '011280',
#   'ceo_nm': '이복진',
#   'corp_cls': 'Y',
#   'jurir_no': '1301110010015',
#   'bizr_no': '1338122623',
#   'adres': '경기도 시흥시 공단1대로379번안길 74',
#   'hm_url': 'www.tailim.com',
#   'ir_url': '',
#   'phn_no': '031-499-3333',
#   'fax_no': '031)498-1115',
#   'induty_code': '1721',
#   'est_dt': '19760412',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00274933',
#   'corp_name': '(주)신세계푸드',
#   'corp_name_eng': 'SHINSEGAE FOOD Inc.',
#   'stock_name': '신세계푸드',
#   'stock_code': '031440',
#   'ceo_nm': '송현석',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110305288',
#   'bizr_no': '2158147377',
#   'adres': '서울특별시 성동구 성수일로 56 성수동BY센터 4-7층(성수동2가, 백영 성수빌딩)',
#   'hm_url': 'www.shinsegaefood.com',
#   'ir_url': '',
#   'phn_no': '02-3397-6000',
#   'fax_no': '02-3397-6198',
#   'induty_code': '56130',
#   'est_dt': '19791011',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00105156',
#   'corp_name': '극동유화(주)',
#   'corp_name_eng': 'KUKDONG OIL & CHEMICALS CO.,LTD',
#   'stock_name': '극동유화',
#   'stock_code': '014530',
#   'ceo_nm': '장홍선, 장선우 (각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1845110001335',
#   'bizr_no': '6218100510',
#   'adres': '경상남도 양산시  어실로 101',
#   'hm_url': 'www.kdoc.co.kr',
#   'ir_url': '',
#   'phn_no': '055-370-9900',
#   'fax_no': '055-383-9918',
#   'induty_code': '19221',
#   'est_dt': '19791228',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01262032',
#   'corp_name': '롯데정보통신(주)',
#   'corp_name_eng': 'LOTTE DATA COMMUNICATION COMPANY',
#   'stock_name': '롯데정보통신',
#   'stock_code': '286940',
#   'ceo_nm': '노준형',
#   'corp_cls': 'Y',
#   'jurir_no': '1101116557114',
#   'bizr_no': '6878100785',
#   'adres': '서울특별시 금천구 가산디지털2로 179 롯데정보통신',
#   'hm_url': 'www.ldcc.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2626-4000',
#   'fax_no': '02-6234-1500',
#   'induty_code': '62021',
#   'est_dt': '20171102',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00838500',
#   'corp_name': '엘브이엠씨홀딩스(주)',
#   'corp_name_eng': 'LVMC Holdings CO,.LTD',
#   'stock_name': '엘브이엠씨',
#   'stock_code': '900140',
#   'ceo_nm': '오세영, 노성석, 김선발 (각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '',
#   'bizr_no': '1048407756',
#   'adres': 'PO Box 309, Ugland House, Grand Cayman, KY1-1104, Cayman Islands',
#   'hm_url': 'http://www.lvmcholdings.net',
#   'ir_url': '',
#   'phn_no': '070-8615-4824',
#   'fax_no': '02-6280-5118',
#   'induty_code': '451',
#   'est_dt': '20090616',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00145163',
#   'corp_name': '파미셀(주)',
#   'corp_name_eng': 'Pharmicell Co.,Ltd.',
#   'stock_name': '파미셀',
#   'stock_code': '005690',
#   'ceo_nm': '김현수',
#   'corp_cls': 'Y',
#   'jurir_no': '1601110005177',
#   'bizr_no': '3148100664',
#   'adres': '서울특별시 강남구 언주로 874 (신사동, 쌍봉빌딩 7층)',
#   'hm_url': 'www.pharmicell.com',
#   'ir_url': '',
#   'phn_no': '02-3496-0114',
#   'fax_no': '02-3496-0149',
#   'induty_code': '21102',
#   'est_dt': '19680820',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00365989',
#   'corp_name': '주식회사 용평리조트',
#   'corp_name_eng': 'YONG PYONG RESORT CORPORATION',
#   'stock_name': '용평리조트',
#   'stock_code': '070960',
#   'ceo_nm': '신달순, 임학운 공동대표',
#   'corp_cls': 'Y',
#   'jurir_no': '1450110002801',
#   'bizr_no': '2268124374',
#   'adres': '강원도 평창군  대관령면 올림픽로 715',
#   'hm_url': 'www.yongpyong.co.kr',
#   'ir_url': '',
#   'phn_no': '033-330-8350',
#   'fax_no': '033-335-5769',
#   'induty_code': '55103',
#   'est_dt': '20000214',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00146649',
#   'corp_name': '일진홀딩스(주)',
#   'corp_name_eng': 'ILJIN HOLDINGS CO.,LTD',
#   'stock_name': '일진홀딩스',
#   'stock_code': '015860',
#   'ceo_nm': '허정석',
#   'corp_cls': 'Y',
#   'jurir_no': '1201110011990',
#   'bizr_no': '1248134732',
#   'adres': '경기도 화성시  만년로 905-17',
#   'hm_url': 'www.iljin.co.kr',
#   'ir_url': '',
#   'phn_no': '031-220-0500',
#   'fax_no': '02-707-9698',
#   'induty_code': '64992',
#   'est_dt': '19820127',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00148443',
#   'corp_name': '제일파마홀딩스(주)',
#   'corp_name_eng': 'JEIL PHARMA HOLDINGS INC.',
#   'stock_name': '제일파마홀딩스',
#   'stock_code': '002620',
#   'ceo_nm': '한상철',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110026652',
#   'bizr_no': '1148101234',
#   'adres': '서울특별시 서초구 사평대로 343',
#   'hm_url': 'www.jeilpharm.co.kr',
#   'ir_url': '',
#   'phn_no': '02-549-7451',
#   'fax_no': '02-518-6485',
#   'induty_code': '715',
#   'est_dt': '19590307',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00164672',
#   'corp_name': '한일현대시멘트(주)',
#   'corp_name_eng': 'HANIL HYUNDAI CEMENT CO.,LTD',
#   'stock_name': '한일현대시멘트',
#   'stock_code': '006390',
#   'ceo_nm': '전근식',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110111867',
#   'bizr_no': '2148124240',
#   'adres': '서울특별시 서초구 효령로 275 서초동 1587 한일시멘트빌딩',
#   'hm_url': 'WWW.HANILHDCEMENT.COM',
#   'ir_url': '',
#   'phn_no': '02-520-2114',
#   'fax_no': '520-2118',
#   'induty_code': '23311',
#   'est_dt': '19691230',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00107066',
#   'corp_name': '남광토건(주)',
#   'corp_name_eng': 'NAMKWANG ENGINEERING & CONSTRUCTION CO.,LTD',
#   'stock_name': '남광토건',
#   'stock_code': '001260',
#   'ceo_nm': '임민규',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110017411',
#   'bizr_no': '1208101995',
#   'adres': '경기도 용인시 기흥구 흥덕중앙로 120 비122호(영덕동, 흥덕유타워)',
#   'hm_url': 'www.namkwang.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3011-0114',
#   'fax_no': '02-3011-0111',
#   'induty_code': '41221',
#   'est_dt': '19540805',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00148939',
#   'corp_name': '조광피혁(주)',
#   'corp_name_eng': 'CHOKWANG LEATHER CO.,LTD',
#   'stock_name': '조광피혁',
#   'stock_code': '004700',
#   'ceo_nm': '이연석',
#   'corp_cls': 'Y',
#   'jurir_no': '1501110001036',
#   'bizr_no': '3158107132',
#   'adres': '충청북도 청주시 흥덕구 공단로126번길 97 (송정동, 공단2브럭)',
#   'hm_url': 'www.chokwang.co.kr',
#   'ir_url': '',
#   'phn_no': '043-270-5311-3',
#   'fax_no': '02-553-6997',
#   'induty_code': '15110',
#   'est_dt': '19660803',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00117337',
#   'corp_name': '(주)동양',
#   'corp_name_eng': 'TONGYANG Inc',
#   'stock_name': '동양',
#   'stock_code': '001520',
#   'ceo_nm': '정진학',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110005333',
#   'bizr_no': '1168134352',
#   'adres': '서울특별시 영등포구 국제금융로2길 24 -',
#   'hm_url': 'www.tongyanginc.co.kr',
#   'ir_url': 'www.tongyanginc.co.kr',
#   'phn_no': '02-6150-7000',
#   'fax_no': '02-6150-7159',
#   'induty_code': '23322',
#   'est_dt': '19550825',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00128032',
#   'corp_name': '삼일제약(주)',
#   'corp_name_eng': 'SAMIL PHARMACEUTICAL CO.,LTD',
#   'stock_name': '삼일제약',
#   'stock_code': '000520',
#   'ceo_nm': '허승범, 김상진 (각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110016679',
#   'bizr_no': '1148116848',
#   'adres': '서울특별시 서초구  효령로 155 (방배동, 삼일제약 사옥)',
#   'hm_url': 'www.samil-pharm.com',
#   'ir_url': '',
#   'phn_no': '02-520-0300',
#   'fax_no': '588-0988',
#   'induty_code': '21210',
#   'est_dt': '19471007',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01234297',
#   'corp_name': '미원스페셜티케미칼(주)',
#   'corp_name_eng': 'Miwon Specialty Chemical Co., Ltd.',
#   'stock_name': '미원에스씨',
#   'stock_code': '268280',
#   'ceo_nm': '김형웅, 배원',
#   'corp_cls': 'Y',
#   'jurir_no': '2101110123944',
#   'bizr_no': '7788700797',
#   'adres': '전라북도 완주군 봉동읍 완주산단1로 167',
#   'hm_url': 'www.miramer.co.kr',
#   'ir_url': '',
#   'phn_no': '063-260-1500',
#   'fax_no': '031-471-4334',
#   'induty_code': '201',
#   'est_dt': '20170501',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00140946',
#   'corp_name': '한솔로지스틱스(주)',
#   'corp_name_eng': 'Hansol Logistics CO., Ltd',
#   'stock_name': '한솔로지스틱스',
#   'stock_code': '009180',
#   'ceo_nm': '황규호',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110150659',
#   'bizr_no': '1028141359',
#   'adres': '서울특별시 중구 을지로 100 파인애비뉴 B동 22층',
#   'hm_url': 'www.hansollogistics.com',
#   'ir_url': '',
#   'phn_no': '02-3287-7400',
#   'fax_no': '02-6031-0981',
#   'induty_code': '5299',
#   'est_dt': '19730814',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00108746',
#   'corp_name': '(주)큐로',
#   'corp_name_eng': 'CURO CO., LTD.',
#   'stock_name': '큐로',
#   'stock_code': '015590',
#   'ceo_nm': '서상훈',
#   'corp_cls': 'Y',
#   'jurir_no': '1812110002275',
#   'bizr_no': '6108102779',
#   'adres': '울산광역시 남구  처용로 260-37',
#   'hm_url': 'www.curo.co.kr',
#   'ir_url': '',
#   'phn_no': '052-278-9000',
#   'fax_no': '052-278-9150',
#   'induty_code': '29176',
#   'est_dt': '19810930',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00122056',
#   'corp_name': '미창석유공업(주)',
#   'corp_name_eng': 'MICHANG OIL IND CO.,LTD',
#   'stock_name': '미창석유공업',
#   'stock_code': '003650',
#   'ceo_nm': '유재순',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110000537',
#   'bizr_no': '6018108046',
#   'adres': '부산광역시 영도구 해양로 241 미창석유',
#   'hm_url': 'www.michang.co.kr',
#   'ir_url': '',
#   'phn_no': '051-403-6441',
#   'fax_no': '051-403-6440',
#   'induty_code': '19221',
#   'est_dt': '19621227',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00166272',
#   'corp_name': '(주)화승코퍼레이션',
#   'corp_name_eng': 'Hwaseung Corporation CO., LTD ',
#   'stock_name': '화승코퍼레이션',
#   'stock_code': '013520',
#   'ceo_nm': '허성룡,현지호',
#   'corp_cls': 'Y',
#   'jurir_no': '1845110001252',
#   'bizr_no': '6218105780',
#   'adres': '부산광역시 연제구 중앙대로 1079 -',
#   'hm_url': 'www.hscorp.com',
#   'ir_url': 'http://www.hscorp.com',
#   'phn_no': '051-717-7300',
#   'fax_no': '055-387-8027',
#   'induty_code': '303',
#   'est_dt': '19780915',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00162063',
#   'corp_name': '한신공영(주)',
#   'corp_name_eng': 'HANSHIN CONSTRUCTION CO.,LTD',
#   'stock_name': '한신공영',
#   'stock_code': '004960',
#   'ceo_nm': '최문규,선홍규(각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110075683',
#   'bizr_no': '1148104605',
#   'adres': '경기도 용인시 처인구  백암면 덕평로 82',
#   'hm_url': 'www.hanshinc.com',
#   'ir_url': '',
#   'phn_no': '02-3393-3114',
#   'fax_no': '02-3393-3159',
#   'induty_code': '41112',
#   'est_dt': '19670224',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00138516',
#   'corp_name': '아남전자(주)',
#   'corp_name_eng': 'ANAM ELECTRONICS CO.,LTD',
#   'stock_name': '아남전자',
#   'stock_code': '008700',
#   'ceo_nm': '김태수',
#   'corp_cls': 'Y',
#   'jurir_no': '1201110018300',
#   'bizr_no': '1228102613',
#   'adres': '서울특별시 구로구 디지털로27가길 27아남빌딩',
#   'hm_url': 'www.aname.co.kr',
#   'ir_url': '',
#   'phn_no': '02-6424-4700',
#   'fax_no': '02-6424-4799',
#   'induty_code': '265',
#   'est_dt': '19730420',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00117498',
#   'corp_name': '스틱인베스트먼트(주)',
#   'corp_name_eng': 'STIC Investments, Inc.',
#   'stock_name': '스틱인베스트먼트',
#   'stock_code': '026890',
#   'ceo_nm': '곽동걸, 곽대환',
#   'corp_cls': 'Y',
#   'jurir_no': '1243110008204',
#   'bizr_no': '1348107979',
#   'adres': '서울특별시 강남구 테헤란로78길 12 MSA빌딩',
#   'hm_url': 'www.stic.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3404-7800',
#   'fax_no': '02-3404-7890',
#   'induty_code': '64201',
#   'est_dt': '19820624',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01035289',
#   'corp_name': '(주)모두투어자기관리부동산투자회사',
#   'corp_name_eng': 'MODE TOUR Real Estate Investment Trust Incorporated',
#   'stock_name': '모두투어리츠',
#   'stock_code': '204210',
#   'ceo_nm': '최동주',
#   'corp_cls': 'Y',
#   'jurir_no': '1101115313731',
#   'bizr_no': '1048653123',
#   'adres': '서울특별시 중구 퇴계로 173 12층(충무로3가, 남산스퀘어)',
#   'hm_url': 'www.modetourreit.com',
#   'ir_url': '',
#   'phn_no': '02-6253-5911',
#   'fax_no': '0262535912',
#   'induty_code': '681',
#   'est_dt': '20140110',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00143794',
#   'corp_name': '(주)원림',
#   'corp_name_eng': 'WONLIM CORPORATION',
#   'stock_name': '원림',
#   'stock_code': '005820',
#   'ceo_nm': '신성엽',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110095152',
#   'bizr_no': '1198101618',
#   'adres': '서울특별시 서초구  남부순환로 2495 원림빌딩 9층',
#   'hm_url': 'www.wonlim.co.kr',
#   'ir_url': '',
#   'phn_no': '02-523-9236',
#   'fax_no': '02-581-6543',
#   'induty_code': '13225',
#   'est_dt': '19681028',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00860730',
#   'corp_name': '에이자기관리부동산투자회사(주)',
#   'corp_name_eng': 'A SELF-ADMINISTERED REAL ESTATE INVESTMENT TRUST INC.',
#   'stock_name': '에이리츠',
#   'stock_code': '140910',
#   'ceo_nm': '김종국 (단독 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101114464501',
#   'bizr_no': '1058750280',
#   'adres': '서울특별시 강남구 언주로 711 9층(논현동, 건설공제조합)',
#   'hm_url': 'www.areit.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2077-5800',
#   'fax_no': '02-2077-5877',
#   'induty_code': '68121',
#   'est_dt': '20101104',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00146232',
#   'corp_name': '일성건설(주)',
#   'corp_name_eng': 'ILSUNG CONSTRUCTION CO.,LTD',
#   'stock_name': '일성건설',
#   'stock_code': '013360',
#   'ceo_nm': '유필상',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110234776',
#   'bizr_no': '1058129640',
#   'adres': '인천광역시 남동구  인하로507번길 80 (구월동, 태광프라자402호)',
#   'hm_url': 'www.ilsungconst.co.kr',
#   'ir_url': '',
#   'phn_no': '032-429-3270',
#   'fax_no': '719-3474',
#   'induty_code': '41221',
#   'est_dt': '19780623',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00145260',
#   'corp_name': '율촌화학(주)',
#   'corp_name_eng': 'YOULCHON CHEMICAL CO.,LTD',
#   'stock_name': '율촌화학',
#   'stock_code': '008730',
#   'ceo_nm': '송녹정,신동윤',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110145147',
#   'bizr_no': '1188101288',
#   'adres': '서울특별시 동작구 여의대방로 112 도연관 15층',
#   'hm_url': 'www.youlchon.com',
#   'ir_url': '',
#   'phn_no': '02-822-0022',
#   'fax_no': '02-821-0956',
#   'induty_code': '22231',
#   'est_dt': '19730501',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00118965',
#   'corp_name': '(주)티에이치엔',
#   'corp_name_eng': 'THN CORPORATION',
#   'stock_name': '티에이치엔',
#   'stock_code': '019180',
#   'ceo_nm': '이광연, 채승훈',
#   'corp_cls': 'Y',
#   'jurir_no': '1701110022781',
#   'bizr_no': '5038119351',
#   'adres': '대구광역시 달서구 성서로71길 43',
#   'hm_url': 'www.th-net.co.kr',
#   'ir_url': '',
#   'phn_no': '053-583-3001',
#   'fax_no': '053) 587-9388',
#   'induty_code': '289',
#   'est_dt': '19860723',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00687711',
#   'corp_name': '한국철강(주)',
#   'corp_name_eng': 'KISCO Corp.',
#   'stock_name': '한국철강',
#   'stock_code': '104700',
#   'ceo_nm': '문종인, 이수하 (각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1942110094318',
#   'bizr_no': '6098184470',
#   'adres': '경상남도 창원시 성산구  공단로103번길 12 한국철강(주)',
#   'hm_url': 'www.kisco.co.kr',
#   'ir_url': '',
#   'phn_no': '055-260-0500',
#   'fax_no': '02-705-4525',
#   'induty_code': '2411',
#   'est_dt': '20080903',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00157991',
#   'corp_name': '한국석유공업(주)',
#   'corp_name_eng': 'KOREA PETROLEUM INDUSTRIES COMPANY',
#   'stock_name': '한국석유공업',
#   'stock_code': '004090',
#   'ceo_nm': '강승모,김득보(각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110048490',
#   'bizr_no': '1068103639',
#   'adres': '서울특별시 용산구  이촌로 166',
#   'hm_url': 'www.koreapetroleum.com',
#   'ir_url': '',
#   'phn_no': '02-799-3114',
#   'fax_no': '02-793-7833',
#   'induty_code': '23999',
#   'est_dt': '19641211',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01475609',
#   'corp_name': '주식회사 디앤디플랫폼위탁관리부동산투자회사',
#   'corp_name_eng': 'D&D Platform REIT Co., Ltd.',
#   'stock_name': '디앤디플랫폼리츠',
#   'stock_code': '377190',
#   'ceo_nm': '이양원',
#   'corp_cls': 'Y',
#   'jurir_no': '1101117420211',
#   'bizr_no': '8398101589',
#   'adres': '서울특별시 강남구 가로수길 77, 5층',
#   'hm_url': 'dndplatformreit.com/',
#   'ir_url': '',
#   'phn_no': '02-6201-9500',
#   'fax_no': '',
#   'induty_code': '681',
#   'est_dt': '20200310',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01394377',
#   'corp_name': '주식회사 이지스밸류플러스위탁관리부동산투자회사',
#   'corp_name_eng': 'IGIS Value Plus REIT Co., Ltd.',
#   'stock_name': '이지스밸류플러스리츠',
#   'stock_code': '334890',
#   'ceo_nm': '도병운',
#   'corp_cls': 'Y',
#   'jurir_no': '1101117173224',
#   'bizr_no': '5368801452',
#   'adres': '서울특별시 영등포구 여의공원로 115, 14층',
#   'hm_url': 'www.igisvaluereit.com',
#   'ir_url': 'www.igisvaluereit.com',
#   'phn_no': '02-6959-3100',
#   'fax_no': '',
#   'induty_code': '681',
#   'est_dt': '20190716',
#   'acc_mt': '08'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00118008',
#   'corp_name': '동원금속(주)',
#   'corp_name_eng': 'DONGWON METAL CO.,LTD',
#   'stock_name': '동원금속',
#   'stock_code': '018500',
#   'ceo_nm': '이은우, 박승룡',
#   'corp_cls': 'Y',
#   'jurir_no': '1701110021816',
#   'bizr_no': '5038106778',
#   'adres': '경상북도 경산시  진량읍 북리1길  69',
#   'hm_url': 'www.dwmic.com',
#   'ir_url': 'http://www.dwmic.com',
#   'phn_no': '053-859-2311',
#   'fax_no': '0538532319',
#   'induty_code': '303',
#   'est_dt': '19851214',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00132354',
#   'corp_name': '쿠쿠홀딩스(주)',
#   'corp_name_eng': 'Cuckoo Holdings Co.,Ltd',
#   'stock_name': '쿠쿠홀딩스',
#   'stock_code': '192400',
#   'ceo_nm': '구본학',
#   'corp_cls': 'Y',
#   'jurir_no': '1845110000634',
#   'bizr_no': '6218102895',
#   'adres': '경상남도 양산시 유산공단2길 14(교동)',
#   'hm_url': 'www.cuckoo.co.kr',
#   'ir_url': '',
#   'phn_no': '055-380-0734',
#   'fax_no': '0553890709',
#   'induty_code': '649',
#   'est_dt': '19781115',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00163716',
#   'corp_name': '(주)한창',
#   'corp_name_eng': 'HANCHANG CORPORATION',
#   'stock_name': '한창',
#   'stock_code': '005110',
#   'ceo_nm': '최 승 환',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110000602',
#   'bizr_no': '6078117053',
#   'adres': '부산광역시 연제구 중앙대로 1052 501호(연산동)',
#   'hm_url': 'www.hanchang.co.kr',
#   'ir_url': '',
#   'phn_no': '02-850-6545',
#   'fax_no': '02)852-8181',
#   'induty_code': '465',
#   'est_dt': '19670710',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01436558',
#   'corp_name': '주식회사 신한서부티엔디위탁관리부동산투자회사',
#   'corp_name_eng': 'Shinhan Seobu T&D REIT Co., Ltd.',
#   'stock_name': '신한서부티엔디리츠',
#   'stock_code': '404990',
#   'ceo_nm': '승만호',
#   'corp_cls': 'Y',
#   'jurir_no': '1101117343356',
#   'bizr_no': '1448801520',
#   'adres': '서울특별시 종로구 종로 33 (청진동, 그랑서울) 1동 18층',
#   'hm_url': 'shsbreit.com',
#   'ir_url': '',
#   'phn_no': '02-2158-7400',
#   'fax_no': '02-2158-7449',
#   'induty_code': '68112',
#   'est_dt': '20200102',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00178754',
#   'corp_name': '(주)동아지질',
#   'corp_name_eng': 'Dong-Ah Geological Engineering Company LTD.',
#   'stock_name': '동아지질',
#   'stock_code': '028100',
#   'ceo_nm': '박만규, 최정욱',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110019843',
#   'bizr_no': '6218112675',
#   'adres': '부산광역시 금정구  금샘로 347 동아지질',
#   'hm_url': 'www.dage.co.kr',
#   'ir_url': '',
#   'phn_no': '051-580-5550',
#   'fax_no': '051-580-5521',
#   'induty_code': '421',
#   'est_dt': '19731130',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00441243',
#   'corp_name': '(주)형지엘리트',
#   'corp_name_eng': 'HYUNGJI ELITE INC.',
#   'stock_name': '형지엘리트',
#   'stock_code': '093240',
#   'ceo_nm': '최병오',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112507551',
#   'bizr_no': '1058639463',
#   'adres': '인천광역시 연수구 하모니로177번길 49 업무동 10층(송도동, 형지글로벌 패션복합센터)',
#   'hm_url': 'www.hyungji-elite.com',
#   'ir_url': '',
#   'phn_no': '032-454-8404',
#   'fax_no': '02-3279-8080',
#   'induty_code': '14112',
#   'est_dt': '20020425',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00159254',
#   'corp_name': '(주)한국전자홀딩스',
#   'corp_name_eng': 'KEC HOLDINGS CO.,LTD',
#   'stock_name': '한국전자홀딩스',
#   'stock_code': '006200',
#   'ceo_nm': '박 명 덕',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110101470',
#   'bizr_no': '2298101123',
#   'adres': '서울특별시 서초구  마방로10길 5',
#   'hm_url': 'www.kecholdings.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3497-5535',
#   'fax_no': '02)589-5529',
#   'induty_code': '64992',
#   'est_dt': '19690909',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00125576',
#   'corp_name': '(주)체시스',
#   'corp_name_eng': 'CHASYS Co.,Ltd',
#   'stock_name': '체시스',
#   'stock_code': '033250',
#   'ceo_nm': '이명곤, 김성광(각자대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1748110004244',
#   'bizr_no': '5158102135',
#   'adres': '경상북도 경산시 진량읍 일연로 528',
#   'hm_url': 'www.chasys.com',
#   'ir_url': '',
#   'phn_no': '053-851-8511',
#   'fax_no': '(053)851-8519',
#   'induty_code': '303',
#   'est_dt': '19890803',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01276594',
#   'corp_name': '(주)신한알파위탁관리부동산투자회사',
#   'corp_name_eng': 'Shinhan Alpha REIT Co,. Ltd.',
#   'stock_name': '신한알파리츠',
#   'stock_code': '293940',
#   'ceo_nm': '이준구',
#   'corp_cls': 'Y',
#   'jurir_no': '1101116601135',
#   'bizr_no': '2938100902',
#   'adres': '서울특별시 종로구 종로 33 그랑서울, 18층',
#   'hm_url': 'www.shalphareit.com',
#   'ir_url': 'www.shalphareit.com',
#   'phn_no': '02-2158-7400',
#   'fax_no': '02-2158-7449',
#   'induty_code': '6811',
#   'est_dt': '20171218',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00168401',
#   'corp_name': '(주)금비',
#   'corp_name_eng': 'KUMBI CO.,LTD',
#   'stock_name': '금비',
#   'stock_code': '008870',
#   'ceo_nm': '고기영',
#   'corp_cls': 'Y',
#   'jurir_no': '1201110002022',
#   'bizr_no': '1268109409',
#   'adres': '경기도 이천시 부발읍 중부대로1707번길 13',
#   'hm_url': 'www.e-kumbi.co.kr',
#   'ir_url': '',
#   'phn_no': '031-632-5280',
#   'fax_no': '02-421-7520',
#   'induty_code': '23192',
#   'est_dt': '19730605',
#   'acc_mt': '09'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00648721',
#   'corp_name': 'SNT에너지(주)',
#   'corp_name_eng': 'SNTEnergy Co.,Ltd.',
#   'stock_name': 'SNT에너지',
#   'stock_code': '100840',
#   'ceo_nm': '김형섭',
#   'corp_cls': 'Y',
#   'jurir_no': '1942110090598',
#   'bizr_no': '6098181774',
#   'adres': '경상남도 창원시 성산구  완암로 12',
#   'hm_url': 'www.hisnt.com',
#   'ir_url': '',
#   'phn_no': '055-212-6500',
#   'fax_no': '02-212-6525',
#   'induty_code': '29176',
#   'est_dt': '20080205',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00135111',
#   'corp_name': '(주)수산중공업',
#   'corp_name_eng': 'SOOSAN HEAVY INDUSTRIES CO.,LTD',
#   'stock_name': '수산중공업',
#   'stock_code': '017550',
#   'ceo_nm': '정석현, 신수근(각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1348110002981',
#   'bizr_no': '1248131958',
#   'adres': '경기도 화성시  양감면 정문송산로 260',
#   'hm_url': 'www.soosan.co.kr',
#   'ir_url': '',
#   'phn_no': '031-352-7733',
#   'fax_no': '031)350-5295',
#   'induty_code': '29241',
#   'est_dt': '19840302',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00150633',
#   'corp_name': '(주)지누스',
#   'corp_name_eng': 'ZINUS INC.',
#   'stock_name': '지누스',
#   'stock_code': '013890',
#   'ceo_nm': '심재형',
#   'corp_cls': 'Y',
#   'jurir_no': '1347110002553',
#   'bizr_no': '1248128792',
#   'adres': '경기도 성남시 분당구 야탑로81번길 10,8층(야탑동, 아미고타워)',
#   'hm_url': 'www.zinus.co.kr',
#   'ir_url': 'www.zinus.co.kr',
#   'phn_no': '031-622-1700',
#   'fax_no': '0316221701',
#   'induty_code': '320',
#   'est_dt': '19790308',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00136341',
#   'corp_name': '신성통상(주)',
#   'corp_name_eng': 'SHINSUNG TONGSANG CO.,LTD',
#   'stock_name': '신성통상',
#   'stock_code': '005390',
#   'ceo_nm': '대표이사 염태순',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110003345',
#   'bizr_no': '1048101106',
#   'adres': '서울특별시 강동구 풍성로63길 84(둔촌동)',
#   'hm_url': 'www.ssts.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3709-9000',
#   'fax_no': '02-6488-0151',
#   'induty_code': '467',
#   'est_dt': '19680111',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00360142',
#   'corp_name': '(주)아이마켓코리아',
#   'corp_name_eng': 'iMarketKorea Inc.',
#   'stock_name': '아이마켓코리아',
#   'stock_code': '122900',
#   'ceo_nm': '남인봉',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112125262',
#   'bizr_no': '1048158502',
#   'adres': '서울특별시 강남구 삼성로 512 삼성동빌딩 16층',
#   'hm_url': 'www.imarketkorea.com',
#   'ir_url': '',
#   'phn_no': '02-3708-5678',
#   'fax_no': '02-3708-5797',
#   'induty_code': '46800',
#   'est_dt': '20001208',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00256955',
#   'corp_name': '(주)테이팩스',
#   'corp_name_eng': 'TAPEX INC',
#   'stock_name': '테이팩스',
#   'stock_code': '055490',
#   'ceo_nm': '김상구',
#   'corp_cls': 'Y',
#   'jurir_no': '1201110095499',
#   'bizr_no': '1398115931',
#   'adres': '경기도 수원시 영통구 대학4로 17 제8층 812호, 813호(이의동, 에이스광교타워 1차)',
#   'hm_url': 'tapex.co.kr',
#   'ir_url': '',
#   'phn_no': '031-8047-4100',
#   'fax_no': '031-8047-4292',
#   'induty_code': '2229',
#   'est_dt': '19940801',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00139454',
#   'corp_name': '애경산업(주)',
#   'corp_name_eng': 'Aekyung Industrial Co., Ltd.',
#   'stock_name': '애경산업',
#   'stock_code': '018250',
#   'ceo_nm': '채동석, 임재영',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110398275',
#   'bizr_no': '1138111573',
#   'adres': '서울특별시 마포구 양화로 188 -',
#   'hm_url': 'www.aekyung.co.kr',
#   'ir_url': '',
#   'phn_no': '02-768-2000',
#   'fax_no': '02-818-8000',
#   'induty_code': '20422',
#   'est_dt': '19850425',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01532603',
#   'corp_name': '주식회사 화승알앤에이',
#   'corp_name_eng': 'HWASEUNG R&A CO., LTD.',
#   'stock_name': '화승알앤에이',
#   'stock_code': '378850',
#   'ceo_nm': '김형진',
#   'corp_cls': 'Y',
#   'jurir_no': '2341110120538',
#   'bizr_no': '3058640935',
#   'adres': '경상남도 양산시 충렬로 61',
#   'hm_url': 'www.hsrna.com',
#   'ir_url': '',
#   'phn_no': '055-370-3331',
#   'fax_no': '055-387-8027',
#   'induty_code': '30399',
#   'est_dt': '20210303',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00534598',
#   'corp_name': '주식회사 한컴라이프케어',
#   'corp_name_eng': 'Hancom Lifecare Inc.',
#   'stock_name': '한컴라이프케어',
#   'stock_code': '372910',
#   'ceo_nm': '오병진',
#   'corp_cls': 'Y',
#   'jurir_no': '1345110021549',
#   'bizr_no': '1358121955',
#   'adres': '경기도 용인시 처인구 양지면 중부대로1960번길 53',
#   'hm_url': 'www.hancomlifecare.com',
#   'ir_url': 'hancomlifecare.irpage.co.kr/#/main',
#   'phn_no': '031-5183-9021',
#   'fax_no': '031-321-4088',
#   'induty_code': '27199',
#   'est_dt': '19711221',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00107224',
#   'corp_name': '(주)남선알미늄',
#   'corp_name_eng': 'NAMSUN ALUMINIUM CO.,LTD',
#   'stock_name': '남선알미늄',
#   'stock_code': '008350',
#   'ceo_nm': '박귀봉, 정순원(각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1701110005042',
#   'bizr_no': '5028100107',
#   'adres': '대구광역시 달성군  논공읍 논공중앙로 288',
#   'hm_url': 'www.namsun.co.kr',
#   'ir_url': '',
#   'phn_no': '053-610-5110',
#   'fax_no': '0536105169',
#   'induty_code': '24222',
#   'est_dt': '19730104',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01510489',
#   'corp_name': '프레스티지바이오파마',
#   'corp_name_eng': 'Prestige BioPharma Limited',
#   'stock_name': '프레스티지바이오파마',
#   'stock_code': '950210',
#   'ceo_nm': '박소연',
#   'corp_cls': 'Y',
#   'jurir_no': '',
#   'bizr_no': '49190',
#   'adres': '21 Biopolis Road, #04-24/28 Nucleos South Building, Singapore 138567 -',
#   'hm_url': 'www.prestigebiopharma.com',
#   'ir_url': '',
#   'phn_no': '070-4124-6152',
#   'fax_no': '0432331552',
#   'induty_code': '70113',
#   'est_dt': '20150713',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00428321',
#   'corp_name': '해태제과식품주식회사',
#   'corp_name_eng': 'Haitai Confectionery and Foods Co., Ltd.',
#   'stock_name': '해태제과식품',
#   'stock_code': '101530',
#   'ceo_nm': '신정훈, 이상진(각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1615110044225',
#   'bizr_no': '3128149680',
#   'adres': '충청남도 천안시 서북구 성거읍 천흥8길 67-26',
#   'hm_url': 'www.ht.co.kr',
#   'ir_url': '',
#   'phn_no': '02-709-7766',
#   'fax_no': '02-793-7969',
#   'induty_code': '107',
#   'est_dt': '20010711',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01415892',
#   'corp_name': '(주)제이알글로벌위탁관리부동산투자회사',
#   'corp_name_eng': 'JR GLOBAL REIT',
#   'stock_name': '제이알글로벌리츠',
#   'stock_code': '348950',
#   'ceo_nm': '오남수',
#   'corp_cls': 'Y',
#   'jurir_no': '1101117263728',
#   'bizr_no': '2078158077',
#   'adres': '서울특별시 중구 을지로 100',
#   'hm_url': 'jrglobalreit.com',
#   'ir_url': '',
#   'phn_no': '02-2008-7035',
#   'fax_no': '',
#   'induty_code': '681',
#   'est_dt': '20191024',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00121534',
#   'corp_name': '(주)MH에탄올',
#   'corp_name_eng': 'MHETHANOL CO.,LTD',
#   'stock_name': 'MH에탄올',
#   'stock_code': '023150',
#   'ceo_nm': '최동호',
#   'corp_cls': 'Y',
#   'jurir_no': '1901110003563',
#   'bizr_no': '6088103800',
#   'adres': '경상남도 창원시 마산회원구 내서읍 광려천남로 25',
#   'hm_url': 'www.mhethanol.com',
#   'ir_url': '',
#   'phn_no': '055-231-0701',
#   'fax_no': '055-231-1282',
#   'induty_code': '11121',
#   'est_dt': '19780704',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01436628',
#   'corp_name': '주식회사 이지스레지던스위탁관리부동산투자회사',
#   'corp_name_eng': 'IGIS RESIDENCE REIT Co., Ltd.',
#   'stock_name': '이지스레지던스리츠',
#   'stock_code': '350520',
#   'ceo_nm': '박영희',
#   'corp_cls': 'Y',
#   'jurir_no': '1101117375375',
#   'bizr_no': '3118601790',
#   'adres': '서울특별시 영등포구 여의공원로 115, 14층',
#   'hm_url': 'igisresidencereit.com/',
#   'ir_url': 'http://igisresidencereit.com/',
#   'phn_no': '02-6959-3100',
#   'fax_no': '02-780-7304',
#   'induty_code': '681',
#   'est_dt': '20200203',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00111458',
#   'corp_name': '대영포장(주)',
#   'corp_name_eng': 'DAEYOUNG PACKAGING CO.,LTD',
#   'stock_name': '대영포장',
#   'stock_code': '014160',
#   'ceo_nm': '강병은,손용수',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110254104',
#   'bizr_no': '1348101183',
#   'adres': '경기도 안산시 단원구 산단로 265 (원시동, 대영포장(주))',
#   'hm_url': 'www.dypc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-490-9300',
#   'fax_no': '02)3472-5811',
#   'induty_code': '1721',
#   'est_dt': '19790601',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00152862',
#   'corp_name': '(주)코오롱',
#   'corp_name_eng': 'KOLON CORPORATION',
#   'stock_name': '코오롱',
#   'stock_code': '002020',
#   'ceo_nm': '안병덕',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110030528',
#   'bizr_no': '2028144660',
#   'adres': '경기 과천시 별양동 1-23 코오롱타워',
#   'hm_url': 'www.kolon.com',
#   'ir_url': '',
#   'phn_no': '02-3677-3114',
#   'fax_no': '3677-3099',
#   'induty_code': '64992',
#   'est_dt': '19570412',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00218575',
#   'corp_name': '(주)황금에스티',
#   'corp_name_eng': 'Hwang Kum Steel & Technology Co., Ltd',
#   'stock_name': '황금에스티',
#   'stock_code': '032560',
#   'ceo_nm': '김종현',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110504195',
#   'bizr_no': '1078118697',
#   'adres': '경기도 안산시 단원구 엠티브이1로 25 (주)황금에스티',
#   'hm_url': 'www.hwangkum.com',
#   'ir_url': '',
#   'phn_no': '02-6121-4600',
#   'fax_no': '031-488-8433',
#   'induty_code': '24290',
#   'est_dt': '19860825',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00134316',
#   'corp_name': '(주)세원정공',
#   'corp_name_eng': 'SEWON PRECISION INDUSTRY CO.,LTD',
#   'stock_name': '세원정공',
#   'stock_code': '021820',
#   'ceo_nm': '장제상',
#   'corp_cls': 'Y',
#   'jurir_no': '1701110039207',
#   'bizr_no': '5038111081',
#   'adres': '대구광역시 달서구 달서대로 554',
#   'hm_url': 'www.se-won.co.kr',
#   'ir_url': '',
#   'phn_no': '053-582-5161',
#   'fax_no': '(053)583-3555',
#   'induty_code': '303',
#   'est_dt': '19890729',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00400857',
#   'corp_name': '(주)에이블씨엔씨',
#   'corp_name_eng': 'ABLE C&C',
#   'stock_name': '에이블씨엔씨',
#   'stock_code': '078520',
#   'ceo_nm': '김유진',
#   'corp_cls': 'Y',
#   'jurir_no': '1101111846174',
#   'bizr_no': '1198134685',
#   'adres': '서울특별시 중구 남대문로 78 7층(명동1가, 타임워크명동빌딩)',
#   'hm_url': 'www.able-cnc.com',
#   'ir_url': '',
#   'phn_no': '02-2199-0123',
#   'fax_no': '02-2199-0177',
#   'induty_code': '20423',
#   'est_dt': '20000107',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00113614',
#   'corp_name': '(주)대현',
#   'corp_name_eng': 'DAEHYUN CO.,LTD',
#   'stock_name': '대현',
#   'stock_code': '016090',
#   'ceo_nm': '신현균',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110319320',
#   'bizr_no': '2118119302',
#   'adres': '서울특별시 강남구 언주로 619 (논현동, 대현그린타워)',
#   'hm_url': 'www.daehyun.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3485-7000',
#   'fax_no': '02)3485-7188',
#   'induty_code': '14112',
#   'est_dt': '19820525',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00113058',
#   'corp_name': '한화생명보험(주)',
#   'corp_name_eng': 'HANWHA LIFE INSURANCE CO., LTD.',
#   'stock_name': '한화생명',
#   'stock_code': '088350',
#   'ceo_nm': '여승주',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110003204',
#   'bizr_no': '1168111757',
#   'adres': '서울특별시 영등포구 63로 50',
#   'hm_url': 'www.hanwhalife.com',
#   'ir_url': '',
#   'phn_no': '02-789-5114',
#   'fax_no': '02-789-8212',
#   'induty_code': '65110',
#   'est_dt': '19460909',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00103042',
#   'corp_name': '(주)케이씨티시',
#   'corp_name_eng': 'KCTC',
#   'stock_name': '케이씨티시',
#   'stock_code': '009070',
#   'ceo_nm': '류주환',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110149446',
#   'bizr_no': '2018110323',
#   'adres': '서울특별시 중구 남대문로 63 한진빌딩',
#   'hm_url': 'www.kctc.co.kr',
#   'ir_url': '',
#   'phn_no': '02-310-0700',
#   'fax_no': '(02) 752-4404',
#   'induty_code': '49301',
#   'est_dt': '19730720',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00106614',
#   'corp_name': '기신정기(주)',
#   'corp_name_eng': 'KISHIN CORPORATION',
#   'stock_name': '기신정기',
#   'stock_code': '092440',
#   'ceo_nm': '윤현도',
#   'corp_cls': 'Y',
#   'jurir_no': '1201110046476',
#   'bizr_no': '1398116717',
#   'adres': '인천광역시 남동구  은봉로 111 49동 1호(논현동, 남동공단)',
#   'hm_url': 'www.kishin.com',
#   'ir_url': '',
#   'phn_no': '032-820-1600',
#   'fax_no': '032-814-7188',
#   'induty_code': '29294',
#   'est_dt': '19881101',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00138190',
#   'corp_name': '(주)지에스글로벌',
#   'corp_name_eng': 'GS Global Corp.',
#   'stock_name': 'GS글로벌',
#   'stock_code': '001250',
#   'ceo_nm': '이영환',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110031479',
#   'bizr_no': '2028133028',
#   'adres': '서울특별시 강남구 논현로 508 GS강남타워',
#   'hm_url': 'www.gsgcorp.com',
#   'ir_url': 'www.gsgcorp.com',
#   'phn_no': '02-2005-5300',
#   'fax_no': '02-2005-5150',
#   'induty_code': '468',
#   'est_dt': '19540731',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00153621',
#   'corp_name': '참엔지니어링(주)',
#   'corp_name_eng': 'Charm Engineering Co.,Ltd.',
#   'stock_name': '참엔지니어링',
#   'stock_code': '009310',
#   'ceo_nm': '변인재',
#   'corp_cls': 'Y',
#   'jurir_no': '1746110001096',
#   'bizr_no': '5068100661',
#   'adres': '경기도 용인시 처인구  남사면 형제로 5',
#   'hm_url': 'www.charmeng.com',
#   'ir_url': '',
#   'phn_no': '031-330-8500',
#   'fax_no': '031-8018-6750',
#   'induty_code': '29271',
#   'est_dt': '19731004',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00120872',
#   'corp_name': '만호제강(주)',
#   'corp_name_eng': 'MANHO ROPE & WIRE LTD',
#   'stock_name': '만호제강',
#   'stock_code': '001080',
#   'ceo_nm': '김상환',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110054659',
#   'bizr_no': '6068108662',
#   'adres': '부산광역시 강서구  녹산화전로 71',
#   'hm_url': 'www.manhorope.com',
#   'ir_url': '',
#   'phn_no': '051-601-0351',
#   'fax_no': '051-442-1163',
#   'induty_code': '24123',
#   'est_dt': '19530904',
#   'acc_mt': '06'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01267684',
#   'corp_name': '쿠쿠홈시스 주식회사',
#   'corp_name_eng': 'CUCKOO HOMESYS CO.,LTD',
#   'stock_name': '쿠쿠홈시스',
#   'stock_code': '284740',
#   'ceo_nm': '구본학',
#   'corp_cls': 'Y',
#   'jurir_no': '1355110319406',
#   'bizr_no': '5908700993',
#   'adres': '경기도 시흥시 엠티브이북로 349(정왕동)',
#   'hm_url': 'www,cuckoo.co.kr',
#   'ir_url': '',
#   'phn_no': '055-380-0734',
#   'fax_no': '032-457-9188',
#   'induty_code': '762',
#   'est_dt': '20171204',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00126779',
#   'corp_name': '삼아알미늄(주)',
#   'corp_name_eng': 'SAMA ALUMINIUM CO.,LTD',
#   'stock_name': '삼아알미늄',
#   'stock_code': '006110',
#   'ceo_nm': '한남희,하상용',
#   'corp_cls': 'Y',
#   'jurir_no': '1341110002365',
#   'bizr_no': '1238101882',
#   'adres': '경기도 평택시 포승읍 평택항로 92 삼아알미늄 주식회사',
#   'hm_url': 'www.sama-al.com',
#   'ir_url': '',
#   'phn_no': '031-467-6800',
#   'fax_no': '025549990',
#   'induty_code': '24222',
#   'est_dt': '19690625',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00157104',
#   'corp_name': '대동전자(주)',
#   'corp_name_eng': 'DAIDONG ELECTRONICS.,LTD',
#   'stock_name': '대동전자',
#   'stock_code': '008110',
#   'ceo_nm': '김명성',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110134819',
#   'bizr_no': '1198104629',
#   'adres': '서울특별시 금천구  가산디지털1로 33',
#   'hm_url': 'www.daidong.com',
#   'ir_url': '',
#   'phn_no': '02-855-5121',
#   'fax_no': '864-4690',
#   'induty_code': '264',
#   'est_dt': '19721010',
#   'acc_mt': '03'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00104698',
#   'corp_name': '(주)LS네트웍스',
#   'corp_name_eng': 'LS Networks Corporation Limited',
#   'stock_name': 'LS네트웍스',
#   'stock_code': '000680',
#   'ceo_nm': '문성준',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110044717',
#   'bizr_no': '6228104805',
#   'adres': '경상남도 김해시 호계로 428 1층(부원동, 세화빌딩)',
#   'hm_url': 'www.lsnetworks.co.kr',
#   'ir_url': 'www.lsnetworks.co.kr',
#   'phn_no': '02-799-7114',
#   'fax_no': '02-6442-5423',
#   'induty_code': '46800',
#   'est_dt': '19491221',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00122348',
#   'corp_name': '(주)방림',
#   'corp_name_eng': 'PANGRIM CO.,LTD',
#   'stock_name': '방림',
#   'stock_code': '003610',
#   'ceo_nm': '서재희 대표집행임원',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110035108',
#   'bizr_no': '1078111490',
#   'adres': '서울특별시 마포구  월드컵북로 402 케이지아이티센터 18층',
# ...
#   'stock_name': '화인베스틸',
#   'stock_code': '133820',
#   'ceo_nm': '박정묵',
#   'corp_cls': 'Y',
#   'jurir_no': '1951110010951',
#   'bizr_no': '6088168647',
#   'adres': '경상남도 창녕군 창녕읍 창밀로 259-33',
#   'hm_url': 'www.finebesteel.com',
#   'ir_url': '',
#   'phn_no': '055-259-2000',
#   'fax_no': '0552592020',
#   'induty_code': '24121',
#   'est_dt': '20070918',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00828497',
#   'corp_name': '한미약품(주)',
#   'corp_name_eng': 'Hanmi Pharm. Co., Ltd.',
#   'stock_name': '한미약품',
#   'stock_code': '128940',
#   'ceo_nm': '박재현',
#   'corp_cls': 'Y',
#   'jurir_no': '1348110197550',
#   'bizr_no': '1248700613',
#   'adres': '경기도 화성시  팔탄면 무하로 214',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '031-356-3311',
#   'fax_no': '',
#   'induty_code': '21210',
#   'est_dt': '20100705',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00861076',
#   'corp_name': '(주)케이탑자기관리부동산투자회사',
#   'corp_name_eng': 'K-TOP REITS CO.,LTD.',
#   'stock_name': '케이탑리츠',
#   'stock_code': '145270',
#   'ceo_nm': '이명식, 조현만(각자대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101114465004',
#   'bizr_no': '1078743354',
#   'adres': '서울특별시 영등포구 국제금융로 70 미원빌딩 19층 1901호',
#   'hm_url': 'www.ktopreits.co.kr',
#   'ir_url': '',
#   'phn_no': '02-783-5858',
#   'fax_no': '02-783-1717',
#   'induty_code': '68112',
#   'est_dt': '20101104',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00260408',
#   'corp_name': '(주)팜스코',
#   'corp_name_eng': 'FARMSCO',
#   'stock_name': '팜스코',
#   'stock_code': '036580',
#   'ceo_nm': '정학상',
#   'corp_cls': 'Y',
#   'jurir_no': '1311110042950',
#   'bizr_no': '1298130202',
#   'adres': '경기도 안성시  미양면 제2공단4길 33',
#   'hm_url': 'www.farmsco.com',
#   'ir_url': '',
#   'phn_no': '02-6200-9901',
#   'fax_no': '02-6200-9908',
#   'induty_code': '106',
#   'est_dt': '19991001',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00422895',
#   'corp_name': '(주)세이브존아이앤씨',
#   'corp_name_eng': 'SAVEZONE I&C Corp.',
#   'stock_name': '세이브존I&C',
#   'stock_code': '067830',
#   'ceo_nm': '김현동, 이상준',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112520644',
#   'bizr_no': '2108141081',
#   'adres': '서울특별시 노원구  한글비석로 57 (하계동)',
#   'hm_url': 'www.savezone.co.kr',
#   'ir_url': '',
#   'phn_no': '032-320-9032',
#   'fax_no': '031-930-9020',
#   'induty_code': '47111',
#   'est_dt': '20020508',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01412822',
#   'corp_name': '솔루스첨단소재 주식회사',
#   'corp_name_eng': 'Solus Advanced Materials Co. Ltd.',
#   'stock_name': '솔루스첨단소재',
#   'stock_code': '336370',
#   'ceo_nm': '진대제, 서광벽(각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '2149110058927',
#   'bizr_no': '6688101406',
#   'adres': '전라북도 익산시 서동로 627 -',
#   'hm_url': 'www.solusadvancedmaterials.com',
#   'ir_url': '',
#   'phn_no': '031-8039-6301',
#   'fax_no': '',
#   'induty_code': '26299',
#   'est_dt': '20191001',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00127802',
#   'corp_name': '삼익THK(주)',
#   'corp_name_eng': 'SAMICK THK CO.,LTD',
#   'stock_name': '삼익THK',
#   'stock_code': '004380',
#   'ceo_nm': '진영환, 진주완',
#   'corp_cls': 'Y',
#   'jurir_no': '1701110000935',
#   'bizr_no': '5038110869',
#   'adres': '대구광역시 달서구  성서동로 163',
#   'hm_url': 'www.samickthk.co.kr',
#   'ir_url': '',
#   'phn_no': '053-665-7000',
#   'fax_no': '053)586-3132',
#   'induty_code': '29141',
#   'est_dt': '19651005',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00776820',
#   'corp_name': '(주)영원무역',
#   'corp_name_eng': 'Youngone Corporation',
#   'stock_name': '영원무역',
#   'stock_code': '111770',
#   'ceo_nm': '성기학',
#   'corp_cls': 'Y',
#   'jurir_no': '1101114129585',
#   'bizr_no': '1048621617',
#   'adres': '서울특별시 중구  만리재로 159',
#   'hm_url': '-',
#   'ir_url': '',
#   'phn_no': '390-6114',
#   'fax_no': '02-390-6604',
#   'induty_code': '46800',
#   'est_dt': '20090702',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00163761',
#   'corp_name': '(주)한창제지',
#   'corp_name_eng': 'HANCHANG PAPER CO.,LTD',
#   'stock_name': '한창제지',
#   'stock_code': '009460',
#   'ceo_nm': '김길수',
#   'corp_cls': 'Y',
#   'jurir_no': '1845110000105',
#   'bizr_no': '6218109073',
#   'adres': '경상남도 양산시  웅상대로 1564 (주)한창제지',
#   'hm_url': 'www.hcpaper.co.kr',
#   'ir_url': '',
#   'phn_no': '055-370-2000',
#   'fax_no': '055-370-2198',
#   'induty_code': '17123',
#   'est_dt': '19731206',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00107613',
#   'corp_name': '(주)이수페타시스',
#   'corp_name_eng': 'ISUPETASYS CO.,LTD',
#   'stock_name': '이수페타시스',
#   'stock_code': '007660',
#   'ceo_nm': '최창복',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110186638',
#   'bizr_no': '5148116131',
#   'adres': '대구광역시 달성군  논공읍 논공로53길 36 이수페타시스',
#   'hm_url': 'www.petasys.com',
#   'ir_url': '',
#   'phn_no': '053-610-0300',
#   'fax_no': '053-6100-401',
#   'induty_code': '2622',
#   'est_dt': '19720204',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00113225',
#   'corp_name': '대한제강(주)',
#   'corp_name_eng': 'DAEHAN STEEL CO.,LTD',
#   'stock_name': '대한제강',
#   'stock_code': '084010',
#   'ceo_nm': '이경백',
#   'corp_cls': 'Y',
#   'jurir_no': '1801110003268',
#   'bizr_no': '6038113259',
#   'adres': '부산광역시 사하구 하신번영로 69',
#   'hm_url': 'www.idaehan.com',
#   'ir_url': '',
#   'phn_no': '02-1670-3300',
#   'fax_no': '051-998-8893',
#   'induty_code': '2411',
#   'est_dt': '19540610',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00118451',
#   'corp_name': '동일제강(주)',
#   'corp_name_eng': 'DONG IL STEEL MFG CO., LTD',
#   'stock_name': '동일제강',
#   'stock_code': '002690',
#   'ceo_nm': '민세홍, 양영석, 김우진 (각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110032005',
#   'bizr_no': '1138107346',
#   'adres': '경기도 안성시 미양면 안성맞춤대로 474-40',
#   'hm_url': 'www.dongil-steel.com',
#   'ir_url': '',
#   'phn_no': '031-677-1234',
#   'fax_no': '',
#   'induty_code': '24122',
#   'est_dt': '19590713',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00119195',
#   'corp_name': '동화약품(주)',
#   'corp_name_eng': 'DONGWHA PHARM.CO.,LTD',
#   'stock_name': '동화약품',
#   'stock_code': '000020',
#   'ceo_nm': '유준하',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110043870',
#   'bizr_no': '1108100102',
#   'adres': '서울특별시 중구 남대문로9길 24 패스트파이브타워 6~8층(다동)',
#   'hm_url': 'www.dong-wha.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2021-9300',
#   'fax_no': '753-2347',
#   'induty_code': '21210',
#   'est_dt': '18970925',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00350312',
#   'corp_name': '에이치디씨랩스(주)',
#   'corp_name_eng': 'HDC LABS Co., Ltd.',
#   'stock_name': 'HDC랩스',
#   'stock_code': '039570',
#   'ceo_nm': '김성은',
#   'corp_cls': 'Y',
#   'jurir_no': '1101111775365',
#   'bizr_no': '1208193646',
#   'adres': '서울특별시 서초구 효령로 346 서초 HDC랩스 타워',
#   'hm_url': 'www.hdc-labs.com/',
#   'ir_url': 'www.hdc-icontrols.com',
#   'phn_no': '02-1899-1909',
#   'fax_no': '031-785-1799',
#   'induty_code': '423',
#   'est_dt': '19990917',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00195229',
#   'corp_name': '(주)휠라홀딩스',
#   'corp_name_eng': 'Fila Holdings',
#   'stock_name': '휠라홀딩스',
#   'stock_code': '081660',
#   'ceo_nm': '윤근창',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110792667',
#   'bizr_no': '1148144271',
#   'adres': '서울특별시 강동구 천호대로 1077 이스트센트럴타워15층,16층,17층,18층',
#   'hm_url': 'www.filaholdings.com/kr/main/index.asp',
#   'ir_url': '',
#   'phn_no': '02-1533-6400',
#   'fax_no': '02-3470-9548',
#   'induty_code': '464',
#   'est_dt': '19910723',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00104722',
#   'corp_name': '국제약품(주)',
#   'corp_name_eng': 'Kukje Pharma Co., Ltd.',
#   'stock_name': '국제약품',
#   'stock_code': '002720',
#   'ceo_nm': '남영우,남태훈,안재만',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110032154',
#   'bizr_no': '2078100309',
#   'adres': '경기도 성남시 분당구  야탑로 96-8',
#   'hm_url': 'www.kukjepharm.co.kr',
#   'ir_url': '',
#   'phn_no': '031-781-9081',
#   'fax_no': '031-781-6040',
#   'induty_code': '21210',
#   'est_dt': '19590727',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00122825',
#   'corp_name': '(주)인스코비',
#   'corp_name_eng': 'Inscobee, Inc',
#   'stock_name': '인스코비',
#   'stock_code': '006490',
#   'ceo_nm': '유인수, 구자갑 (각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110018592',
#   'bizr_no': '1198103654',
#   'adres': '서울특별시 금천구 디지털로 130 남성프라자 613호',
#   'hm_url': 'www.inscobee.com',
#   'ir_url': '',
#   'phn_no': '070-7510-3448',
#   'fax_no': '02-544-9641',
#   'induty_code': '612',
#   'est_dt': '19700727',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00134565',
#   'corp_name': '(주)이스타코',
#   'corp_name_eng': 'e-STARCO. CO.,LTD',
#   'stock_name': '이스타코',
#   'stock_code': '015020',
#   'ceo_nm': '김승제,김동현(각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1243110006042',
#   'bizr_no': '1338122225',
#   'adres': '서울특별시 양천구 오목로 325 대학빌딩 5층',
#   'hm_url': 'www.e-starco.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2643-7922',
#   'fax_no': '02-2643-7922',
#   'induty_code': '68121',
#   'est_dt': '19800930',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00136776',
#   'corp_name': '제이준코스메틱(주)',
#   'corp_name_eng': 'Jayjun Cosmetic Co., Ltd.',
#   'stock_name': '제이준코스메틱',
#   'stock_code': '025620',
#   'ceo_nm': '양재원, 고병철 (각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1341110001672',
#   'bizr_no': '1388103204',
#   'adres': '인천광역시 남동구 남동대로 405 (남촌동 614)',
#   'hm_url': 'www.jayjun.kr',
#   'ir_url': '',
#   'phn_no': '02-2193-9500',
#   'fax_no': '070-8650-1234',
#   'induty_code': '204',
#   'est_dt': '19720630',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00138242',
#   'corp_name': '케이지모빌리티(주)',
#   'corp_name_eng': 'KG Mobility Corp.',
#   'stock_name': 'KG모빌리티',
#   'stock_code': '003620',
#   'ceo_nm': '곽재선, 정용원',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110035132',
#   'bizr_no': '1258114248',
#   'adres': '경기도 평택시  동삭로 455-12',
#   'hm_url': 'www.kg-mobility.com',
#   'ir_url': '',
#   'phn_no': '031-610-1114',
#   'fax_no': '02-3469-6992',
#   'induty_code': '301',
#   'est_dt': '19621206',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00138792',
#   'corp_name': '아시아나항공(주)',
#   'corp_name_eng': 'Asiana Airlines Inc.',
#   'stock_name': '아시아나항공',
#   'stock_code': '020560',
#   'ceo_nm': '원유석',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110562804',
#   'bizr_no': '1048117480',
#   'adres': '서울특별시 강서구  오정로 443-83',
#   'hm_url': 'www.flyasiana.com',
#   'ir_url': '',
#   'phn_no': '02-2669-3114',
#   'fax_no': '02-2127-8260',
#   'induty_code': '511',
#   'est_dt': '19880217',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00141477',
#   'corp_name': '(주)영흥',
#   'corp_name_eng': 'YOUNGWIRE CO., LTD.',
#   'stock_name': '영흥',
#   'stock_code': '012160',
#   'ceo_nm': '강근욱, 강희준 (각자대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1942110000191',
#   'bizr_no': '6098102065',
#   'adres': '충청남도 보령시 주교면 관창공단길 50 -',
#   'hm_url': 'www.youngwire.com',
#   'ir_url': '',
#   'phn_no': '02-2077-8500',
#   'fax_no': '02-2077-8512',
#   'induty_code': '24123',
#   'est_dt': '19770420',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00153339',
#   'corp_name': '태경산업(주)',
#   'corp_name_eng': 'TAEKYUNG INDUSTRIAL CO.,LTD',
#   'stock_name': '태경산업',
#   'stock_code': '015890',
#   'ceo_nm': '김해련, 김민정, 박충기 (각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1348110002080',
#   'bizr_no': '1248130662',
#   'adres': '서울특별시 강서구 공항대로 467 4층(등촌동)',
#   'hm_url': 'www.taekyung.co.kr',
#   'ir_url': '',
#   'phn_no': '031-206-0071',
#   'fax_no': '02-3661-7057',
#   'induty_code': '20129',
#   'est_dt': '19820215',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00169048',
#   'corp_name': '에이치엘비글로벌(주)',
#   'corp_name_eng': 'HLB GLOBAL Co., Ltd.',
#   'stock_name': 'HLB글로벌',
#   'stock_code': '003580',
#   'ceo_nm': '김광재',
#   'corp_cls': 'Y',
#   'jurir_no': '1449110000072',
#   'bizr_no': '2258100025',
#   'adres': '강원도 정선군  사북읍 동탄길 32',
#   'hm_url': 'www.hlbglobal.co.kr',
#   'ir_url': '',
#   'phn_no': '02-6925-4450',
#   'fax_no': '02-6925-4449',
#   'induty_code': '072',
#   'est_dt': '19620924',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00136624',
#   'corp_name': '(주)신영와코루',
#   'corp_name_eng': 'SHINYOUNG WACOAL INC',
#   'stock_name': '신영와코루',
#   'stock_code': '005800',
#   'ceo_nm': '이의평, 이성원',
#   'corp_cls': 'Y',
#   'jurir_no': '1101110094964',
#   'bizr_no': '1198101559',
#   'adres': '서울특별시 금천구  가산디지털1로 104 (주)신영와코루',
#   'hm_url': 'www.shinyoungwacoal.co.kr/',
#   'ir_url': '',
#   'phn_no': '02-818-5114',
#   'fax_no': '02-852-5011',
#   'induty_code': '14120',
#   'est_dt': '19681021',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00124540',
#   'corp_name': '(주)대우건설',
#   'corp_name_eng': 'DAEWOO ENGINEERING & CONSTRUCTION CO.,LTD',
#   'stock_name': '대우건설',
#   'stock_code': '047040',
#   'ceo_nm': '백정완',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112137895',
#   'bizr_no': '1048158180',
#   'adres': '서울특별시 중구 을지로 170 (을지로4가)',
#   'hm_url': 'daewooenc.com',
#   'ir_url': '',
#   'phn_no': '02-2288-3114',
#   'fax_no': '02-2288-3113',
#   'induty_code': '41112',
#   'est_dt': '20001227',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00193328',
#   'corp_name': '(주)수산인더스트리',
#   'corp_name_eng': 'SOOSAN INDUSTRIES CO., LTD.',
#   'stock_name': '수산인더스트리',
#   'stock_code': '126720',
#   'ceo_nm': '한봉섭,김병현(각자대표)',
#   'corp_cls': 'Y',
#   'jurir_no': '1615110001613',
#   'bizr_no': '3128102856',
#   'adres': '충청남도 천안시 서북구 천일고3길 47',
#   'hm_url': 'www.soosanind.co.kr',
#   'ir_url': '',
#   'phn_no': '02-514-1541',
#   'fax_no': '02-2017-8181',
#   'induty_code': '422',
#   'est_dt': '19830416',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00248974',
#   'corp_name': '하나제약(주)',
#   'corp_name_eng': 'Hana Pharm. Co., Ltd.',
#   'stock_name': '하나제약',
#   'stock_code': '293480',
#   'ceo_nm': '최태홍',
#   'corp_cls': 'Y',
#   'jurir_no': '1311110002409',
#   'bizr_no': '1248137632',
#   'adres': '경기도 화성시 향남읍 제약단지로 13-39',
#   'hm_url': 'www.hanaph.co.kr',
#   'ir_url': 'http://www.hanaph.co.kr/investment/irNotice.do',
#   'phn_no': '02-577-7667',
#   'fax_no': '02-566-6003',
#   'induty_code': '212',
#   'est_dt': '19780119',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00349097',
#   'corp_name': '(주)케이티스카이라이프',
#   'corp_name_eng': 'KT Skylife Co.,Ltd.',
#   'stock_name': '케이티스카이라이프',
#   'stock_code': '053210',
#   'ceo_nm': '양춘식',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112149436',
#   'bizr_no': '1178131120',
#   'adres': '서울특별시 마포구 매봉산로 758층, 9층',
#   'hm_url': 'www.ktskylife.co.kr',
#   'ir_url': '',
#   'phn_no': '02-2003-3000',
#   'fax_no': '2003-3299',
#   'induty_code': '60229',
#   'est_dt': '20010112',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00585219',
#   'corp_name': '세원이앤씨(주)',
#   'corp_name_eng': 'SEWON E&C CO.,LTD.',
#   'stock_name': '세원이앤씨',
#   'stock_code': '091090',
#   'ceo_nm': '이종인, 김동화 (각자대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101113489609',
#   'bizr_no': '1078680236',
#   'adres': '경상남도 창원시 성산구 공단로 211 -',
#   'hm_url': 'www.sewonenc.com',
#   'ir_url': '',
#   'phn_no': '055-269-7000',
#   'fax_no': '055-261-3853',
#   'induty_code': '251',
#   'est_dt': '20060703',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00671376',
#   'corp_name': '(주)티웨이항공',
#   'corp_name_eng': "T'way Air Co., Ltd.",
#   'stock_name': '티웨이항공',
#   'stock_code': '091810',
#   'ceo_nm': '정홍근',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112782046',
#   'bizr_no': '1018194800',
#   'adres': '대구광역시 중구 동덕로 167 케이티대구타워 신관 10층 (동인동2가)',
#   'hm_url': 'www.twayair.com',
#   'ir_url': '',
#   'phn_no': '02-6250-4984',
#   'fax_no': '02-6250-5999',
#   'induty_code': '511',
#   'est_dt': '20030701',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00344287',
#   'corp_name': '에이치디현대인프라코어(주)',
#   'corp_name_eng': 'HD Hyundai Infracore Co., Ltd.',
#   'stock_name': 'HD현대인프라코어',
#   'stock_code': '042670',
#   'ceo_nm': '조영철, 오승현',
#   'corp_cls': 'Y',
#   'jurir_no': '1201110234469',
#   'bizr_no': '1218140254',
#   'adres': '인천광역시 동구  인중로 489(화수동)',
#   'hm_url': 'www.hd-infracore.com',
#   'ir_url': '',
#   'phn_no': '032-211-1114',
#   'fax_no': '02-3398-8339',
#   'induty_code': '29241',
#   'est_dt': '20001023',
#   'acc_mt': '12'}]
