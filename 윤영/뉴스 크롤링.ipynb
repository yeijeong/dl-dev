# %%
# !pip install requests

# %%
#크롤링시 필요한 라이브러리 불러오기
from bs4 import BeautifulSoup
import requests
import re
import datetime
from tqdm import tqdm
import sys

# %%
# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
  #입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num+1
    else:
        return num+9*(num-1)

# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)

def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(start_page)
        print("생성url: ", url)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&start=" + str(page)
            urls.append(url)
        print("생성url: ", urls)
        return urls    

# html에서 원하는 속성 추출하는 함수 만들기 (기사, 추출하려는 속성값)
def news_attrs_crawler(articles,attrs):
    attrs_content=[]
    for i in articles:
        attrs_content.append(i.attrs[attrs])
    return attrs_content

# ConnectionError방지
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

#html생성해서 기사크롤링하는 함수 만들기(url): 링크를 반환
def articles_crawler(url):
    #html 불러오기
    original_html = requests.get(i,headers=headers)
    html = BeautifulSoup(original_html.text, "html.parser")

    url_naver = html.select("div.group_news > ul.list_news > li div.news_area > div.news_info > div.info_group > a.info")
    url = news_attrs_crawler(url_naver,'href')
    return url

# %%
#####뉴스크롤링 시작#####

#검색어 입력
search = input("검색할 키워드를 입력해주세요:")
#검색 시작할 페이지 입력
page = int(input("\n크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 시작 페이지: ",page,"페이지")   
#검색 종료할 페이지 입력
page2 = int(input("\n크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...
print("\n크롤링할 종료 페이지: ",page2,"페이지")   


# naver url 생성
url = makeUrl(search,page,page2)

#뉴스 크롤러 실행
news_titles = []
news_url =[]
news_contents =[]
news_dates = []
for i in url:
    url = articles_crawler(url)
    news_url.append(url)


#제목, 링크, 내용 1차원 리스트로 꺼내는 함수 생성
def makeList(newlist, content):
    for i in content:
        for j in i:
            newlist.append(j)
    return newlist

    
#제목, 링크, 내용 담을 리스트 생성
news_url_1 = []

#1차원 리스트로 만들기(내용 제외)
makeList(news_url_1,news_url)

#NAVER 뉴스만 남기기
final_urls = []
for i in tqdm(range(len(news_url_1))):
    if "news.naver.com" in news_url_1[i]:
        final_urls.append(news_url_1[i])
    else:
        pass
# Out:
# 크롤링할 시작 페이지:  1 페이지
#
# 크롤링할 종료 페이지:  3 페이지
# 생성url:  ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query=윤&start=1', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=윤&start=11', 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=윤&start=21']
# 100%|██████████| 60/60 [00:00<?, ?it/s]

# %%
# 뉴스 내용 크롤링

for i in tqdm(final_urls):
    #각 기사 html get하기
    news = requests.get(i,headers=headers)
    news_html = BeautifulSoup(news.text,"html.parser")
    # 뉴스 제목 가져오기
    title = news_html.select_one("#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
    if title == None:
        title = news_html.select_one("#content > div.end_ct > div > h2")
    
    # 뉴스 본문 가져오기
    content = news_html.select("div#dic_area")
    if content == []:
        content = news_html.select("#articeBody")
        
    # 기사 텍스트만 가져오기
    # list합치기
    content = ''.join(str(content))

    # html태그제거 및 텍스트 다듬기
    pattern1 = '<[^>]*>'
    title = re.sub(pattern=pattern1, repl='', string=str(title))
    content = re.sub(pattern=pattern1, repl='', string=content)
    pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
    content = content.replace(pattern2, '')

    news_titles.append(title)
    news_contents.append(content)

    try:
        html_date = news_html.select_one("div#ct> div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > div > span")
        news_date = html_date.attrs['data-date-time']
    except AttributeError:
        news_date = news_html.select_one("#content > div.end_ct > div > div.article_info > span > em")
        news_date = re.sub(pattern=pattern1,repl='',string=str(news_date))
    # 날짜 가져오기
    news_dates.append(news_date)

print("검색된 기사 갯수: 총 ",(page2+1-page)*10,'개')
print("\n[뉴스 제목]")
print(news_titles)
print("\n[뉴스 링크]")
print(final_urls)
print("\n[뉴스 내용]")
print(news_contents)
print('news_title: ',len(news_titles))
print('news_url: ',len(final_urls))
print('news_contents: ',len(news_contents))
print('news_dates: ',len(news_dates))
# Out:
# 100%|██████████| 30/30 [00:07<00:00,  4.25it/s]
# 검색된 기사 갯수: 총  30 개
#
# [뉴스 제목]
# ['윤 대통령 "엑스포 유치에 프랑스 동포들도 힘 모아달라"', "윤 대통령, 오늘 마크롱과 회담…'부산엑스포 유치' 연설", '윤 대통령, 20일 엑스포 PT 키워드…미래·약속·보답·연대', '윤 대통령, 프랑스 동포들 만나 “부산엑스포 유치에 힘 모아달라”', '"서울광장 놔두고 도로 집회만 허용... 교통불편 유도하는 윤 정부"', "윤 대통령, 오늘 '엑스포 유치' 영어 PT…마크롱과 정상회담도", '김기현 "\'조국 수호\' 문재인·\'비리\' 이재명…윤 정부, 정상화에 앞장"', "'부산엑스포' 유치 총력전…윤 대통령 오늘 밤 직접 연설", '대통령실 "킬러문항 배제 3개월전 예고…윤 대통령, 기존 원칙 재확인"', '윤 대통령, 프랑스 파리 도착…부산엑스포 유치전 본격 돌입', "'부산엑스포' 유치 총력전…윤 대통령 오늘 밤 직접 연설", '윤 대통령, 파리 도착‥부산엑스포 유치전 돌입', "윤 대통령, '미래·약속·보답·연대' 화두로 부산엑스포 PT", '대통령실 "킬러문항 배제 3개월전 예고…윤 대통령, 기존 원칙 재확인"', '부산 vs 리야드 접전… 윤, ‘K-소프트파워’로 179개국 사로잡는다', '유승민 “윤 대통령, 만5세 입학·‘바이든-날리면’ 때처럼 또 남 탓”', '국민의힘 “윤 대통령, ‘조국 사태’ 수사한 대입 전문가”', '한 총리 "윤 대통령, 부산엑스포 PT…우호적 분위기 확산될 것"', "윤 대통령, 오늘 프랑스行…'엑스포 유치' PT 직접 나선다", '윤 대통령 국정수행 긍정평가 38.7% 부정평가 58%ㅣ리얼미터', '"대법원의 노란봉투법 \'독촉\' 판결... 윤 대통령
희 여사가 19일 경기 성남시 서울공항에서 프랑스·베트남 순방을 위해 공군 1호기에 탑승하며 인사를 하고 있다. (대통령실 제공) 2023.6.19/뉴스1 ⓒ News1 안은나 기자(파리=뉴스1) 나연준 기자 = 윤석열 대통령은 20일(이하 현지시간) 오전 2030 부산세계박람회(엑스포) 유치를 위해 경쟁 프레젠테이션(PT) 최종 예행연습에 돌입한다.이도운 대통령실 대변인은 19일 밤 프랑스 파리의 한 호텔에 마련된 프레스센터에서 브리핑을 통해 "대통령께서 오전 10시부터 숙소 1층 홀에서 프레젠테이션 리허설을 예정하고 있다"고 말했다.이 대변인은 "리허설에는 싸이, IT 전문가, 건축·조경 전문가 등 연사 4분이 다 참석한다"며 "리허설을 현장에서 수행원들이 다같이 보고 피드백을 주면, 그것을 반영해서 2차 리허설을 할 예정"이라고 밝혔다.이어 이 대변인은 "행사장과 똑같을 수는 없지만 비슷한 환경을 만들어서 리허설을 한다"고 덧붙였다.이번 PT에서 우리나라는 우리의 강점인 디지털 영상기술을 최대한 활용할 계획이다. 3D 기술, 뮤직비디오 패턴도 이용해 30분 내내 눈길을 뗄 수 없도록 프로그램을 구성하겠다는 것이다.윤 대통령은 20일 오후 파리에서 국제박람회기구(BIE) 총회에서 4차 경쟁 PT에 참여한다. 한국은 사우디아라비아에 이어 2번째로 PT에 나서고, 각 국가는 30분씩 PT를 진행한다. 윤 대통령은 영어로 PT에 나설 계획이다.윤 대통령의 경쟁 PT의 키워드는 \'미래\', \'약속\', \'보답\', \'연대\' 등이다. 윤 대통령은 각 국가가 부산엑스포에 참여하게 될 경우 가져갈 혜택 등에 대해 더 구체적으로 설명할 예정이다.대통령실 핵심 관계자는 "지금까지의 엑스포는 올림픽이나 월드컵처럼 국가 간 경쟁하는 스타일로 진행됐다. 이번에는 경쟁이 아니라 각국이 연대해서 새로운 흐름을 만들어 보자는 것"이라고 설명했다.나아가 이 관계자는 "부산엑스포에서는 경쟁할 상품이 없는 나라도 참여해서 그 나라가 가진 문화, 전통을 전시할 공간을 우리가 넓혀줄 것"이라며 "우리가 국제사회로부터 받은 여러 도움을 국제사회에 보답하는 차원"이라고 덧붙였다.윤 대통령 외에도 PT에 나설 가수 싸이와 각계 전문가 등에 대한 관심도 높다.이 대변인은 "싸이가 강남스타일이 나오고 파리 에펠탑 앞에서 플래시목을 즉석에서 하는 행사에 2만 명이 모이기도 했다"며 "그때 플래시몹처럼 부산엑스포를 통해 전 세계를 모아보자는 취지가 있다"고 설명했다.걸그룹 에스파의 카리나는 영상으로 PT에 참여한다. 이 대변인은 "에스파는 그 자체로도 인기가 많지만, 에스파는 전 세계에서 처음으로 아바타와 함께 공연하는 걸그룹"이라며 "우리의 디지털 기술, 미래세대 등을 강조한다고 보면 된다"고 했다.대통령실은 함께 PT에 나설 2명의 민간 전문가는 아직 공개하지 않았다. 이 대변인은 "이분들은 공개가 되면 PT를 앞두고 영향을 받을 수 있다. 공개하면 다들 어디서 많이 들어봤는데 하며 이해할 것"이라며 "최강의 멤버로 PT를 준비하고 있다"고 말했다.\n\t\t]', '[\n\n\n\n\n윤석열 대통령이 "대한민국은 \'2030 부산세계박람회\' 유치를 위해 온 국민이 하나가 돼 뛰고 있다"면서, 프랑스 동포들의 지원을 요청했습니다. 윤 대통령은 현지시각 19일 프랑스 파리에서 한인 동포들과 만찬 간담회를 갖고 "오는 11월, 에펠탑이라는 대표적인 박람회 유산을 자랑하는 이곳 파리에서 2030 세계박람회 개최지 선정을 위한 최종 투표가 진행된다"며 이 같이 당부했습니다. 윤 대통령은 "부산세계박람회 유치는, 인류가 당면한 복합위기에 대응하는 \'솔루션 플랫폼\'으로서 세계 시민과 미래세대를 위한 기회의 장이 될 것"이라며 "박람회 유치를 위해 프랑스 동포들께서도 당연히 힘을 모아주실 것으로 기대하고 있다"고 말했습니다. 이어 "박람회 유치는 BIE(국제박람회기구) 회원국 179개국에서 한 국가마다 비밀투표를 하는 것이기 때문에 유치 과정이 올림픽이나 월드컵보다 더 어렵다고 알려져 있다"면서 "우리가 유치하게 된다면 대한민국의 글로벌 외교에 새로운 지평을 열게 될 것"이라고 덧붙였습니다. 윤 대통령은 현지시각 20일 파리에서 열리는 BIE 총회 무대에 올라, 2030 부산세계박람회 개최를 호소하는 영어 연설을 할 예정입니다. 윤 대통령은 또 "한국과 프랑스는 137년의 수교 역사 동안 연대와 협력의 기억 위에 함께 성장하고 발전해왔다"면서 "오늘날 한국과 프랑스는 자유, 인권, 법치의 보편적 가치를 공유하는 파트너"라고 밝혔습니다. 그러면서 "앞으로도 양국은 활발한 문화 인적 교류를 바탕으로, 첨단 기술 분야와 글로벌 어젠다에서 협력을 강화해 나갈 것"이라고 했습니다. 윤 대통령은 현지시각 20일 에마뉘엘 마크롱 프랑스 대통령과 오찬을 겸한 정상회담을 갖습니다. 윤 대통령은 지난달 출범한 재외동포청도 언급하면서 "모국과 여러분을 더욱 긴밀히 연결하고 글로벌 비즈니스 허브가 되어 재외동포들의 든든한 울타리가 될 것"이라며 "동포 여러분께서도 모국의 발전을 위해 소중한 역할을 해주시기를 당부드 ...
# news_title:  30
# news_url:  30
# news_contents:  30
# news_dates:  30

# %%
###데이터 프레임으로 만들기###
import pandas as pd

#데이터 프레임 만들기
news_df = pd.DataFrame({'date':news_dates,'title':news_titles,'link':final_urls,'content':news_contents})
news_df

#중복 행 지우기
news_df = news_df.drop_duplicates(keep='first',ignore_index=True)
print("중복 제거 후 행 개수: ",len(news_df))

#데이터 프레임 저장
now = datetime.datetime.now() 
news_df.to_csv('{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H%M%S')),encoding='utf-8',index=False)
# Out:
# 중복 제거 후 행 개수:  28
