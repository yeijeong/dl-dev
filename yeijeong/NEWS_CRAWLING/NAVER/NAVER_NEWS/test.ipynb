# %%
import pandas as pd

# %%
hrt1 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\현대로템_20230628_014703.csv') # 1~4000
hrt1.tail()
# Out:
#                     date                         title  \
# 567  2022-07-07 15:10:02     현대로템 "K2 전차 수출 폴란드와 협의 중"
# 568  2022-04-22 11:28:02    현대로템, 강원도 액화수소 충전소 실증사업 수주
# 569  2022-04-28 18:22:01  현대제철 당진공장서 사고…현대로템 소속 노동자 중상
# 570  2022-04-22 08:57:01   현대로템, 강원도 액화수소 충전소 실증 사업 수주
# 571  2022-04-22 09:05:01   현대로템, 강원도 액화수소 충전소 실증 사업 수주
#
#                                                   link  \
# 567  https://n.news.naver.com/mnews/article/018/000...
# 568  https://n.news.naver.com/mnews/article/016/000...
# 569  https://n.news.naver.com/mnews/article/119/000...
# 570  https://n.news.naver.com/mnews/article/119/000...
# 571  https://n.news.naver.com/mnews/article/366/000...
#
#                                                content
# 567  [\n\t\t\t[이데일리 하지나 기자] 현대로템(064350)은 K2 전차를 폴란...
# 568  [\n국내기술로 만든 시스템 첫 적용\n\n\n\n현대로템이 강원테크노파크 액화수소...
# 569  [\n\n\n\n\n현대제철 당진제철소. ⓒ현대제철[데일리안 = 김민희 기자] 현대...
# 570  [\n자체 액화수소 충전소 구축 시스템 실증 나서…국내 기업 처음\n\n\n\n현대...
# ...

# %%
hrt2 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\현대로템_20230628_030453.csv') # 4001~10000
hrt2.tail()
# Out:
#                   date                                          title  \
# 0  2022-04-22 09:05:01                    현대로템, 강원도 액화수소 충전소 실증 사업 수주
# 1  2022-07-07 15:10:02                      현대로템 "K2 전차 수출 폴란드와 협의 중"
# 2  2022-04-28 18:22:01                   현대제철 당진공장서 사고…현대로템 소속 노동자 중상
# 3  2022-04-27 11:16:06  현대로템, 1분기 영업익 235억원 전년比 8.7%↓…순익은 151% 늘어(종합)
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/366/000...
# 1  https://n.news.naver.com/mnews/article/018/000...
# 2  https://n.news.naver.com/mnews/article/119/000...
# 3  https://n.news.naver.com/mnews/article/421/000...
#
#                                              content
# 0  [\n현대로템(064350)이 액화수소 충전소 실증 사업을 수주했다.22일 현대로템...
# 1  [\n\t\t\t[이데일리 하지나 기자] 현대로템(064350)은 K2 전차를 폴란...
# 2  [\n\n\n\n\n현대제철 당진제철소. ⓒ현대제철[데일리안 = 김민희 기자] 현대...
# 3  [\n매출액 6774억 3.7%↑…신규수주 3480억원"안정적 수주잔고·생산성 향상...

# %%
hrt3 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\현대로템_20230702_002446.csv') # 1~1000
hrt3.tail()
# Out:
#                     date                                   title  \
# 556  2022-07-25 08:39:00          [부고]채종칠(현대로템 커뮤니케이션실장 상무)씨 빙부상
# 557  2022-05-03 06:00:03  [단독] 현대로템 856억 벌금 1위…열차 납품 제때 못하게 된 이유
# 558  2022-05-18 08:06:28               [클릭 e종목] 현대로템, 목표주가 하향 조정
# 559  2022-07-25 08:26:57          [부고]채종칠씨(현대로템 커뮤니케이션실장 상무) 빙부상
# 560  2022-07-25 09:26:04                 채종칠씨(현대로템 커뮤니케이션실장) 빙부상
#
#                                                   link  \
# 556  https://n.news.naver.com/mnews/article/003/001...
# 557  https://n.news.naver.com/mnews/article/025/000...
# 558  https://n.news.naver.com/mnews/article/277/000...
# 559  https://n.news.naver.com/mnews/article/421/000...
# 560  https://n.news.naver.com/mnews/article/014/000...
#
#                                                content
# 556  [\n\t\t\t[서울=뉴시스]  ▲조인현씨 별세, 채종칠(현대로템 커뮤니케이션실장...
# 557  [\n  \n\n\n\n현대로템이 제작한 준고속열차인 EMU-250. 현재 'KTX...
# 558  [\n\n\n\n\n19일 경기도 성남시 서울공항에서 열린 '서울 국제 항공우주 및...
# ...

# %%
hrt4 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\현대로템_20230702_004658.csv') # 1000-2000
hrt4.tail()
# Out:
#                   date                                   title  \
# 1  2022-06-14 18:24:07                    현대로템, 유로사토리서 K2전차 홍보
# 2  2022-05-03 06:00:03  [단독] 현대로템 856억 벌금 1위…열차 납품 제때 못하게 된 이유
# 3  2023-06-30 18:06:03                    개미 상반기 성적 보니…0.8% 수익
# 4  2022-05-18 08:06:28               [클릭 e종목] 현대로템, 목표주가 하향 조정
# 5  2022-07-25 08:26:57          [부고]채종칠씨(현대로템 커뮤니케이션실장 상무) 빙부상
#
#                                                 link  \
# 1  https://n.news.naver.com/mnews/article/014/000...
# 2  https://n.news.naver.com/mnews/article/025/000...
# 3  https://n.news.naver.com/mnews/article/015/000...
# 4  https://n.news.naver.com/mnews/article/277/000...
# 5  https://n.news.naver.com/mnews/article/421/000...
#
#                                              content
# 1  [\n\t\t\t  현대로템은 13~17일(현지시간) 프랑스 파리에서 열리는 유로사...
# 2  [\n  \n\n\n\n현대로템이 제작한 준고속열차인 EMU-250. 현재 'KTX...
# 3  [\n개인 순매수 톱10 종목 분석에코프로서 53.7% 수익네이버·카카오 10%대 ...
# ...

# %%
hrt5 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\현대로템_20230702_010324.csv') # 2000-3000
hrt5.tail()
# Out:
#                   date                                   title  \
# 1  2022-06-14 18:24:07                    현대로템, 유로사토리서 K2전차 홍보
# 2  2022-05-03 06:00:03  [단독] 현대로템 856억 벌금 1위…열차 납품 제때 못하게 된 이유
# 3  2022-05-18 08:06:28               [클릭 e종목] 현대로템, 목표주가 하향 조정
# 4  2023-06-30 18:06:03                    개미 상반기 성적 보니…0.8% 수익
# 5  2022-07-25 08:26:57          [부고]채종칠씨(현대로템 커뮤니케이션실장 상무) 빙부상
#
#                                                 link  \
# 1  https://n.news.naver.com/mnews/article/014/000...
# 2  https://n.news.naver.com/mnews/article/025/000...
# 3  https://n.news.naver.com/mnews/article/277/000...
# 4  https://n.news.naver.com/mnews/article/015/000...
# 5  https://n.news.naver.com/mnews/article/421/000...
#
#                                              content
# 1  [\n\t\t\t  현대로템은 13~17일(현지시간) 프랑스 파리에서 열리는 유로사...
# 2  [\n  \n\n\n\n현대로템이 제작한 준고속열차인 EMU-250. 현재 'KTX...
# 3  [\n\n\n\n\n19일 경기도 성남시 서울공항에서 열린 '서울 국제 항공우주 및...
# ...

# %%
hrt6 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\현대로템_20230702_012701.csv') # 3000-4000
hrt6.tail()
# Out:
#                   date                                   title  \
# 0  2022-07-25 09:26:04                 채종칠씨(현대로템 커뮤니케이션실장) 빙부상
# 1  2022-06-14 18:24:07                    현대로템, 유로사토리서 K2전차 홍보
# 2  2022-05-03 06:00:03  [단독] 현대로템 856억 벌금 1위…열차 납품 제때 못하게 된 이유
# 3  2022-05-18 08:06:28               [클릭 e종목] 현대로템, 목표주가 하향 조정
# 4  2022-07-25 08:26:57          [부고]채종칠씨(현대로템 커뮤니케이션실장 상무) 빙부상
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/014/000...
# 1  https://n.news.naver.com/mnews/article/014/000...
# 2  https://n.news.naver.com/mnews/article/025/000...
# 3  https://n.news.naver.com/mnews/article/277/000...
# 4  https://n.news.naver.com/mnews/article/421/000...
#
#                                              content
# 0  [\n\t\t\t  [파이낸셜뉴스] ▲ 조인현씨 별세, 채종칠씨(현대로템 커뮤니케이...
# 1  [\n\t\t\t  현대로템은 13~17일(현지시간) 프랑스 파리에서 열리는 유로사...
# 2  [\n  \n\n\n\n현대로템이 제작한 준고속열차인 EMU-250. 현재 'KTX...
# ...

# %%
has = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스_20230628_120947.csv') 
has.tail()
# Out:
#                     date                                    title  \
# 727  2021-08-11 08:28:13    대신증권 “한화에어로스페이스, 전 부문 실적 호조로 목표주가 상향”
# 728  2023-05-12 15:23:02            (주)한화, 사상 최대 실적…1분기 영업익 1조4천억
# 729  2021-08-07 12:53:03     한화에어로스페이스, 역대 최대 분기 실적 달성…"전 부문 레벨업"
# 730  2021-08-05 15:37:59  한화에어로스페이스, 2분기 1천326억원 흑자…작년보다 89％↑(종합)
# 731  2021-09-10 09:54:13         한화에어로스페이스, 지역 독거노인 500가구에 식재료 전달
#
#                                                   link  \
# 727  https://n.news.naver.com/mnews/article/366/000...
# 728  https://n.news.naver.com/mnews/article/009/000...
# 729  https://n.news.naver.com/mnews/article/016/000...
# 730  https://n.news.naver.com/mnews/article/001/001...
# 731  https://n.news.naver.com/mnews/article/421/000...
#
#                                                content
# 727  [\n\t\t\t        대신증권이 11일 한화에어로스페이스(012450)의 ...
# 728  [\n\t\t\t㈜한화가 사상 최대 1분기 실적을 기록했다.12일 (주)한화는 올해...
# 729  [\n대신증권, '매수' 의견…"하반기 실적도 좋을 것"\n\n\n\n[제공=대신증...
# ...

# %%
has2 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\한화에어로스페이스_20230703_140233.csv')
has2.tail()
# Out:
#                     date                                     title  \
# 756  2023-05-23 10:07:57           육해공 보폭 넓히는 김동관…닻 올린 한화오션 과제는 산적
# 757  2022-02-17 14:08:15             한화에어로스페이스, 28일 국내 기관투자자 IR 개최
# 758  2021-10-15 13:32:15                 한화시스템·한화에어로스페이스 등 정기인사 단행
# 759  2021-09-23 07:43:53  [클릭 e종목] "상반기 화려했던 한화에어로스페이스, 하반기는 숨고르기"
# 760  2023-05-19 21:42:31                 전라남도-한화에어로, 우주발사체 클러스터 구축
#
#                                                   link  \
# 756  https://n.news.naver.com/mnews/article/001/001...
# 757  https://n.news.naver.com/mnews/article/003/001...
# 758  https://n.news.naver.com/mnews/article/119/000...
# 759  https://n.news.naver.com/mnews/article/277/000...
# 760  https://n.news.naver.com/mnews/article/660/000...
#
#                                                content
# 756  [\n'한국판 록히드마틴' 숙원 현실화…경영 정상화·노조관계 정립(서울=연합뉴스) ...
# 757  [\n\t\t\t[서울=뉴시스] 이정필 기자 = 한화에어로스페이스는 오는 28일 국...
# 758  [\n\n\n\n\n한화시스템, 한화에어로스페이스 로고.ⓒ각사[데일리안 = 이건엄 ...
# ...

# %%
has3 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\한화에어로스페이스_20230703_141648_page1000_2000.csv')
has3.tail()
# Out:
#                   date                                     title  \
# 0  2021-10-15 13:32:15                 한화시스템·한화에어로스페이스 등 정기인사 단행
# 1  2021-09-23 07:43:53  [클릭 e종목] "상반기 화려했던 한화에어로스페이스, 하반기는 숨고르기"
# 2  2023-05-19 21:42:31                 전라남도-한화에어로, 우주발사체 클러스터 구축
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/119/000...
# 1  https://n.news.naver.com/mnews/article/277/000...
# 2  https://n.news.naver.com/mnews/article/660/000...
#
#                                              content
# 0  [\n\n\n\n\n한화시스템, 한화에어로스페이스 로고.ⓒ각사[데일리안 = 이건엄 ...
# 1  [\n민수 부문 비용 증가 영향…하반기 다소 숨고르기 전망우주 및 위성 사업 성장 ...
# 2  [\n전라남도와 고흥군, 한화에어로스페이스가 고흥을 우주발사체 산업의 중심지로 육성...

# %%
has4 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\한화에어로스페이스_20230703_142820_page2000_3000.csv')
has4.tail()
# Out:
#                   date                                     title  \
# 0  2021-10-15 13:32:15                 한화시스템·한화에어로스페이스 등 정기인사 단행
# 1  2021-09-23 07:43:53  [클릭 e종목] "상반기 화려했던 한화에어로스페이스, 하반기는 숨고르기"
# 2  2023-05-19 21:42:31                 전라남도-한화에어로, 우주발사체 클러스터 구축
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/119/000...
# 1  https://n.news.naver.com/mnews/article/277/000...
# 2  https://n.news.naver.com/mnews/article/660/000...
#
#                                              content
# 0  [\n\n\n\n\n한화시스템, 한화에어로스페이스 로고.ⓒ각사[데일리안 = 이건엄 ...
# 1  [\n민수 부문 비용 증가 영향…하반기 다소 숨고르기 전망우주 및 위성 사업 성장 ...
# 2  [\n전라남도와 고흥군, 한화에어로스페이스가 고흥을 우주발사체 산업의 중심지로 육성...

# %%
has5 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\한화에어로스페이스_20230703_143642_page3000_4000.csv')
has5.tail()
# Out:
#                   date                          title  \
# 0  2021-10-15 13:32:15      한화시스템·한화에어로스페이스 등 정기인사 단행
# 1  2022-02-17 14:17:43        한화에어로스페이스, 오는 28일 IR 개최
# 2  2022-02-17 14:08:15  한화에어로스페이스, 28일 국내 기관투자자 IR 개최
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/119/000...
# 1  https://n.news.naver.com/mnews/article/277/000...
# 2  https://n.news.naver.com/mnews/article/003/001...
#
#                                              content
# 0  [\n\n\n\n\n한화시스템, 한화에어로스페이스 로고.ⓒ각사[데일리안 = 이건엄 ...
# 1  [\n\t\t\t 한화에어로스페이스는 오는 28일 국내 기관 투자자 대상 기업설명회...
# 2  [\n\t\t\t[서울=뉴시스] 이정필 기자 = 한화에어로스페이스는 오는 28일 국...

# %%
has6 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\한화에어로스페이스_20230703_151211_page2000_2500.csv')
has6.tail()
# Out:
#                   date                                title  \
# 0  2023-07-03 10:02:03  "폴란드 방산 석·박사 50명 양성"..현대로템, 산학협력 지원
# 1  2022-02-17 14:17:43              한화에어로스페이스, 오는 28일 IR 개최
# 2  2022-02-17 14:08:15        한화에어로스페이스, 28일 국내 기관투자자 IR 개최
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/014/000...
# 1  https://n.news.naver.com/mnews/article/277/000...
# 2  https://n.news.naver.com/mnews/article/003/001...
#
#                                              content
# 0  [\n\n\n\n\n현대로템 이용배 사장, 방위사업청 엄동환 청장, KAIST 이광...
# 1  [\n\t\t\t 한화에어로스페이스는 오는 28일 국내 기관 투자자 대상 기업설명회...
# 2  [\n\t\t\t[서울=뉴시스] 이정필 기자 = 한화에어로스페이스는 오는 28일 국...

# %%
has7 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\한화에어로스페이스\\한화에어로스페이스_20230703_151901_page2000_2100.csv')
has7.tail()
# Out:
#                   date                                title  \
# 0  2021-10-01 09:32:04       [특징주]한화에어로스페이스, 누리호 발사 기대감에 강세
# 1  2022-02-17 14:08:15        한화에어로스페이스, 28일 국내 기관투자자 IR 개최
# 2  2023-07-03 10:02:03  "폴란드 방산 석·박사 50명 양성"..현대로템, 산학협력 지원
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/016/000...
# 1  https://n.news.naver.com/mnews/article/003/001...
# 2  https://n.news.naver.com/mnews/article/014/000...
#
#                                              content
# 0  [\n\n\n\n\n[헤럴드경제=이현정 기자]한화에어로스페이스가 22일 이틀째 강세...
# 1  [\n\t\t\t[서울=뉴시스] 이정필 기자 = 한화에어로스페이스는 오는 28일 국...
# 2  [\n\n\n\n\n현대로템 이용배 사장, 방위사업청 엄동환 청장, KAIST 이광...

# %%
has8 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\한화에어로스페이스_20230703_152120_page1000_1100.csv')
has8.tail()
# Out:
#                   date                           title  \
# 0  2021-10-01 09:32:04  [특징주]한화에어로스페이스, 누리호 발사 기대감에 강세
# 1  2022-02-17 14:08:15   한화에어로스페이스, 28일 국내 기관투자자 IR 개최
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/016/000...
# 1  https://n.news.naver.com/mnews/article/003/001...
#
#                                              content
# 0  [\n\n\n\n\n[헤럴드경제=이현정 기자]한화에어로스페이스가 22일 이틀째 강세...
# 1  [\n\t\t\t[서울=뉴시스] 이정필 기자 = 한화에어로스페이스는 오는 28일 국...

# %%
has9 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\한화에어로스페이스_20230703_152602_page1_100.csv')
has9.tail()
# Out:
#                     date                                 title  \
# 271  2023-05-12 12:18:31   MSCI 지수에 한화에어로스페이스·KT 신규 편입…에코프로 불발
# 272  2023-04-25 09:17:04  한화에어로스페이스, 항(抗)재밍 기술 보유 이스라엘 스타트업 투자
# 273  2023-04-25 10:36:02     한화에어로스페이스, 이스라엘 '항재밍' 스타트업에 지분 투자
# 274  2023-06-07 18:01:01  언론 앞에 처음 등장한 한화 김동관의 다짐 "이윤만 좇지 않겠다"
# 275  2023-06-07 19:08:57  부산에 ‘K해양방산’ 총집결…한화오션 vs 현대중 신경전 ‘치열’
#
#                                                   link  \
# 271  https://n.news.naver.com/mnews/article/025/000...
# 272  https://n.news.naver.com/mnews/article/031/000...
# 273  https://n.news.naver.com/mnews/article/018/000...
# 274  https://n.news.naver.com/mnews/article/469/000...
# 275  https://n.news.naver.com/mnews/article/025/000...
#
#                                                content
# 271  [\n\t\t\t  모건스탠리캐피털인터내셔널(MSCI) 한국 지수 구성 종목에 한화...
# 272  [\n美허니웰벤처스 등과 GPS 교란방어 장치 생산 인피니돔에 900만 달러 투자한...
# 273  [\n美허니웰벤처스 등과 GPS 교란방어 장치 업체인피니돔에 총 900만 달러(약 ...
# ...

# %%
hrt7 = pd.read_csv('D:\\big16\\final project\\DATA\\NEWS_DATA\\한화에어로스페이스\\현대로템_20230703_152832_page1_100.csv')
hrt7.tail()
# Out:
#                     date                             title  \
# 169  2023-03-30 14:36:01    현대로템, 육군 전방부대에 모듈형 간부숙소 4개동 기증
# 170  2023-04-28 15:27:57   현대로템, 1.1조 규모 SR 고속철도차량 도입사업 수주
# 171  2023-04-28 17:38:15  [유가증권시장 공시] HMM / 현대로템 / HJ중공업 등
# 172  2023-03-31 09:17:04  현대로템, 대만 스마트 시티 박람회 참가…철도 솔루션 선봬
# 173  2023-04-28 09:59:10              현대로템, 오늘 1분기 경영실적 발표
#
#                                                   link  \
# 169  https://n.news.naver.com/mnews/article/018/000...
# 170  https://n.news.naver.com/mnews/article/003/001...
# 171  https://n.news.naver.com/mnews/article/009/000...
# 172  https://n.news.naver.com/mnews/article/277/000...
# 173  https://n.news.naver.com/mnews/article/003/001...
#
#                                                content
# 169  [\n육군 22사단에 간부용 이동식 간이주택 기증육군, 모듈형 숙소 효과성 검증 후...
# 170  [\n\t\t\t[서울=뉴시스] 박은비 기자 = 현대로템은 1조859억9999만97...
# 171  [\n\t\t\t◇HMM=6353억원 규모 장기화물 운송계약 용역 제공.◇현대로템=...
# ...
