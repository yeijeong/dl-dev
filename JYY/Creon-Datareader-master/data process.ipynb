# %%
import pandas as pd

# %%
#6월 28일것에 29일것 추가
#전처리 후 28일것 제거
#머신러닝에 2년치 대입

# %%
total = pd.read_csv('../../../data/A012450분봉데이터.csv')
total1 = pd.read_csv('../../../data/A012450분봉데이터하루.csv')

for index in [total, total1]:
    index.sort_values(['date','time'], inplace=True) # 내림차순 정렬
    # index.rename(columns={'filename':'name'}, inplace=True)
    index.reset_index(inplace=True)
    index.drop('index', axis=1, inplace=True)
total, total1
# Out:
# (        Unnamed: 0      date  time    open    high     low   close  volume  \
#  0           187689  20210630   901   47450   47500   47350   47400    3572
#  1           187688  20210630   902   47350   47400   47200   47200    1382
#  2           187687  20210630   903   47200   47200   47150   47200    1170
#  3           187686  20210630   904   47200   47200   47150   47150     941
#  4           187685  20210630   905   47200   47250   47150   47200    1224
#  ...            ...       ...   ...     ...     ...     ...     ...     ...
#  187685           4  20230628  1517  128000  128300  127900  128200    6046
#  187686           3  20230628  1518  128200  128300  127700  128000    1057
#  187687           2  20230628  1519  128000  128000  127800  127800    2326
#  187688           1  20230628  1520  127800  127900  127600  127700    2079
#  187689           0  20230628  1530  127700  127700  127700  127700   12394
#
#          Accumulated sales volume  Accumulated number of contract
#  0                           1705                            1866
#  1                           2745                            2208
#  2                           3642                            2481
#  3                           4542                            2522
#  4                           4817                            3471
#  ...                          ...                             ...
#  187685                    265805                          213450
#  187686                    266452                          213860
#  187687                    268013                          214625
#  187688                    269339                          215378
#  187689                    269339                          227387
#
#  [187690 rows x 10 columns],
#       Unnamed: 0      date  time    open    high     low   close  volume  \
#  0           380  20230629   901  127100  128200  126700  126700    5714
#  1           379  20230629   902  126700  127400  126100  127200    8421
#  2           378  20230629   903  127200  127600  127000  127100    4328
#  3           377  20230629   904  127100  127200  126400  126500    6644
#  4           376  20230629   905  126500  126700  126200  126200    5442
#  ..          ...       ...   ...     ...     ...     ...     ...     ...
#  376           4  20230629  1517  125300  125300  125200  125300    1209
#  377           3  20230629  1518  125300  125400  125200  125400    1789
#  378           2  20230629  1519  125300  125400  125300  125400    2731
#  379           1  20230629  1520  125400  125500  125300  125300    2449
#  380           0  20230629  1530  125200  125200  125200  125200   45553
#
#       Accumulated sales volume  Accumulated number of contract
#  0                        1592                            3138
#  1                        6303                            6848
#  2                        7857                            9622
#  3                       12058                           12065
#  4                       15263                           14302
#  ..                        ...                             ...
#  376                    311109                          327719
#  377                    311233                          329384
#  378                    311538                          331810
#  379                    312742                          333055
#  380                    312742                          377115
#
#  [381 rows x 10 columns])

# %%
total = pd.concat([total, total1])
total = total.drop(columns=total.columns[0])
total.reset_index(inplace=True)
total.drop('index', axis=1, inplace=True)
total
# Out:
#             date  time    open    high     low   close  volume  \
# 0       20210630   901   47450   47500   47350   47400    3572
# 1       20210630   902   47350   47400   47200   47200    1382
# 2       20210630   903   47200   47200   47150   47200    1170
# 3       20210630   904   47200   47200   47150   47150     941
# 4       20210630   905   47200   47250   47150   47200    1224
# ...          ...   ...     ...     ...     ...     ...     ...
# 188066  20230629  1517  125300  125300  125200  125300    1209
# 188067  20230629  1518  125300  125400  125200  125400    1789
# 188068  20230629  1519  125300  125400  125300  125400    2731
# 188069  20230629  1520  125400  125500  125300  125300    2449
# 188070  20230629  1530  125200  125200  125200  125200   45553
#
#         Accumulated sales volume  Accumulated number of contract
# 0                           1705                            1866
# 1                           2745                            2208
# 2                           3642                            2481
# 3                           4542                            2522
# 4                           4817                            3471
# ...                          ...                             ...
# 188066                    311109                          327719
# 188067                    311233                          329384
# 188068                    311538                          331810
# 188069                    312742                          333055
# 188070                    312742                          377115
#
# [188071 rows x 9 columns]

# %%
# kospi200=pd.read_csv('../../../data/kospidata/total.csv')
# kospi200.drop(kospi200[kospi200['time'].isin([1521,1522,1523,1524,1525,1526,1527,1528,1529])].index, inplace=True)
# kospi200.sort_values(['date','time'], inplace=True) # 내림차순 정렬
# kospi200.reset_index(inplace=True)
# kospi200.drop('index', axis=1, inplace=True)
# kospi200.to_csv('../../../data/kospidata/arratotal.csv')

# %%
kospi200 = pd.read_csv('../../../data/kospi200.csv')

# 첫 번째 데이터프레임과 두 번째 데이터프레임을 'A'와 'C' 컬럼을 기준으로 합치기
total = pd.merge(total, kospi200, left_on='date', right_on='time')
total
# Out:
# Empty DataFrame
# Columns: [date_x, time_x, open, high, low, close_x, volume, Accumulated sales volume, Accumulated number of contract, Unnamed: 0, date_y, time_y, close_y]
# Index: []

# %%
asdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 asdf
#
# NameError: name 'asdf' is not defined

# %%
import ta
import talib
import numpy as np
import pandas as pd
import scipy
from tqdm.notebook import tqdm
H, L, C, V = total['high'], total['low'], total['close'], total['volume']

total['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

total['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

total['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
total['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

total['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
total['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

total['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
total['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
total['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
total['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
total['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
total['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
total['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
total['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
total['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
total['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
total['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
total['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
total['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
total['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
total['MACD'] = ta.trend.macd(close=C, fillna=True)
total['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
total['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
total['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
total['TRIX'] = ta.trend.trix(close=C, fillna=True)
total['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
total['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
total['DPO'] = ta.trend.dpo(close=C, fillna=True)
total['KST'] = ta.trend.kst(close=C, fillna=True)
total['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
total['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
total['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
total['RSI'] = ta.momentum.rsi(close=C, fillna=True)
total['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
total['TSI'] = ta.momentum.tsi(close=C, fillna=True)
total['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
total['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
total['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
total['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
total['KAMA'] = ta.momentum.kama(close=C, fillna=True)
total['ROC'] = ta.momentum.roc(close=C, fillna=True)
total['PPO'] = ta.momentum.ppo(close=C, fillna=True)
total['PVO'] = ta.momentum.pvo(volume=V, fillna=True)

#등락률 계산
total["close yesterday"] = total["close"].shift(1)
total["change"] = ((total["close"] - total["close yesterday"]) / total["close yesterday"])*100
total["ratio high close"] = ((total["high"] - total["close yesterday"]) / total["close yesterday"])*100
total["ratio low close"] = ((total["low"] - total["close yesterday"]) / total["close yesterday"])*100
total["ratio open close"] = (total["open"] - total["close yesterday"]) / total["close yesterday"]*100
total.drop("close yesterday", axis=1).to_clipboard(index=False)

#이동평균선
total['MA5'] = talib.SMA(total['close'], 5)
total['MA10'] = talib.SMA(total['close'], 10)
total['MA20'] = talib.SMA(total['close'], 20)
total['MA60'] = talib.SMA(total['close'], 60)
total['MA120'] = talib.SMA(total['close'], 120)

#지수평균선
total['EMA5'] = talib.EMA(total['close'], 5)
total['EMA10'] = talib.EMA(total['close'], 12)
total['EMA20'] = talib.EMA(total['close'], 20)
total['EMA60'] = talib.EMA(total['close'], 30)
total['EMA120'] = talib.EMA(total['close'], 90)

total['ratio close MA5'] = total["close"] / total["MA5"]
total['ratio close MA10'] = total["close"] / total["MA10"]
total['ratio close MA20'] = total["close"] / total["MA20"]
total['ratio close MA60'] = total["close"] / total["MA60"]
total['ratio close MA120'] = total["close"] / total["MA120"]

#이동거래평균선
total['MA5 VOLUME'] = talib.SMA(total['volume'], 5)
total['MA10 VOLUME'] = talib.SMA(total['volume'], 10)
total['MA20 VOLUME'] = talib.SMA(total['volume'], 20)
total['MA60 VOLUME'] = talib.SMA(total['volume'], 60)
total['MA120 VOLUME'] = talib.SMA(total['volume'], 120)

#mdd 구하는 것
window = 394 #하루 분봉데이터 개수
#종가에서 하루 단위 최고치 peak를 구함
peak = total['close'].rolling(window, min_periods=1).max()
# 3.최고치 대비 현재 종가가 얼마나 하락했는지 구함
drawdown = total['close']/peak - 1.0
# 4. drawdown에서 1년기간 단위로 최저치 max_dd를 구한다. 
total['mdd'] = drawdown.rolling(window, min_periods=1).min()
#mdd가 낮을수록 위험성이 적은 것이다
# Out:
# c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\ta\trend.py:780: RuntimeWarning: invalid value encountered in scalar divide
#   dip[idx] = 100 * (self._dip[idx] / value)
# c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\ta\trend.py:785: RuntimeWarning: invalid value encountered in scalar divide
#   din[idx] = 100 * (self._din[idx] / value)
# c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\series.py:917: RuntimeWarning: invalid value encountered in cast
#   arr = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 83
#      81 total["ratio low close"] = ((total["low"] - total["close yesterday"]) / total["close yesterday"])*100
#      82 total["ratio open close"] = (total["open"] - total["close yesterday"]) / total["close yesterday"]*100
# ---> 83 total.drop("close yesterday", axis=1).to_clipboard(index=False)
#      85 #이동평균선
#      86 total['MA5'] = talib.SMA(total['close'], 5)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\generic.py:3034, in NDFrame.to_clipboard(self, excel, sep, **kwargs)
#    2967 r"""
#    2968 Copy object to the system clipboard.
#    2969
#    (...)
#    3030    pyperclip.copy(html)
#    3031 """
#    3032 from pandas.io import clipboards
# -> 3034 clipboards.to_clipboard(self, excel=excel, sep=sep, **kwargs)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\io\clipboards.py:156, in to_clipboard(obj, excel, sep, **kwargs)
#     153 buf = StringIO()
#     155 # clipboard_set (pyperclip) expects unicode
# --> 156 obj.to_csv(buf, sep=sep, encoding="utf-8", **kwargs)
#     157 text = buf.getvalue()
#     159 clipboard_set(text)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\io\formats\csvs.py:259, in CSVFormatter.save(self)
#     240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#    (...)
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
# --> 259     self._save()
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\io\formats\csvs.py:264, in CSVFormatter._save(self)
#     262 if self._need_to_save_header:
#     263     self._save_header()
# --> 264 self._save_body()
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\io\formats\csvs.py:302, in CSVFormatter._save_body(self)
#     300 if start_i >= end_i:
#     301     break
# --> 302 self._save_chunk(start_i, end_i)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\io\formats\csvs.py:309, in CSVFormatter._save_chunk(self, start_i, end_i)
#     306 slicer = slice(start_i, end_i)
#     307 df = self.obj.iloc[slicer]
# --> 309 res = df._mgr.to_native_types(**self._number_format)
#     310 data = [res.iget_values(i) for i in range(len(res.items))]
#     312 ix = self.data_index[slicer]._format_native_types(**self._number_format)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\internals\managers.py:512, in BaseBlockManager.to_native_types(self, **kwargs)
#     507 def to_native_types(self: T, **kwargs) -> T:
#     508     """
#     509     Convert values to native types (strings / python objects) that are used
#     510     in formatting (repr / csv).
#     511     """
# --> 512     return self.apply("to_native_types", **kwargs)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\internals\blocks.py:531, in Block.to_native_types(self, na_rep, quoting, **kwargs)
#     528 @final
#     529 def to_native_types(self, na_rep: str = "nan", quoting=None, **kwargs) -> Block:
#     530     """convert to our native types format"""
# --> 531     result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     532     return self.make_block(result)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\internals\blocks.py:2543, in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2540         values = np.array(values, dtype="object")
#    2542     values[mask] = na_rep
# -> 2543     values = values.astype(object, copy=False)
#    2544     return values
#    2546 from pandas.io.formats.format import FloatArrayFormatter
#
# KeyboardInterrupt:

# %%
# peaks 리스트 초기화
peaks = []
# 양수 peak 찾기
peaks.extend(scipy.signal.find_peaks(total['close'], distance=5, width=10)[0])

# 음수 peak 찾기
peaks.extend(scipy.signal.find_peaks(-total['close'], distance=5, width=10)[0])
        
# 마지막 날짜가 peak인 경우 peaks에 추가
if len(total)-1 not in peaks:
    peaks.append(len(total)-1)

# 수익성, 안전성, 유동성 지표 추가
total.loc[:, 'peak_date'] = ''
total.loc[:, 'peak_close'] = np.nan
total.loc[:, 'peak_diffratio'] = np.nan
total.loc[:, 'interpeak_mdd'] = np.nan
total.loc[:, 'interpeak_trans_price_exp'] = np.nan
total.loc[:, 'trans_price_exp']=np.nan

_last_date = 0  # 이전 날짜를 저장하는 변수 초기화
for peak in peaks:  # peaks 리스트의 각 peak에 대해 반복
    _date = total.iloc[peak]['date']  # 현재 peak의 날짜 저장
    _close = total.iloc[peak]['close']  # 현재 peak의 종가 저장
    mask = (total['date'] >= _last_date) & (total['date'] <= _date)  # 이전 날짜부터 현재 peak 날짜까지의 mask 생성
    _last_date = _date  # 이전 날짜를 현재 peak의 날짜로 업데이트
    if len(total[mask]) > 0:  # mask에 해당하는 데이터가 있는 경우
        total.loc[mask, 'peak_date'] = _date  # mask에 해당하는 행의 'peak_date' 열에 현재 peak의 날짜 저장
        total.loc[mask, 'peak_close'] = _close  # mask에 해당하는 행의 'peak_close' 열에 현재 peak의 종가 저장
        _x = np.array(total.loc[mask, 'close'])  # mask에 해당하는 행의 'close' 열을 numpy 배열로 변환하여 _x에 저장
        lower = np.argmax(np.maximum.accumulate(_x) - _x)  # 최대값을 누적한 후 현재 값과의 차이 중 최대값의 인덱스를 lower에 저장
        upper = np.argmax(_x[:lower+1])  # lower 이전까지의 값 중 최대값의 인덱스를 upper에 저장
        total.loc[mask, 'interpeak_mdd'] = (_x[lower] - _x[upper]) / _x[upper]  # mask에 해당하는 행의 'interpeak_mdd' 열에 MDD 계산 결과 저장
        # total.loc[mask, 'interpeak_trans_price_exp'] = total.loc[mask, 'trans_price_exp'].mean()  # mask에 해당하는 행의 'interpeak_trans_price_exp' 열에 'trans_price_exp' 열의 평균값 저장 = nan값만 나온다
                
total.loc[:, 'peak_diffratio'] = (total.loc[:, 'peak_close'] - total.loc[:, 'close']) / total.loc[:, 'close']  # 'peak_diffratio' 열에 종가와 peak 종가의 차이 비율 계산하여 저장
total = total.drop(['peak_date', 'peak_close'], axis=1)  # 'peak_date'와 'peak_close' 열 삭제        

total
# Out:
#             date  time    open    high     low   close       value peak_date  \
# 0       20210628   901   47050   47400   47000   47300   812740000
# 1       20210628   902   47300   47350   47100   47300   519680000
# 2       20210628   903   47250   47350   47200   47250   339770000
# 3       20210628   904   47250   47400   47200   47300   298840000
# 4       20210628   905   47350   48350   47300   48150  1741660000
# ...          ...   ...     ...     ...     ...     ...         ...       ...
# 188447  20230628  1517  128000  128300  127900  128200   774400000
# 188448  20230628  1518  128200  128300  127700  128000   135220000
# 188449  20230628  1519  128000  128000  127800  127800   297460000
# 188450  20230628  1520  127800  127900  127600  127700   265480000
# 188451  20230628  1530  127700  127700  127700  127700  1582710000
#
#         peak_close  peak_diffratio  interpeak_mdd  interpeak_trans_price_exp  \
# 0              NaN             NaN            NaN                        NaN
# 1              NaN             NaN            NaN                        NaN
# 2              NaN             NaN            NaN                        NaN
# 3              NaN             NaN            NaN                        NaN
# 4              NaN             NaN            NaN                        NaN
# ...            ...             ...            ...                        ...
# 188447         NaN             NaN            NaN                        NaN
# 188448         NaN             NaN            NaN                        NaN
# 188449         NaN             NaN            NaN                        NaN
# 188450         NaN             NaN            NaN                        NaN
# 188451         NaN             NaN            NaN                        NaN
#
#         trans_price_exp
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 188447              NaN
# 188448              NaN
# 188449              NaN
# 188450              NaN
# 188451              NaN
#
# [188452 rows x 13 columns]

# %%
# # 데이터를 토대로 종목별, 일간 수익률, 연간수익률, 일간리스크, 연간리스크를 구하기
# # 5종목 분당 변동률
# mins_ret = total.pct_change()
# # 하루 변동률
# daily_ret = mins_ret.mean() * 394
# # 5종목 1년간 변동률 평균(252는 미국 1년 평균 개장일)
# annual_ret = daily_ret.mean() * 252
# #분당 변 리스크
# mins_ret = total.cov()
# # 5종목 연간 리스크 = cov()함수를 이용한 분당 변동률 의 공분산
# mins_cov = mins_ret.cov()
# # 5종목 1년간 리스크(252는 미국 1년 평균 개장일)
# daily_cov = mins_cov * 394
# # 5종목 1년간 리스크(252는 미국 1년 평균 개장일)
# annual_cov = daily_cov * 252


# # 1. 수익률, 리스크, 비중 list 생성
# # 수익률 = port_ret
# # 리스크 = port_risk
# # 비  중 = port_weights
# port_ret = []
# port_risk = []
# port_weights = []
# # 샤프지수 추가
# shape_ratio = []

# for i in range(20000):
#     # 2. 랜덤 숫자 4개 생성 - 랜덤숫자 4개의 합 = 1이되도록 생성
#     weights = np.random.random(len(total))
#     weights /= np.sum(weights)
    
#     # 3. 랜덤 생성된 종목뵹 비중 배열과 종목별 연간 수익률을 곱해 포트폴리오의 전체 수익률(returns)를 구한다.
#     returns = np.dot(weights, daily_ret)

#     # 4. 종목별 연간공분산과 종목별 비중배열 곱하고, 다시 종목별 비중의 전치로 곱한다.
#     # 결과값의 제곱근을 sqrt()함수로 구하면 해당 포트폴리오 전체 risk가 구해진다. 
#     risk = np.sqrt(np.dot(weights.T, np.dot(daily_ret, weights)))

#     # 5. 20,000개 포트폴리오의 수익률, 리스크, 종목별 비중을 각각 리스트에 추가한다.
#     port_ret.append(returns)
#     port_risk.append(risk)
#     port_weights.append(weights)
#     shape_ratio.append(returns/risk)

# # 포트폴리오 결과에 샤프지수 추가
# portfolio = {'Returns' : port_ret, 'Risk' : port_risk, 'Shape' : shape_ratio}
# for j, s in enumerate(stocks):
#     # 6. portfolio 4종목의 가중치 weights를 1개씩 가져온다.
#     portfolio[s] = [weight[j] for weight in port_weights]

# # 7. 최종 df는 시총 상위 5종목의 보유 비중에 따른 risk와 예상 수익률을 확인할 수 있다.
# df = pd.DataFrame(portfolio)
# df = df[['Returns', 'Risk', 'Shape'] + [s for s in stocks]]


# # 8. 샤프지수로 위험단위당 예측 수익률이 가장 높은 포트폴리오 구하기
# # 샤프지수 칼럼에서 가장 높은 샤프지수 구하기
# max_shape = df.loc[df['Shape'] == df['Shape'].max()]
# Out:
# 0       20230622
# 1       20230622
# 2       20230622
# 3       20230622
# 4       20230622
#           ...
# 1828    20230630
# 1829    20230630
# 1830    20230630
# 1831    20230630
# 1832    20230630
# Name: date, Length: 1833, dtype: int64

# %%
total.describe()
# Out:
#               time         open         high          low        close  \
# count  1833.000000  1833.000000  1833.000000  1833.000000  1833.000000
# mean   1192.153846  1699.241680  1700.337152  1698.009274  1699.435352
# std     192.632403    34.530506    34.669522    34.336974    34.572598
# min     901.000000  1622.000000  1622.000000  1620.000000  1620.000000
# 25%    1020.000000  1668.000000  1669.000000  1667.000000  1669.000000
# 50%    1209.000000  1694.000000  1695.000000  1692.000000  1694.000000
# 75%    1346.000000  1729.000000  1730.000000  1728.000000  1729.000000
# max    1530.000000  1773.000000  1775.000000  1766.000000  1774.000000
#
#              volume  Accumulated sales volume  Accumulated number of contract  \
# count   1833.000000               1833.000000                     1833.000000
# mean     753.698309              56948.047463                    49380.698854
# std     1575.154087              32965.328522                    36984.407272
# min        1.000000                  0.000000                      758.000000
# 25%       13.000000              30396.000000                    22816.000000
# 50%      136.000000              53942.000000                    34561.000000
# 75%      800.000000              80149.000000                    60630.000000
# max    26786.000000             144066.000000                   178724.000000
#
#                MFI            ADI  ...  ratio close MA5  ratio close MA10  \
# count  1833.000000    1833.000000  ...      1829.000000       1824.000000
# mean     41.567578   54539.106688  ...         1.000015          1.000040
# std      30.234385   51304.111444  ...         0.002205          0.002868
# min       0.000000  -11546.194232  ...         0.989373          0.987257
# 25%      14.713427   23287.239102  ...         0.998949          0.998495
# 50%      36.612401   37188.054830  ...         1.000117          1.000179
# 75%      67.821704   52850.854830  ...         1.001140          1.001425
# max      99.906753  193327.801064  ...         1.022635          1.024469
#
#        ratio close MA20  ratio close MA60  ratio close MA120   MA5 VOLUME  \
# count       1814.000000       1774.000000        1714.000000  1829.000000
# mean           1.000073          1.000056           0.999990   752.792674
# std            0.003754          0.005834           0.007804   819.420328
# min            0.985758          0.980141           0.976290     2.800000
# 25%            0.997981          0.996623           0.994720   219.800000
# 50%            1.000102          1.000005           0.999809   435.000000
# 75%            1.001775          1.003074           1.005256   999.000000
# max            1.025834          1.023640           1.024840  7853.600000
#
#        MA10 VOLUME  MA20 VOLUME  MA60 VOLUME  MA120 VOLUME
# count  1824.000000  1814.000000  1774.000000   1714.000000
# mean    751.428728   752.321803   755.234602    761.610161
# std     638.335319   508.355100   320.284248    223.702715
# min      28.500000    90.300000   246.083333    298.441667
# 25%     281.175000   384.487500   540.041667    578.145833
# 50%     558.950000   612.800000   683.966667    763.095833
# 75%    1042.275000   958.600000   957.691667    932.425000
# max    5192.800000  3573.150000  1713.866667   1228.025000
#
# [8 rows x 74 columns]

# %%
# chart_data.index = pd.to_datetime(chart_data.date) 
# chart_data = chart_data.iloc[:, 1:]

# a = chart_data.isnull().sum(0)
# nullCol = [x for x in a.index if a[x] != 0]

# if len(nullCol) > 0:
#     for c in nullCol:
#         print('{} has Null'.format(c))
#         chart_data[c] = chart_data[c].interpolate(method='time')


# total = total.iloc[:, 1:]

# a = total.isnull().sum(0) 
# nullCol = [x for x in a.index if a[x] != 0]
# if len(nullCol) > 0:
#     for c in nullCol:
#         print('{} has Null'.format(c))
#         total[c] = total[c].interpolate(method='time')
# Out:
# shift has Null
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 8
#       6 for c in nullCol:
#       7     print('{} has Null'.format(c))
# ----> 8     total[c] = total[c].interpolate(method='time')
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\series.py:5942, in Series.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    5930 def interpolate(
#    5931     self: Series,
#    5932     method: str = "linear",
#    (...)
#    5940     **kwargs,
#    5941 ) -> Series | None:
# -> 5942     return super().interpolate(
#    5943         method=method,
#    5944         axis=axis,
#    5945         limit=limit,
#    5946         inplace=inplace,
#    5947         limit_direction=limit_direction,
#    5948         limit_area=limit_area,
#    5949         downcast=downcast,
#    5950         **kwargs,
#    5951     )
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\generic.py:7681, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7675 if isna(index).any():
#    7676     raise NotImplementedError(
#    7677         "Interpolation with NaNs in the index "
#    7678         "has not been implemented. Try filling "
#    7679         "those NaNs before interpolating."
#    7680     )
# -> 7681 new_data = obj._mgr.interpolate(
#    7682     method=method,
#    7683     axis=axis,
#    7684     index=index,
#    7685     limit=limit,
#    7686     limit_direction=limit_direction,
#    7687     limit_area=limit_area,
#    7688     inplace=inplace,
#    7689     downcast=downcast,
#    7690     **kwargs,
#    7691 )
#    7693 result = self._constructor(new_data)
#    7694 if should_transpose:
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\internals\managers.py:417, in BaseBlockManager.interpolate(self, inplace, **kwargs)
#     416 def interpolate(self: T, inplace: bool, **kwargs) -> T:
# --> 417     return self.apply(
#     418         "interpolate", inplace=inplace, **kwargs, using_cow=using_copy_on_write()
#     419     )
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\internals\blocks.py:1380, in Block.interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, downcast, using_cow, **kwargs)
#    1377     data = self.values.copy()
#    1378 data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
# -> 1380 missing.interpolate_array_2d(
#    1381     data,
#    1382     method=method,
#    1383     axis=axis,
#    1384     index=index,
#    1385     limit=limit,
#    1386     limit_direction=limit_direction,
#    1387     limit_area=limit_area,
#    1388     fill_value=fill_value,
#    1389     **kwargs,
#    1390 )
#    1392 nb = self.make_block_same_class(data, refs=refs)
#    1393 return nb._maybe_downcast([nb], downcast, using_cow)
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\missing.py:267, in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     264 else:
#     265     assert index is not None  # for mypy
# --> 267     _interpolate_2d_with_fill(
#     268         data=data,
#     269         index=index,
#     270         axis=axis,
#     271         method=method,
#     272         limit=limit,
#     273         limit_direction=limit_direction,
#     274         limit_area=limit_area,
#     275         fill_value=fill_value,
#     276         **kwargs,
#     277     )
#
# File c:\Users\TJ\anaconda3\envs\pro64\lib\site-packages\pandas\core\missing.py:309, in _interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     307 if method == "time":
#     308     if not needs_i8_conversion(index.dtype):
# --> 309         raise ValueError(
#     310             "time-weighted interpolation only works "
#     311             "on Series or DataFrames with a "
#     312             "DatetimeIndex"
#     313         )
#     314     method = "values"
#     316 valid_limit_directions = ["forward", "backward", "both"]
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex
