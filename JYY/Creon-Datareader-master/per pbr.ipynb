# %%
import requests

res = requests.get('http://localhost:3000/get_historical_data?url=https://kr.investing.com/indices/us-spx-500-historical-data')
data = res.json()
data
# Out:
# {'url': 'https://kr.investing.com/indices/us-spx-500-historical-data',
#  'data': {'data': [{'direction_color': 'redFont',
#     'rowDate': '2022년 10월 07일',
#     'rowDateRaw': 1665100800,
#     'rowDateTimestamp': '2022-10-07T00:00:00Z',
#     'last_close': '3,639.66',
#     'last_open': '3,706.74',
#     'last_max': '3,706.74',
#     'last_min': '3,620.73',
#     'volume': '',
#     'volumeRaw': 0,
#     'change_precent': '-2.80',
#     'last_closeRaw': '3639.65991210937500',
#     'last_openRaw': '3706.73999023437500',
#     'last_maxRaw': '3706.73999023437500',
#     'last_minRaw': '3620.72998046875000',
#     'change_precentRaw': -2.800361778677356},
#    {'direction_color': 'redFont',
#     'rowDate': '2022년 10월 06일',
#     'rowDateRaw': 1665014400,
#     'rowDateTimestamp': '2022-10-06T00:00:00Z',
#     'last_close': '3,744.52',
#     'last_open': '3,771.97',
#     'last_max': '3,797.93',
#     'last_min': '3,739.22',
#     'volume': '',
#     'volumeRaw': 0,
# ...

# %%
import pandas as pd
df = pd.DataFrame(data['data']['data'])
df
# Out:
#     direction_color        rowDate  rowDateRaw      rowDateTimestamp  \
# 0           redFont  2022년 10월 07일  1665100800  2022-10-07T00:00:00Z
# 1           redFont  2022년 10월 06일  1665014400  2022-10-06T00:00:00Z
# 2           redFont  2022년 10월 05일  1664928000  2022-10-05T00:00:00Z
# 3         greenFont  2022년 10월 04일  1664841600  2022-10-04T00:00:00Z
# 4         greenFont  2022년 10월 03일  1664755200  2022-10-03T00:00:00Z
# ..              ...            ...         ...                   ...
# 188         redFont  2022년 01월 07일  1641513600  2022-01-07T00:00:00Z
# 189         redFont  2022년 01월 06일  1641427200  2022-01-06T00:00:00Z
# 190         redFont  2022년 01월 05일  1641340800  2022-01-05T00:00:00Z
# 191         redFont  2022년 01월 04일  1641254400  2022-01-04T00:00:00Z
# 192       greenFont  2022년 01월 03일  1641168000  2022-01-03T00:00:00Z
#
#     last_close last_open  last_max  last_min volume  volumeRaw change_precent  \
# ...

# %%
import requests

res = requests.get('http://localhost:3000/get_historical_data?url=https://kr.investing.com/indices/us-spx-500-historical-data&start_date=2022-01-01')
data = res.json()
data
